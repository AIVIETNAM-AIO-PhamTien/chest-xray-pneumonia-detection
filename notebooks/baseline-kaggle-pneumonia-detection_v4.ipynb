# %% [markdown]
# # Phát hiện viêm phổi trên ảnh X-quang ngực
#
# **Baseline v4 — kiểm chứng confound tỉ lệ khung**
#
# Dữ liệu: [Chest X-Ray Images (Pneumonia)](https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia) —
# 5.856 ảnh X-quang ngực của trẻ 1–5 tuổi, hai lớp `NORMAL` và `PNEUMONIA`.
#
# ---
#
# ## Tóm tắt
#
# | Hạng mục | Lựa chọn |
# |---|---|
# | Kiến trúc so sánh | ResNet18, DenseNet121, CNN nhỏ train từ đầu |
# | Câu hỏi trọng tâm | Mô hình có bám vào tỉ lệ khung ảnh thay vì bệnh lý? |
# | Xử lý mất cân bằng | So sánh cross-entropy có và không có trọng số lớp |
# | Chia dữ liệu | Cross-validation theo **nhóm suy từ tên file**; original test được dùng như **known benchmark** |
# | Chọn checkpoint | Theo validation AUC, không dùng test |
# | Chọn cấu hình | Theo OOF group AUC, không dùng test |
# | Điểm làm việc | Tune riêng ngưỡng ảnh và group trên OOF validation |
# | Tiền xử lý | Đối chứng 2×2: letterbox giữ tỉ lệ so với stretch ép vuông |
# | Đơn vị đánh giá | Báo cả **mức ảnh** và **mức filename-derived group** |
#
# Kết quả ở phần 3, đối chứng resize ở mục 3.5, diễn giải ở phần 4, hạn chế ở
# phần 5.
#
# ---
#
# ### Chuẩn bị
#
# **Kaggle:** Add Data `chest-xray-pneumonia`, bật GPU T4 và Internet. `RUN_MODE="auto"`
# sẽ dùng cấu hình đầy đủ. Chạy smoke trước bằng cách đổi thành `RUN_MODE="smoke"`.
#
# **MacBook:** mở notebook từ project này; dữ liệu sibling `../chest_xray` được tự
# tìm. `auto` dùng MPS/CPU và chạy smoke: 2 cấu hình nhỏ × 1 fold × 1 epoch, đi qua cả
# hai chế độ resize. Có thể đặt `RUN_MODE="full"`, nhưng full 8 × 5 (~85 phút trên
# T4) nên ưu tiên Kaggle GPU và dùng **Save Version → Save & Run All**.
#
# > Kết quả của notebook v2 được giữ nguyên làm audit artifact. Notebook source này
# > không dùng lại output cũ; mọi bảng được sinh lại từ đầu. Known benchmark đã được
# > xem trong quá trình phát triển nên chỉ phục vụ chẩn đoán distribution shift, không
# > được xem là final untouched holdout.

# %% [markdown]
# ## Cấu hình

# %%
RUN_MODE      = "auto"   # auto | smoke | full
DATA_ROOT_OVERRIDE = None # ví dụ: "/Users/me/data/chest_xray"
SEED          = 42
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 15
LR            = 1e-4
WEIGHT_DECAY  = 1e-5
PATIENCE      = 5
NUM_WORKERS   = 2         # runtime sẽ ép về 0 trên macOS

N_FOLDS       = 5         # 1 = một holdout 15%; 5 = cross-validation đầy đủ
VAL_FRACTION  = 0.15      # chỉ dùng khi N_FOLDS = 1
BORDER_FRAC   = 0.15      # dùng ở phần 4.3
DETERMINISTIC = True      # cudnn tất định; chậm hơn một chút, đổi lại tái lập tốt hơn
RESIZE_MODE   = "letterbox"  # mặc định cho thí nghiệm không ghi rõ "resize"
THRESHOLD_OBJECTIVE = "sensitivity"  # sensitivity | balanced_accuracy
TARGET_SENSITIVITY = 0.97
BOOTSTRAP_REPS = 2000    # KTC cho audit tỉ lệ khung ở mức filename-derived group

# Hai bộ augmentation. "mạnh" mô phỏng thiết lập của các cài đặt công khai
# đạt độ đặc hiệu cao hơn: xoay 30 độ, zoom và dịch ảnh.
AUG_PRESETS = {
    "nhe":  {"rotation": 10, "scale": 0.00, "translate": 0.00, "jitter": 0.15},
    "manh": {"rotation": 30, "scale": 0.20, "translate": 0.10, "jitter": 0.20},
}

# BỐN DÒNG ĐẦU là thiết kế 2x2 tách riêng ảnh hưởng của cách resize và của
# augmentation, đăng ký trước trong FACTORIAL_NAMES. Trước đây stretch và
# letterbox nằm ở hai lần chạy khác nhau nên không quy được nguyên nhân; giờ
# chúng nằm cùng một run, cùng fold, cùng seed.
# Bốn dòng sau là ablation quanh baseline. cnn_tu_dau thay đổi nhiều yếu tố cùng
# lúc, nên không dùng để kết luận riêng về pretraining.
ALL_EXPERIMENTS = [
    # --- 2x2: resize x augmentation ---------------------------------------
    {"name": "resnet18",     "arch": "resnet18",    "size": 224, "aug": "nhe",
     "balancing": "weighted", "resize": "letterbox",
     "hoi": "baseline; giữ tỉ lệ bằng đệm viền"},
    {"name": "stretch_nhe",  "arch": "resnet18",    "size": 224, "aug": "nhe",
     "balancing": "weighted", "resize": "stretch",
     "hoi": "ép vuông đổi cách mã hóa tỉ lệ khung, có đổi lỗi FP không?"},
    {"name": "augment_manh", "arch": "resnet18",    "size": 224, "aug": "manh",
     "balancing": "weighted", "resize": "letterbox",
     "hoi": "augment mạnh có thu hẹp khoảng cách OOF→test?"},
    {"name": "stretch_manh", "arch": "resnet18",    "size": 224, "aug": "manh",
     "balancing": "weighted", "resize": "stretch",
     "hoi": "augment mạnh có bù được biến dạng do ép vuông?"},
    # --- ablation quanh baseline ------------------------------------------
    {"name": "khong_weight", "arch": "resnet18",    "size": 224, "aug": "nhe",
     "balancing": "none",     "resize": RESIZE_MODE,
     "hoi": "trọng số lớp có cần không?"},
    {"name": "anh_128",      "arch": "resnet18",    "size": 128, "aug": "nhe",
     "balancing": "weighted", "resize": RESIZE_MODE,
     "hoi": "128px có mất gì so với 224px?"},
    {"name": "densenet121",  "arch": "densenet121", "size": 224, "aug": "nhe",
     "balancing": "weighted", "resize": RESIZE_MODE,
     "hoi": "mô hình lớn hơn có hơn không?"},
    {"name": "cnn_tu_dau",   "arch": "small_cnn",   "size": 150, "aug": "manh",
     "balancing": "none",     "resize": RESIZE_MODE,
     "hoi": "tái hiện CNN 150px train từ đầu"},
]

# Bốn ô của thiết kế 2x2, đăng ký TRƯỚC khi chạy. Cả bốn đều được chấm trên
# known benchmark test ở mục 3.5 — không phải để chọn mô hình, mà vì câu hỏi
# "cách resize có đổi lỗi false positive không" chỉ trả lời được khi có chỉ số
# test của cả bốn. Việc chọn BEST vẫn hoàn toàn bằng OOF.
FACTORIAL_NAMES = ["resnet18", "stretch_nhe", "augment_manh", "stretch_manh"]


# Smoke phải đi qua CẢ HAI chế độ resize. Một cấu hình letterbox duy nhất sẽ
# không dựng cache stretch, không train model stretch, và quan trọng nhất là
# không phát hiện được nếu loader test lấy nhầm cache.
SMOKE_EXPERIMENTS = [
    {"name": "smoke_letterbox", "arch": "small_cnn", "size": 128, "aug": "nhe",
     "balancing": "weighted", "resize": "letterbox",
     "hoi": "kiểm tra pipeline, không dùng để báo cáo"},
    {"name": "smoke_stretch",   "arch": "small_cnn", "size": 128, "aug": "nhe",
     "balancing": "weighted", "resize": "stretch",
     "hoi": "kiểm tra pipeline, không dùng để báo cáo"},
]
EXPERIMENTS = ALL_EXPERIMENTS
CLASSES = ("NORMAL", "PNEUMONIA")  # NORMAL=0, PNEUMONIA=1

# %%
import gc, hashlib, json, os, platform, random, re, time, warnings
from collections import Counter, defaultdict
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import PIL
import scipy
import sklearn
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from PIL import Image
from sklearn.metrics import (average_precision_score, confusion_matrix, f1_score,
                             precision_score, recall_score, roc_auc_score)
from sklearn.model_selection import StratifiedGroupKFold
from torch.utils.data import DataLoader, Dataset
from torchvision import models, transforms

warnings.filterwarnings("ignore", category=UserWarning)

IS_KAGGLE = Path("/kaggle/working").is_dir()
if torch.cuda.is_available():
    DEVICE = torch.device("cuda")
elif hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
    DEVICE = torch.device("mps")
else:
    DEVICE = torch.device("cpu")

if RUN_MODE == "auto":
    RUN_MODE = "full" if IS_KAGGLE and DEVICE.type == "cuda" else "smoke"
if RUN_MODE not in {"smoke", "full"}:
    raise ValueError("RUN_MODE phải là 'auto', 'smoke' hoặc 'full'")

if RUN_MODE == "smoke":
    EPOCHS, N_FOLDS, BATCH_SIZE = 1, 1, min(BATCH_SIZE, 16)
    EXPERIMENTS = SMOKE_EXPERIMENTS
    # Smoke phải đi qua cả mục 3.5, nếu không thì đường code đó không được kiểm
    # tra cho tới lúc chạy full và lỗi mới lộ ra sau 85 phút.
    FACTORIAL_NAMES = [spec["name"] for spec in SMOKE_EXPERIMENTS]
else:
    EXPERIMENTS = ALL_EXPERIMENTS

if platform.system() == "Darwin":
    NUM_WORKERS = 0  # notebook + spawn không an toàn với closure worker/cache global
LOCAL_PROJECT_ROOT = next((p for p in (Path.cwd(), *Path.cwd().parents)
                           if (p / ".git").is_dir()), Path.cwd())
WORK_DIR = (Path("/kaggle/working") if IS_KAGGLE
            else LOCAL_PROJECT_ROOT / "artifacts/notebook_rerun")
WORK_DIR.mkdir(parents=True, exist_ok=True)
LOG_PATH = WORK_DIR / "train_log.txt"
LOG_PATH.write_text("", encoding="utf-8")
PIN_MEMORY = DEVICE.type == "cuda"
AMP_ENABLED = DEVICE.type == "cuda"
DEVICE_NAME = (torch.cuda.get_device_name(0) if DEVICE.type == "cuda"
               else "Apple Metal (MPS)" if DEVICE.type == "mps" else platform.processor() or "CPU")

if DETERMINISTIC and DEVICE.type == "cuda":
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


def set_seed(seed=SEED):
    """Seed mọi nguồn ngẫu nhiên mà pipeline đụng tới."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def loader_seed_args(seed=SEED):
    """generator + worker_init_fn cho DataLoader.

    Thiếu hai thứ này thì thứ tự xáo trộn và augmentation chạy trong worker vẫn
    ngẫu nhiên dù đã gọi set_seed — một lỗ hổng tái lập rất hay bị bỏ sót.
    """
    generator = torch.Generator()
    generator.manual_seed(seed)

    def worker_init_fn(worker_id):
        worker_seed = seed + worker_id
        random.seed(worker_seed)
        np.random.seed(worker_seed)

    return {"generator": generator, "worker_init_fn": worker_init_fn}


def log(*parts):
    """In ra màn hình, đồng thời ghi vào LOG_PATH.

    Output của notebook Kaggle có thể mất chunk khi in nhanh; file thì không.
    """
    line = " ".join(str(part) for part in parts)
    print(line)
    with open(LOG_PATH, "a", encoding="utf-8") as handle:
        handle.write(line + "\n")


set_seed()

# Ghi lại phiên bản thư viện. Thiếu nó thì con số trong báo cáo không gắn được
# với môi trường đã sinh ra chúng.
VERSIONS = {
    "python": platform.python_version(), "torch": torch.__version__,
    "torchvision": torchvision.__version__, "numpy": np.__version__,
    "pandas": pd.__version__, "scikit-learn": sklearn.__version__,
    "scipy": scipy.__version__,
    "pillow": PIL.__version__,
}
with open(WORK_DIR / "environment.json", "w") as handle:
    json.dump({**VERSIONS, "device": str(DEVICE), "device_name": DEVICE_NAME,
               "run_mode": RUN_MODE, "seed": SEED,
               "deterministic": DETERMINISTIC}, handle, indent=2)

# Lưu cấu hình đã resolve sau khi auto/smoke/full được áp dụng. File này giúp
# phân biệt source config với config thực sự sinh ra kết quả.
RESOLVED_CONFIG = {
    "run_mode": RUN_MODE,
    "seed": SEED,
    "image_cache_size": IMG_SIZE,
    "batch_size": BATCH_SIZE,
    "epochs": EPOCHS,
    "learning_rate": LR,
    "weight_decay": WEIGHT_DECAY,
    "patience": PATIENCE,
    "n_folds": N_FOLDS,
    "val_fraction": VAL_FRACTION,
    "deterministic": DETERMINISTIC,
    "threshold_objective": THRESHOLD_OBJECTIVE,
    "target_sensitivity": TARGET_SENSITIVITY,
    "bootstrap_reps": BOOTSTRAP_REPS,
    "augment_presets": AUG_PRESETS,
    "experiments": EXPERIMENTS,
    "factorial_names": FACTORIAL_NAMES,
}
with open(WORK_DIR / "resolved_config.json", "w", encoding="utf-8") as handle:
    json.dump(RESOLVED_CONFIG, handle, indent=2, ensure_ascii=False)

log("runtime:", "Kaggle" if IS_KAGGLE else "local", "| mode:", RUN_MODE)
log("device:", DEVICE, f"({DEVICE_NAME})", "| AMP:", AMP_ENABLED,
    "| workers:", NUM_WORKERS)
if RUN_MODE == "smoke":
    log("SMOKE RUN: chỉ kiểm tra pipeline; KHÔNG dùng chỉ số để báo cáo.")
log("phiên bản:", " ".join(f"{k}={v}" for k, v in VERSIONS.items()))
# Out:
# runtime: Kaggle | mode: full
# device: cuda (Tesla T4) | AMP: True | workers: 2
# phiên bản: python=3.12.13 torch=2.10.0+cu128 torchvision=0.25.0+cu128 numpy=2.0.2 pandas=2.3.3 scikit-learn=1.6.1 scipy=1.16.3 pillow=11.3.0

# %% [markdown]
# ---
#
# # 1. Dữ liệu
#
# ## 1.1. Nạp dữ liệu
#
# Notebook tìm dữ liệu theo thứ tự: `DATA_ROOT_OVERRIDE`, biến môi trường
# `CXR_DATA_ROOT`, Kaggle input, rồi các thư mục hiện tại/cha trên Mac. Nó chỉ
# chấp nhận thư mục chứa trực tiếp `train/NORMAL` và `train/PNEUMONIA`.
#
# Bên trong dataset còn hai thứ gây sai số nếu quét thư mục ngây thơ:
#
# - cây `chest_xray/chest_xray/` lồng bên trong, **chứa bản sao của toàn bộ ảnh**
# - cây `__MACOSX/` chứa file `._*.jpeg` — không phải ảnh, nhưng có đuôi `.jpeg`
#   và có đủ cấu trúc `train/NORMAL` + `train/PNEUMONIA`

# %%
def list_images(directory):
    """Ảnh .jpeg thật, bỏ file sidecar ._* của macOS."""
    return sorted(p for p in Path(directory).glob("*.jpeg")
                  if not p.name.startswith("._"))


def find_data_root(search_paths):
    """Thư mục chứa trực tiếp train/NORMAL và train/PNEUMONIA."""
    if isinstance(search_paths, (str, Path)):
        search_paths = [search_paths]

    candidates = []
    for base in map(Path, search_paths):
        if not base.exists():
            continue
        for train_dir in base.rglob("train"):
            if "__MACOSX" in train_dir.parts:
                continue
            if (train_dir / "NORMAL").is_dir() and (train_dir / "PNEUMONIA").is_dir():
                candidates.append(train_dir.parent.resolve())

    if not candidates:
        raise FileNotFoundError(
            f"Không tìm thấy dataset dưới {[str(p) for p in search_paths]}. "
            "Kaggle: Add Data 'Chest X-Ray Images (Pneumonia)'. "
            "Mac: đặt DATA_ROOT_OVERRIDE hoặc CXR_DATA_ROOT.")

    candidates = sorted(set(candidates), key=lambda path: len(path.parts))
    for candidate in candidates:
        n = len(list_images(candidate / "train" / "NORMAL"))
        mark = "  <- dùng" if candidate == candidates[0] else "  (bản trùng, bỏ qua)"
        print(f"  {candidate}  [{n} ảnh train/NORMAL]{mark}")
    return candidates[0]


explicit_root = DATA_ROOT_OVERRIDE or os.environ.get("CXR_DATA_ROOT")
if explicit_root:
    DATA_ROOT = find_data_root([explicit_root])
else:
    cwd = Path.cwd()
    DATA_ROOT = find_data_root([
        "/kaggle/input", cwd / "chest_xray", cwd.parent / "chest_xray",
        cwd.parent.parent / "chest_xray", cwd / "data/raw",
        cwd.parent / "data/raw",
    ])
log("\nDATA_ROOT =", DATA_ROOT)
# Out:
#   /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray  [1341 ảnh train/NORMAL]  <- dùng
#   /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/chest_xray  [1341 ảnh train/NORMAL]  (bản trùng, bỏ qua)
#
# DATA_ROOT = /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray

# %% [markdown]
# ## 1.2. Danh sách ảnh và filename-derived group
#
# Tên file là thông tin duy nhất để suy ra ảnh nào có thể thuộc cùng một group:
#
# | Lớp | Dạng tên |
# |---|---|
# | Viêm phổi | `person1_bacteria_1.jpeg`, `person1_virus_6.jpeg` |
# | Bình thường | `IM-0115-0001.jpeg`, `NORMAL2-IM-1427-0001.jpeg` |
#
# Bộ đếm `person` **không dùng chung** giữa hai phân nhóm viêm phổi: `bacteria` và
# `virus` mỗi loại chạy một dãy riêng từ 1. Khoá định danh vì vậy phải gồm cả phân
# nhóm — mục 1.3.4 chứng minh bằng số.

# %%
PNEUMONIA_RE = re.compile(r"^person(\d+)_(bacteria|virus)_", re.IGNORECASE)
NORMAL_RE    = re.compile(r"^(?:(NORMAL\d+)-)?IM-(\d+)-", re.IGNORECASE)


def parse_group_id(filename):
    """Khoá group suy từ tên file; không khẳng định đây là clinical patient ID."""
    match = PNEUMONIA_RE.match(filename)
    if match:
        return f"pneumonia:{match.group(2).lower()}:{int(match.group(1))}"
    match = NORMAL_RE.match(filename)
    if match:
        return f"normal:{(match.group(1) or 'IM').lower()}:{int(match.group(2))}"
    raise ValueError(f"Tên file lạ, không suy ra được group: {filename}")


def build_manifest(root):
    """Một dòng cho mỗi ảnh: đường dẫn, split gốc, nhãn, filename-derived group."""
    rows = []
    for split in ("train", "val", "test"):
        for class_id, class_name in enumerate(CLASSES):
            directory = Path(root) / split / class_name
            if not directory.is_dir():
                continue
            for path in list_images(directory):
                rows.append({
                    "path": str(path.resolve()), "filename": path.name,
                    "split_original": split, "class_name": class_name,
                    "class_id": class_id, "group_id": parse_group_id(path.name)})
    if not rows:
        raise FileNotFoundError(f"Không có ảnh .jpeg nào dưới {root}")

    frame = pd.DataFrame(rows)
    frame["cache_index"] = np.arange(len(frame))   # vị trí trong cache ở mục 2.2
    return frame


manifest = build_manifest(DATA_ROOT)
log(f"{len(manifest):,} ảnh | {manifest['group_id'].nunique():,} filename-derived groups")
manifest.head(3)
# Out:
# 5,856 ảnh | 4,097 filename-derived groups
#                                                 path           filename  \
# 0  /kaggle/input/datasets/paultimothymooney/chest...  IM-0115-0001.jpeg
# 1  /kaggle/input/datasets/paultimothymooney/chest...  IM-0117-0001.jpeg
# 2  /kaggle/input/datasets/paultimothymooney/chest...  IM-0119-0001.jpeg
#
#   split_original class_name  class_id       group_id  cache_index
# 0          train     NORMAL         0  normal:im:115            0
# 1          train     NORMAL         0  normal:im:117            1
# 2          train     NORMAL         0  normal:im:119            2

# %% [markdown]
# ## 1.3. Kiểm tra chất lượng dữ liệu

# %%
print("1.3.1  Số lượng theo split và lớp")
print("-" * 62)
print(f"{'split':<8}{'NORMAL':>9}{'PNEUMONIA':>12}{'tổng':>9}{'P/N':>7}")
for split in ("train", "val", "test"):
    subset = manifest[manifest["split_original"] == split]
    counts = subset["class_name"].value_counts()
    normal, pneumonia = int(counts.get("NORMAL", 0)), int(counts.get("PNEUMONIA", 0))
    ratio = pneumonia / normal if normal else float("nan")
    print(f"{split:<8}{normal:>9,}{pneumonia:>12,}{normal + pneumonia:>9,}{ratio:>7.2f}")
print(f"{'TỔNG':<8}{'':>9}{'':>12}{len(manifest):>9,}")
# Out:
# 1.3.1  Số lượng theo split và lớp
# --------------------------------------------------------------
# split      NORMAL   PNEUMONIA     tổng    P/N
# train       1,341       3,875    5,216   2.89
# val             8           8       16   1.00
# test          234         390      624   1.67
# TỔNG                             5,856

# %% [markdown]
# Tập validation gốc chỉ có **16 ảnh** — quá nhỏ để chọn checkpoint, nên mục 2.1
# cắt validation mới từ pool train+val.
#
# Tỉ lệ hai lớp cũng khác nhau giữa các split: train **2,89:1** còn test **1,67:1**.
# Điểm này quyết định cách đọc kết quả ở phần 3.

# %%
print("1.3.2  Ảnh trùng nội dung (SHA-256)")
print("-" * 62)
manifest["sha256"] = [hashlib.sha256(Path(path).read_bytes()).hexdigest()
                      for path in manifest["path"]]
by_hash = defaultdict(list)
for digest, split in zip(manifest["sha256"], manifest["split_original"]):
    by_hash[digest].append(split)

duplicates = [s for s in by_hash.values() if len(s) > 1]
cross_split = [s for s in duplicates if len(set(s)) > 1]
print(f"tổng file             : {len(manifest):,}")
print(f"hash duy nhất         : {len(by_hash):,}")
print(f"nhóm ảnh trùng        : {len(duplicates)}")
print(f"  trong đó xuyên split: {len(cross_split)}")
print()
print("Không có ảnh y hệt nằm xuyên original split." if not cross_split
      else "CẢNH BÁO: ảnh trùng xuyên original split — kết quả đánh giá bị nhiễm.")
# Out:
# 1.3.2  Ảnh trùng nội dung (SHA-256)
# --------------------------------------------------------------
# tổng file             : 5,856
# hash duy nhất         : 5,824
# nhóm ảnh trùng        : 30
#   trong đó xuyên split: 0
#
# Không có ảnh y hệt nằm xuyên original split.

# %%
print("1.3.3  Định dạng, độ phân giải, tỉ lệ khung")
print("-" * 62)
modes, unreadable, dims = Counter(), 0, []
for path in manifest["path"]:
    try:
        with Image.open(path) as image:
            modes[image.mode] += 1
            dims.append(image.size)
    except OSError:
        unreadable += 1

dims = pd.DataFrame(dims, columns=["width", "height"])
dims["aspect"] = dims["width"] / dims["height"]
manifest[["width", "height", "aspect"]] = dims[["width", "height", "aspect"]]
manifest_dims = dims                       # dùng lại ở mục 1.4

print(f"file không mở được : {unreadable}")
for mode, count in modes.most_common():
    print(f"  mode {mode:<4}       : {count:,}")
print(f"số kích thước khác : {dims.drop(columns='aspect').drop_duplicates().shape[0]:,}")
print(f"rộng  : {dims.width.min():,} – {dims.width.max():,}  (trung vị {int(dims.width.median()):,})")
print(f"cao   : {dims.height.min():,} – {dims.height.max():,}  (trung vị {int(dims.height.median()):,})")
print(f"tỉ lệ : {dims.aspect.min():.2f} – {dims.aspect.max():.2f}  (trung vị {dims.aspect.median():.2f})")
print()
print("Tỉ lệ khung trung vị theo original split/lớp:")
display(manifest.pivot_table(index="split_original", columns="class_name",
                             values="aspect", aggfunc="median").round(3))
print("\nCác thí nghiệm sau ép grayscale và so sánh có kiểm soát letterbox với stretch.")
# Out:
# 1.3.3  Định dạng, độ phân giải, tỉ lệ khung
# --------------------------------------------------------------
# file không mở được : 0
#   mode L          : 5,573
#   mode RGB        : 283
# số kích thước khác : 4,803
# rộng  : 384 – 2,916  (trung vị 1,281)
# cao   : 127 – 2,713  (trung vị 888)
# tỉ lệ : 0.84 – 3.38  (trung vị 1.42)
#
# Tỉ lệ khung trung vị theo original split/lớp:
# class_name      NORMAL  PNEUMONIA
# split_original
# test             1.353      1.506
# train            1.223      1.488
# val              1.225      1.503
# Các thí nghiệm sau ép grayscale và so sánh có kiểm soát letterbox với stretch.

# %%
print("1.3.4  Filename-derived group và nguy cơ trùng giữa các split")
print("-" * 62)
naive_re = re.compile(r"^(person\d+)_", re.IGNORECASE)
naive, corrected = defaultdict(set), defaultdict(set)
for filename, split in zip(manifest["filename"], manifest["split_original"]):
    match = naive_re.match(filename)
    naive[match.group(1).lower() if match else filename].add(split)
    corrected[parse_group_id(filename)].add(split)

naive_span     = sum(1 for s in naive.values() if len(s) > 1)
corrected_span = sum(1 for s in corrected.values() if len(s) > 1)
print(f"khoá person<N>              : {len(naive):,} nhóm, {naive_span} nằm ở >1 split")
print(f"khoá (phân nhóm, person<N>) : {len(corrected):,} nhóm, {corrected_span} nằm ở >1 split")

subtype_ids = defaultdict(set)
for filename in manifest["filename"]:
    match = PNEUMONIA_RE.match(filename)
    if match:
        subtype_ids[match.group(2).lower()].add(int(match.group(1)))
print()
for subtype, ids in sorted(subtype_ids.items()):
    print(f"  {subtype:<9}: {len(ids):,} số, dải 1..{max(ids)}, "
          f"mật độ {len(ids) / max(ids):.3f}")
print(f"  số được dùng bởi CẢ HAI phân nhóm: "
      f"{len(subtype_ids['bacteria'] & subtype_ids['virus']):,}")

per_group = Counter(parse_group_id(f) for f in manifest["filename"])
multi = sum(1 for n in per_group.values() if n > 1)
print(f"\nnhóm có >1 ảnh: {multi:,}/{len(per_group):,} "
      f"(nhiều nhất {max(per_group.values())} ảnh)")
# Out:
# 1.3.4  Filename-derived group và nguy cơ trùng giữa các split
# --------------------------------------------------------------
# khoá person<N>              : 3,257 nhóm, 170 nằm ở >1 split
# khoá (phân nhóm, person<N>) : 4,097 nhóm, 0 nằm ở >1 split
#
#   bacteria : 1,437 số, dải 1..1954, mật độ 0.735
#   virus    : 1,216 số, dải 1..1685, mật độ 0.722
#   số được dùng bởi CẢ HAI phân nhóm: 979
#
# nhóm có >1 ảnh: 726/4,097 (nhiều nhất 30 ảnh)

# %% [markdown]
# Hai dãy `bacteria` và `virus` đều gần liên tục, đều bắt đầu từ 1, và có 979 số
# dùng ở cả hai. Nếu bộ đếm là toàn cục thì dãy `virus` phải tránh các số đã thuộc
# `bacteria`; thực tế chúng trùng nhau liên tục. Vậy `person1_bacteria` và
# `person1_virus` là hai người khác nhau.
#
# Với khoá này, **không group nào nằm ở nhiều hơn một split gốc** — tập test
# gốc dùng làm holdout được.
#
# Nhưng 726 group có nhiều hơn một ảnh. Vì vậy validation phải chia theo group và
# đánh giá phải báo thêm mức group. Không gọi đây là clinical patient khi chưa có
# metadata chính thức.

# %% [markdown]
# ## 1.4. Phân tích khám phá

# %%
C_NORMAL, C_PNEUMONIA = "#2a78d6", "#eb6834"
CLASS_COLOR = {"NORMAL": C_NORMAL, "PNEUMONIA": C_PNEUMONIA}
INK, INK_SOFT, GRID = "#0b0b0b", "#52514e", "#e5e4e0"

plt.rcParams.update({
    "figure.facecolor": "white", "axes.facecolor": "white",
    "axes.edgecolor": GRID, "axes.labelcolor": INK_SOFT,
    "axes.titlecolor": INK, "axes.titlesize": 12, "axes.titleweight": "600",
    "axes.titlelocation": "left", "axes.titlepad": 12,
    "axes.grid": True, "grid.color": GRID, "grid.linewidth": 0.8,
    "axes.axisbelow": True, "axes.spines.top": False, "axes.spines.right": False,
    "xtick.color": INK_SOFT, "ytick.color": INK_SOFT,
    "xtick.labelsize": 10, "ytick.labelsize": 10,
    "legend.frameon": False, "font.size": 10,
})


def tidy(ax, ygrid_only=True):
    ax.tick_params(length=0)
    ax.xaxis.grid(not ygrid_only)
    ax.yaxis.grid(ygrid_only)
    return ax

# %% [markdown]
# ### Phân bố lớp theo split

# %%
counts = (manifest.groupby(["split_original", "class_name"])
          .size().unstack(fill_value=0).reindex(["train", "val", "test"]))

fig, ax = plt.subplots(figsize=(9, 4.2))
y, h, gap = np.arange(len(counts)), 0.36, 0.02
for offset, cls in ((-h / 2 - gap / 2, "NORMAL"), (h / 2 + gap / 2, "PNEUMONIA")):
    bars = ax.barh(y + offset, counts[cls].values, height=h,
                   color=CLASS_COLOR[cls], label=cls)
    for rect, value in zip(bars, counts[cls].values):
        ax.text(rect.get_width() + 60, rect.get_y() + rect.get_height() / 2,
                f"{value:,}", va="center", ha="left", fontsize=9, color=INK_SOFT)

ratios = counts["PNEUMONIA"] / counts["NORMAL"].clip(lower=1)
ax.set_yticks(y)
ax.set_yticklabels([f"{s}\n{r:.2f}:1" for s, r in ratios.items()])
ax.set_xlim(0, counts.values.max() * 1.16)
ax.set_xlabel("số ảnh")
ax.set_title("Phân bố lớp theo split  ·  tỉ lệ PNEUMONIA/NORMAL dưới tên split")
ax.legend(loc="upper right", ncol=2)
tidy(ax, ygrid_only=False)
plt.tight_layout(); plt.show()

# %% [markdown]
# Một mô hình đoán PNEUMONIA cho mọi ảnh đã đạt **62,5%** accuracy trên test. Nên
# accuracy đơn thuần không kết luận được gì.

# %% [markdown]
# ### Kích thước và tỉ lệ khung ảnh

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4.2))

axes[0].scatter(manifest_dims.width, manifest_dims.height, s=4, alpha=0.18,
                color=C_NORMAL, edgecolors="none")
axes[0].axvline(IMG_SIZE, color=C_PNEUMONIA, lw=2, ls="--")
axes[0].axhline(IMG_SIZE, color=C_PNEUMONIA, lw=2, ls="--")
axes[0].text(IMG_SIZE * 1.1, manifest_dims.height.max() * 0.93,
             f"đầu vào mô hình {IMG_SIZE}×{IMG_SIZE}", color=C_PNEUMONIA, fontsize=9)
axes[0].set_xlabel("rộng (px)"); axes[0].set_ylabel("cao (px)")
axes[0].set_title("Kích thước ảnh gốc")
tidy(axes[0], ygrid_only=False)

axes[1].hist(manifest_dims.aspect, bins=60, color=C_NORMAL)
axes[1].axvline(1.0, color=C_PNEUMONIA, lw=2, ls="--")
axes[1].text(1.02, axes[1].get_ylim()[1] * 0.9, "vuông", color=C_PNEUMONIA, fontsize=9)
axes[1].set_xlabel("tỉ lệ khung (rộng / cao)"); axes[1].set_ylabel("số ảnh")
axes[1].set_title("Tỉ lệ khung")
tidy(axes[1])

plt.tight_layout(); plt.show()

print(f"{(manifest_dims.aspect > 1).mean():.0%} ảnh nằm ngang (rộng > cao).")
print(f"Cache mặc định là {RESIZE_MODE} ở kích thước {IMG_SIZE}×{IMG_SIZE}.")
print("Thiết kế 2×2 phía sau dựng cả letterbox và stretch cho cùng manifest/fold.")
# Out:
# 99% ảnh nằm ngang (rộng > cao).
# Cache mặc định là letterbox ở kích thước 224×224.
# Thiết kế 2×2 phía sau dựng cả letterbox và stretch cho cùng manifest/fold.

# %% [markdown]
# ### Tỉ lệ khung có phải một shortcut?
#
# Hai lớp có phân bố tỉ lệ khung khác nhau rõ rệt. Nếu khác biệt đủ lớn, mô hình
# có thể học chính tỉ lệ khung thay vì dấu hiệu bệnh lý --- đặc biệt khi pipeline
# ép mọi ảnh thành hình vuông, biến tỉ lệ khung thành biến dạng giải phẫu.
#
# Phép đo dưới đây dùng **duy nhất tỉ lệ khung** làm điểm số phân loại, không có
# mô hình nào cả. AUC thu được là lượng thông tin lớp nằm sẵn trong một con số mà
# không liên quan gì tới phổi.

# %%
aspect = manifest.copy()
sizes = []
for path in aspect["path"]:
    with Image.open(path) as image:
        sizes.append(image.size)
aspect[["width", "height"]] = pd.DataFrame(sizes, index=aspect.index)
aspect["aspect"] = aspect["width"] / aspect["height"]

# Chiều của điểm số phải chọn trên development rồi ĐÓNG BĂNG. Lấy
# max(auc, 1-auc) riêng từng split sẽ luôn báo trên 0.5 và che mất trường hợp
# quan hệ đổi chiều giữa train và test — đúng thứ cần phát hiện.
development = aspect[aspect["split_original"].isin(["train", "val"])]
median_by_class = development.groupby("class_id")["aspect"].median()
DIRECTION = 1.0 if median_by_class[1] >= median_by_class[0] else -1.0
aspect["aspect_score"] = DIRECTION * aspect["aspect"]

# Mức group: một group nhiều ảnh sẽ bị tính trọng số nhiều lần ở mức ảnh.
aspect_group = (aspect.groupby(["split_original", "group_id"], as_index=False)
                .agg(class_id=("class_id", "first"),
                     aspect_score=("aspect_score", "median")))

print("AUC khi CHỈ dùng tỉ lệ khung làm điểm số, không có mô hình.")
print(f"Chiều khóa trên development: "
      f"{'tỉ lệ lớn hơn → PNEUMONIA' if DIRECTION > 0 else 'tỉ lệ nhỏ hơn → PNEUMONIA'}\n")
for split in ("train", "test"):
    subset = aspect[aspect["split_original"] == split]
    by_group = aspect_group[aspect_group["split_original"] == split]
    auc_image = roc_auc_score(subset["class_id"], subset["aspect_score"])
    auc_group = roc_auc_score(by_group["class_id"], by_group["aspect_score"])
    print(f"  {split:<6} AUC ảnh {auc_image:.4f} (n={len(subset):,})   "
          f"AUC group {auc_group:.4f} (n={len(by_group):,})")
    for class_id, name in enumerate(CLASSES):
        values = subset[subset["class_id"] == class_id]["aspect"]
        print(f"      {name:<10} trung vị {values.median():.3f}  "
              f"IQR [{values.quantile(.25):.3f}, {values.quantile(.75):.3f}]")

fig, ax = plt.subplots(figsize=(9, 4))
bins = np.linspace(aspect["aspect"].quantile(.005), aspect["aspect"].quantile(.995), 60)
for class_id, name in enumerate(CLASSES):
    ax.hist(aspect[(aspect["split_original"] == "train")
                   & (aspect["class_id"] == class_id)]["aspect"],
            bins=bins, color=CLASS_COLOR[name], alpha=0.62, label=name)
ax.set_xlabel("tỉ lệ khung (rộng / cao)")
ax.set_ylabel("số ảnh")
ax.set_title("Tỉ lệ khung theo lớp trên tập train")
ax.legend(loc="upper right")
tidy(ax)
plt.tight_layout(); plt.show()

ASPECT = aspect[["path", "aspect"]].set_index("path")["aspect"]
# Out:
# AUC khi CHỈ dùng tỉ lệ khung làm điểm số, không có mô hình.
# Chiều khóa trên development: tỉ lệ lớn hơn → PNEUMONIA
#
#   train  AUC ảnh 0.8654 (n=5,216)   AUC group 0.8816 (n=3,654)
#       NORMAL     trung vị 1.223  IQR [1.138, 1.311]
#       PNEUMONIA  trung vị 1.488  IQR [1.352, 1.644]
#   test   AUC ảnh 0.7044 (n=624)   AUC group 0.6998 (n=428)
#       NORMAL     trung vị 1.353  IQR [1.213, 1.518]
#       PNEUMONIA  trung vị 1.506  IQR [1.382, 1.657]

# %% [markdown]
# Tỉ lệ khung một mình đã tách được hai lớp đáng kể, và tách mạnh hơn trên train
# so với test. Điều này có hai hệ quả:
#
# 1. Một mô hình học được đặc trưng này sẽ đạt kết quả cao trên validation (vốn
#    cùng phân bố với train) nhưng chuyển kém sang test --- đúng dạng khoảng cách
#    val--test quan sát được ở phần 3.
# 2. Cần một ablation thay đổi \emph{cách resize} để biết mô hình có thực sự dùng
#    đặc trưng này hay không. Mục 2.2 bổ sung chế độ letterbox cho mục đích đó.

# %% [markdown]
# ### Ảnh mẫu

# %%
set_seed()
fig, axes = plt.subplots(2, 5, figsize=(14, 6.8), constrained_layout=True)
for row, cls in enumerate(CLASSES):
    pool = manifest[(manifest["split_original"] == "train")
                    & (manifest["class_name"] == cls)].sample(5, random_state=SEED)
    for col, (_, item) in enumerate(pool.iterrows()):
        with Image.open(item["path"]) as image:
            gray = image.convert("L")
            original = f"{image.size[0]}×{image.size[1]}  ·  r={image.size[0] / image.size[1]:.2f}"
            axes[row, col].imshow(gray, cmap="gray")
        axes[row, col].set_title(original, fontsize=9, color=INK_SOFT)
        axes[row, col].axis("off")
    axes[row, 0].text(-0.08, 0.5, cls, transform=axes[row, 0].transAxes,
                      rotation=90, va="center", ha="center", fontsize=11,
                      fontweight="600", color=CLASS_COLOR[cls])
fig.suptitle("Ảnh gốc từ train  ·  kích thước và tỉ lệ khung ghi trên mỗi ảnh",
             fontsize=12, fontweight="600", x=0.02, ha="left")
plt.show()

# %% [markdown]
# Viêm phổi biểu hiện là vùng mờ trắng ở nhu mô phổi. Đáng chú ý: hầu hết ảnh có
# **ký hiệu định hướng "R"** ở góc trên — đặc trưng không mang thông tin bệnh lý
# nhưng mô hình có thể bám vào. Phần 4 kiểm tra điều đó.

# %% [markdown]
# ### Số ảnh trên mỗi filename-derived group

# %%
per_patient = manifest.groupby("group_id").size()
distribution = per_patient.value_counts().sort_index()

fig, ax = plt.subplots(figsize=(9, 4))
bars = ax.bar(distribution.index, distribution.values, color=C_NORMAL, width=0.72)
for rect, value in zip(bars, distribution.values):
    if value >= distribution.max() * 0.04:
        ax.text(rect.get_x() + rect.get_width() / 2, rect.get_height() * 1.06,
                f"{value:,}", ha="center", fontsize=9, color=INK_SOFT)
ax.set_yscale("log")
ax.set_xlabel("số ảnh của một group")
ax.set_ylabel("số group (thang log)")
ax.set_title(f"Số ảnh trên mỗi filename-derived group  ·  "
             f"{(per_patient > 1).sum():,}/{len(per_patient):,} group có nhiều hơn 1 ảnh")
tidy(ax)
plt.tight_layout(); plt.show()

# %% [markdown]
# ### Độ sáng trung bình theo lớp

# %%
set_seed()
train_pool = manifest[manifest["split_original"] == "train"]
sample = pd.concat([
    train_pool[train_pool["class_name"] == cls].sample(
        min(300, (train_pool["class_name"] == cls).sum()), random_state=SEED)
    for cls in CLASSES])

brightness = pd.DataFrame([
    {"class_name": item["class_name"],
     "mean": np.asarray(Image.open(item["path"]).convert("L").resize((64, 64)),
                        dtype=np.float32).mean()}
    for _, item in sample.iterrows()])

fig, ax = plt.subplots(figsize=(9, 4))
bins = np.linspace(0, 255, 46)
for cls in CLASSES:
    values = brightness[brightness["class_name"] == cls]["mean"]
    ax.hist(values, bins=bins, color=CLASS_COLOR[cls], alpha=0.62,
            label=f"{cls}  (TB {values.mean():.0f})")
span = brightness["mean"]
ax.set_xlim(max(0, span.min() - 12), min(255, span.max() + 12))
ax.set_xlabel("độ sáng trung bình của ảnh  (0 = đen, 255 = trắng)")
ax.set_ylabel("số ảnh")
ax.set_title("Phân bố độ sáng theo lớp")
ax.legend(loc="upper right")
tidy(ax)
plt.tight_layout(); plt.show()

delta = abs(brightness.groupby("class_name")["mean"].mean().diff().iloc[-1])
pooled = brightness.groupby("class_name")["mean"].std().mean()
print(f"chênh lệch trung bình giữa hai lớp: {delta:.1f} mức xám")
print(f"độ lệch chuẩn trong mỗi lớp       : {pooled:.1f}")
print(f"Cohen's d = {delta / pooled:.2f}")
# Out:
# chênh lệch trung bình giữa hai lớp: 2.3 mức xám
# độ lệch chuẩn trong mỗi lớp       : 16.9
# Cohen's d = 0.13

# %% [markdown]
# Hai phân bố chồng lấn gần như hoàn toàn. Mô hình **không thể** phân biệt hai lớp
# chỉ bằng độ sáng tổng thể. Kiểm tra này loại trừ một dạng học tắt; đặc trưng cục
# bộ thì phải chờ phần 4.

# %% [markdown]
# ---
#
# # 2. Phương pháp
#
# ## 2.1. Chia dữ liệu
#
# Tập test gốc giữ nguyên làm holdout, không tham gia bất kỳ quyết định nào.
# Validation cắt từ pool train+val bằng `StratifiedGroupKFold` theo group suy từ
# tên file: mọi ảnh của một group luôn nằm cùng một phía, và mỗi ảnh trong pool
# làm validation đúng một lần. Đây không phải metadata bệnh nhân chính thức.
#
# Chạy nhiều fold cho hai thứ mà một lần chia không cho được: **độ dao động** của
# kết quả, và một **ngưỡng quyết định ổn định** (mục 3.4).

# %%
def label_split(manifest, train, val, test):
    out = manifest.copy()
    out["split"] = pd.NA
    out.loc[train.index, "split"] = "train"
    out.loc[val.index,   "split"] = "val"
    out.loc[test.index,  "split"] = "test"
    return out


def make_folds(manifest, n_folds=N_FOLDS, val_fraction=VAL_FRACTION, seed=SEED):
    """Danh sách manifest, mỗi phần tử là một fold đã gán cột split."""
    pool = manifest[manifest["split_original"].isin(["train", "val"])]
    test = manifest[manifest["split_original"] == "test"]
    n_splits = max(2, round(1 / val_fraction)) if n_folds == 1 else n_folds
    splitter = StratifiedGroupKFold(n_splits=n_splits, shuffle=True, random_state=seed)

    folds = [label_split(manifest, pool.iloc[train_idx], pool.iloc[val_idx], test)
             for train_idx, val_idx in
             splitter.split(pool, pool["class_id"], groups=pool["group_id"])]
    return folds[:1] if n_folds == 1 else folds


def count_leaked_groups(split):
    """Số filename-derived groups xuất hiện ở nhiều split. Phải bằng 0."""
    return int((split.groupby("group_id")["split"].nunique() > 1).sum())


def count_leaked_hashes(split):
    """Số nội dung ảnh y hệt xuất hiện ở nhiều split. Phải bằng 0."""
    return int((split.groupby("sha256")["split"].nunique() > 1).sum())


def split_summary(split):
    rows = []
    for name in ("train", "val", "test"):
        subset = split[split["split"] == name]
        counts = subset["class_name"].value_counts()
        normal, pneumonia = int(counts.get("NORMAL", 0)), int(counts.get("PNEUMONIA", 0))
        rows.append({"split": name, "NORMAL": normal, "PNEUMONIA": pneumonia,
                     "tổng": normal + pneumonia,
                     "groups": subset["group_id"].nunique(),
                     "P/N": round(pneumonia / max(normal, 1), 2)})
    return pd.DataFrame(rows).set_index("split")


FOLDS = make_folds(manifest)
log(f"\n{len(FOLDS)} fold, chia theo filename-derived group:")
for i, split in enumerate(FOLDS):
    s = split_summary(split)
    log(f"  fold {i}: train {s.loc['train','tổng']:>5,}  val {s.loc['val','tổng']:>4,}  "
        f"test {s.loc['test','tổng']:>4,}  |  group/hash ở >1 split: "
        f"{count_leaked_groups(split)}/{count_leaked_hashes(split)}")
    assert count_leaked_groups(split) == 0
    assert count_leaked_hashes(split) == 0
    split.to_csv(WORK_DIR / f"manifest_fold{i}.csv", index=False)

print("\nChi tiết fold 0:")
display(split_summary(FOLDS[0]))
# Out:
# 5 fold, chia theo filename-derived group:
#   fold 0: train 4,168  val 1,064  test  624  |  group/hash ở >1 split: 0/0
#   fold 1: train 4,224  val 1,008  test  624  |  group/hash ở >1 split: 0/0
#   fold 2: train 4,165  val 1,067  test  624  |  group/hash ở >1 split: 0/0
#   fold 3: train 4,190  val 1,042  test  624  |  group/hash ở >1 split: 0/0
#   fold 4: train 4,181  val 1,051  test  624  |  group/hash ở >1 split: 0/0
#
# Chi tiết fold 0:
#        NORMAL  PNEUMONIA  tổng  groups   P/N
# split
# train    1092       3076  4168    2934  2.82
# val       257        807  1064     735  3.14
# test      234        390   624     428  1.67

# %% [markdown]
# ## 2.2. Tiền xử lý và augmentation
#
# Ảnh gốc trung bình khoảng 1,3 megapixel với kích thước rất khác nhau. Toàn bộ
# được giải mã **một lần** về mảng `uint8` 224×224 giữ trong RAM (~294 MB).
# `letterbox` giữ nguyên tỉ lệ khung rồi pad vào hình vuông; không kéo giãn giải phẫu.
# Nếu
# giải mã lại mỗi epoch thì CPU thành nút thắt và accelerator phải chờ.
#
# Augmentation chỉ áp cho train. Validation và test dùng pipeline tất định — nếu
# không, chỉ số đánh giá sẽ dao động theo nhiễu ngẫu nhiên.

# %%
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD  = [0.229, 0.224, 0.225]
MEAN_T = torch.tensor(IMAGENET_MEAN, device=DEVICE).view(1, 3, 1, 1)
STD_T  = torch.tensor(IMAGENET_STD,  device=DEVICE).view(1, 3, 1, 1)


def device_augment(batch, cfg):
    """Lật, xoay, zoom, dịch, đổi sáng/tương phản trên CUDA/MPS/CPU.

    Làm bằng PIL trong DataLoader thì CPU thành nút thắt: riêng RandomRotation
    và ColorJitter đã ngốn hơn 1.000 lần thời gian đọc cache. Ở đây mọi phép
    biến đổi là tensor op chạy theo lô trên accelerator đang chọn.

    Xoay, zoom và dịch được gộp vào MỘT phép biến đổi affine, nên chỉ nội suy
    một lần thay vì ba lần chồng lên nhau.
    """
    n, dev = batch.size(0), batch.device
    flip = torch.rand(n, device=dev) < 0.5
    batch = torch.where(flip.view(-1, 1, 1, 1), batch.flip(-1), batch)

    rand = lambda: torch.rand(n, device=dev) * 2 - 1          # noqa: E731  -1..1
    angles = rand() * (cfg["rotation"] * np.pi / 180)
    zoom = 1 + rand() * cfg["scale"]
    cos, sin = torch.cos(angles) * zoom, torch.sin(angles) * zoom
    theta = torch.zeros(n, 2, 3, device=dev)
    theta[:, 0, 0], theta[:, 0, 1] = cos, -sin
    theta[:, 1, 0], theta[:, 1, 1] = sin, cos
    theta[:, 0, 2] = rand() * cfg["translate"]
    theta[:, 1, 2] = rand() * cfg["translate"]
    grid = F.affine_grid(theta, batch.shape, align_corners=False)
    batch = F.grid_sample(batch, grid, align_corners=False, padding_mode="zeros")

    j = cfg["jitter"]
    scale = 1 + rand().view(-1, 1, 1, 1) * j
    contrast = 1 + rand().view(-1, 1, 1, 1) * j
    mean = batch.mean(dim=(1, 2, 3), keepdim=True)
    return ((batch * scale - mean) * contrast + mean).clamp(0, 1)


def to_model_input(batch_uint8, size=IMG_SIZE, aug=None):
    """(B,H,W) uint8 -> (B,3,H,W) chuẩn hoá trên DEVICE.

    Cache giữ ảnh ở IMG_SIZE; thí nghiệm nào cần kích thước khác thì thu nhỏ
    ngay trên DEVICE. Đây là resize hai bước (gốc -> IMG_SIZE -> size), áp dụng
    đồng nhất cho mọi split nên không tạo chênh lệch giữa train và test.
    """
    x = batch_uint8.to(DEVICE, non_blocking=True).float().div_(255).unsqueeze(1)
    if size != IMG_SIZE:
        x = F.interpolate(x, size=(size, size), mode="bilinear", align_corners=False)
    if aug is not None:
        x = device_augment(x, aug)
    return (x.expand(-1, 3, -1, -1) - MEAN_T) / STD_T


def resize_for_cache(image, size=IMG_SIZE, mode=RESIZE_MODE):
    gray = image.convert("L")
    if mode == "stretch":
        return np.asarray(gray.resize((size, size), Image.Resampling.BILINEAR))
    if mode != "letterbox":
        raise ValueError(f"RESIZE_MODE lạ: {mode}")
    gray.thumbnail((size, size), Image.Resampling.BILINEAR)
    array = np.asarray(gray)
    fill = int(np.median(array))
    canvas = Image.new("L", (size, size), color=fill)
    offset = ((size - gray.width) // 2, (size - gray.height) // 2)
    canvas.paste(gray, offset)
    return np.asarray(canvas)


def build_image_cache(manifest, size=IMG_SIZE, mode=RESIZE_MODE):
    cache = np.zeros((len(manifest), size, size), dtype=np.uint8)
    for position, path in enumerate(manifest["path"]):
        with Image.open(path) as image:
            cache[position] = resize_for_cache(image, size, mode)
        if (position + 1) % 1500 == 0:
            print(f"  {position + 1:,}/{len(manifest):,}")
    return cache


# Mỗi chế độ resize cần một cache riêng. Chỉ dựng những chế độ thực sự được
# dùng, để so sánh stretch với letterbox nằm trong cùng một lần chạy thay vì hai
# lần chạy khác nhau như trước.
REQUIRED_MODES = sorted({spec.get("resize", RESIZE_MODE) for spec in EXPERIMENTS})
IMAGE_CACHES = {}
for mode in REQUIRED_MODES:
    _started = time.time()
    IMAGE_CACHES[mode] = build_image_cache(manifest, mode=mode)
    log(f"cache {mode}: {IMAGE_CACHES[mode].nbytes / 1e6:.0f} MB cho "
        f"{len(manifest):,} ảnh trong {time.time() - _started:.0f}s")

# Cache mặc định cho các đoạn không gắn với một thí nghiệm cụ thể.
IMAGE_CACHE = IMAGE_CACHES[RESIZE_MODE if RESIZE_MODE in IMAGE_CACHES
                           else REQUIRED_MODES[0]]


class XRayDataset(Dataset):
    """Trả về ảnh uint8 thô; augmentation diễn ra trên DEVICE."""

    def __init__(self, rows, mode=RESIZE_MODE):
        self.rows, self.mode = rows, mode

    def __len__(self):
        return len(self.rows)

    def __getitem__(self, index):
        cache_index, label = self.rows[index]
        return torch.from_numpy(IMAGE_CACHES[self.mode][cache_index]), label


def make_loader(split, name, batch_size=BATCH_SIZE, seed=SEED, mode=RESIZE_MODE):
    subset = split[split["split"] == name]
    return DataLoader(
        XRayDataset(list(zip(subset["cache_index"], subset["class_id"])), mode),
        batch_size=batch_size, shuffle=(name == "train"),
        num_workers=NUM_WORKERS, pin_memory=PIN_MEMORY,
        persistent_workers=NUM_WORKERS > 0,
        **loader_seed_args(seed))


def make_loaders(split, batch_size=BATCH_SIZE, seed=SEED, mode=RESIZE_MODE):
    return {name: make_loader(split, name, batch_size, seed, mode)
            for name in ("train", "val")}


def class_weights_from(split):
    """Trọng số nghịch tần suất, chuẩn hoá để loss giữ nguyên thang đo."""
    counts = Counter(split[split["split"] == "train"]["class_id"])
    total = sum(counts.values())
    return torch.tensor([total / (len(CLASSES) * counts[i]) for i in range(len(CLASSES))],
                        dtype=torch.float, device=DEVICE)
# Out:
#   1,500/5,856
#   3,000/5,856
#   4,500/5,856
# cache letterbox: 294 MB cho 5,856 ảnh trong 55s
#   1,500/5,856
#   3,000/5,856
#   4,500/5,856
# cache stretch: 294 MB cho 5,856 ảnh trong 64s

# %% [markdown]
# ## 2.3. Chỉ số đánh giá
#
# Bài toán y tế nên bảng kết quả gồm cả nhóm chỉ số học máy lẫn nhóm quen dùng
# trong lâm sàng:
#
# | Chỉ số | Ý nghĩa | Lưu ý khi đọc |
# |---|---|---|
# | `accuracy` | Tỉ lệ đúng chung | Đoán bừa PNEUMONIA đã được 62,5% trên tập test này |
# | `precision` | Trong số ca bị gắn nhãn bệnh, bao nhiêu đúng | **Phụ thuộc tỉ lệ mắc bệnh** của tập đang đo |
# | `recall` = độ nhạy | Trong số ca bệnh thật, bắt được bao nhiêu | Bỏ sót viêm phổi là lỗi nguy hiểm nhất |
# | `specificity` = độ đặc hiệu | Trong số ca lành thật, nhận đúng bao nhiêu | Phơi bày tỉ lệ báo động giả |
# | `f1` | Trung bình điều hoà precision và recall | Chỉ nhìn lớp dương |
# | `bal_acc` | Trung bình độ nhạy và độ đặc hiệu | Không thưởng cho mô hình đoán lệch một phía |
# | `auc` | Chất lượng xếp hạng, không phụ thuộc ngưỡng | Cao mà accuracy thấp ⇒ vấn đề ở ngưỡng |
# | `pr_auc` | Như trên nhưng nhìn qua precision | |
#
# **Về precision trong bối cảnh y tế.** Precision (giá trị tiên đoán dương) thay
# đổi theo tỉ lệ mắc bệnh của quần thể: cùng một mô hình đem sang nơi có tỉ lệ mắc
# khác sẽ cho precision khác, dù mô hình không đổi. Tập test ở đây có **62,5% ca
# bệnh** — cao hơn thực tế phòng khám rất nhiều, nên precision đo ở đây không
# chuyển sang thực tế được.
#
# Độ nhạy và độ đặc hiệu là thuộc tính của chính mô hình, không phụ thuộc tỉ lệ
# mắc. Vì vậy chúng là số chính của báo cáo này, còn precision ghi kèm chú thích.
#
# Với một công cụ **sàng lọc**, bỏ sót ca bệnh nguy hiểm hơn báo động giả, nên độ
# nhạy được ưu tiên. Precision chỉ thành ràng buộc chính khi mỗi ca dương tính kéo
# theo can thiệp tốn kém hoặc xâm lấn.
#
# **Mức ảnh và mức group.** Tập test có 624 ảnh nhưng 428 group suy từ tên file,
# trong đó 82 group có nhiều hơn một ảnh. Chỉ số mức ảnh tính trọng số gấp bội cho
# group có nhiều ảnh. Báo cáo cả hai, nhưng không gọi group này là bệnh nhân chính
# thức vì dataset không kèm patient metadata.

# %%
METRIC_COLS = ["accuracy", "precision", "recall", "specificity",
               "f1", "bal_acc", "auc", "pr_auc"]


def metrics_at(labels, probs, threshold=0.5):
    """Chấm điểm tại một ngưỡng. threshold=0.5 chính là argmax trên hai logit."""
    labels, probs = np.asarray(labels), np.asarray(probs)
    preds = (probs >= threshold).astype(int)
    tn, fp, fn, tp = confusion_matrix(labels, preds, labels=[0, 1]).ravel()
    sensitivity, specificity = tp / max(tp + fn, 1), tn / max(tn + fp, 1)
    return {
        "threshold": float(threshold),
        "accuracy": float((labels == preds).mean()),
        "precision": precision_score(labels, preds, zero_division=0),
        "recall": recall_score(labels, preds, zero_division=0),
        "specificity": float(specificity),
        "f1": f1_score(labels, preds, zero_division=0),
        "bal_acc": float((sensitivity + specificity) / 2),
        "auc": roc_auc_score(labels, probs),
        "pr_auc": average_precision_score(labels, probs),
        "confusion_matrix": confusion_matrix(labels, preds).tolist(),
    }


def to_group_level(group_ids, labels, probs):
    """Gộp theo filename-derived group; xác suất là trung bình các ảnh."""
    frame = pd.DataFrame({"group": group_ids, "label": labels, "prob": probs})
    label_counts = frame.groupby("group")["label"].nunique()
    if int(label_counts.max()) != 1:
        bad = label_counts[label_counts > 1].index.tolist()[:5]
        raise ValueError(f"Group chứa nhiều nhãn, ví dụ: {bad}")
    rolled = frame.groupby("group", sort=True).agg(
        label=("label", "first"), prob=("prob", "mean"))
    return rolled["label"].to_numpy(), rolled["prob"].to_numpy()


def tune_threshold(labels, probs, objective=THRESHOLD_OBJECTIVE,
                   target_sensitivity=TARGET_SENSITIVITY):
    """Chọn một candidate thật trên validation/OOF, không nội suy qua vùng tie."""
    labels, probs = np.asarray(labels), np.asarray(probs)
    candidates = np.unique(np.clip(probs, 0.001, 0.999))
    if len(candidates) > 400:
        indices = np.linspace(0, len(candidates) - 1, 400).round().astype(int)
        candidates = candidates[np.unique(indices)]

    rows = [metrics_at(labels, probs, float(t)) for t in candidates]
    if objective == "balanced_accuracy":
        best = max(rows, key=lambda m: (m["bal_acc"], m["specificity"],
                                        m["recall"], m["threshold"]))
    elif objective == "sensitivity":
        feasible = [m for m in rows if m["recall"] >= target_sensitivity - 1e-12]
        if not feasible:
            warnings.warn("Không có ngưỡng đạt target sensitivity; dùng recall cao nhất.")
            feasible = rows
            best = max(feasible, key=lambda m: (m["recall"], m["specificity"],
                                                m["threshold"]))
        else:
            best = max(feasible, key=lambda m: (m["specificity"], m["bal_acc"],
                                                m["threshold"]))
    else:
        raise ValueError(f"THRESHOLD_OBJECTIVE lạ: {objective}")
    return float(best["threshold"]), best

# %% [markdown]
# ## 2.4. Kiến trúc
#
# Ba kiến trúc có thể chạy trong cùng framework. Chỉ các dòng ablation đổi đúng
# một yếu tố mới được diễn giải nhân quả; cấu hình `small_cnn` khác nhiều yếu tố:
#
# | Tên | Mô tả |
# |---|---|
# | `resnet18` | Pretrained ImageNet, fine-tune toàn bộ |
# | `densenet121` | Pretrained ImageNet, sâu hơn, nhiều tham số hơn |
# | `small_cnn` | 4 khối tích chập train từ đầu, không pretrained |
#
# `small_cnn` là tham chiếu train-from-scratch, không cô lập riêng tác động của
# pretraining.

# %%
class SmallCNN(nn.Module):
    """4 khối Conv-BN-ReLU-Pool rồi gộp toàn cục. Train từ đầu."""

    def __init__(self, num_classes=len(CLASSES)):
        super().__init__()
        def block(cin, cout):
            return nn.Sequential(
                nn.Conv2d(cin, cout, 3, padding=1), nn.BatchNorm2d(cout),
                nn.ReLU(inplace=True), nn.MaxPool2d(2))
        self.features = nn.Sequential(block(3, 32), block(32, 64),
                                      block(64, 128), block(128, 256))
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d(1), nn.Flatten(),
            nn.Dropout(0.3), nn.Linear(256, num_classes))

    def forward(self, x):
        return self.classifier(self.features(x))


def build_model(arch, pretrained=True, device=DEVICE):
    if arch == "resnet18":
        weights = models.ResNet18_Weights.DEFAULT if pretrained else None
        model = models.resnet18(weights=weights)
        model.fc = nn.Linear(model.fc.in_features, len(CLASSES))
    elif arch == "densenet121":
        weights = models.DenseNet121_Weights.DEFAULT if pretrained else None
        model = models.densenet121(weights=weights)
        model.classifier = nn.Linear(model.classifier.in_features, len(CLASSES))
    elif arch == "small_cnn":
        model = SmallCNN()
    else:
        raise ValueError(f"Kiến trúc lạ: {arch!r}")
    return model.to(device)


def target_layer_for(model, arch):
    """Lớp tích chập cuối để gắn Grad-CAM. Chỉ đích danh theo kiến trúc.

    Cách dò 'Conv2d cuối cùng' sẽ sai âm thầm khi đổi kiến trúc — heatmap vẫn
    hiện ra, chỉ là hiện sai chỗ.
    """
    return {"resnet18": lambda: model.layer4[-1],
            "densenet121": lambda: model.features.denseblock4,
            "small_cnn": lambda: model.features[-1]}[arch]()


def parameter_count_millions(arch):
    model = build_model(arch, pretrained=False, device=torch.device("cpu"))
    count = sum(p.numel() for p in model.parameters()) / 1e6
    del model
    return round(count, 1)


display(pd.DataFrame([
    {"thí nghiệm": s["name"], "kiến trúc": s["arch"], "px": s["size"],
     "resize": s.get("resize", RESIZE_MODE),
     "augment": s["aug"], "balancing": s["balancing"],
     "tham số (M)": parameter_count_millions(s["arch"]),
     "câu hỏi": s["hoi"]}
    for s in EXPERIMENTS]).set_index("thí nghiệm"))
# Out:
#                 kiến trúc   px     resize augment balancing  tham số (M)  \
# thí nghiệm
# resnet18         resnet18  224  letterbox     nhe  weighted         11.2
# stretch_nhe      resnet18  224    stretch     nhe  weighted         11.2
# augment_manh     resnet18  224  letterbox    manh  weighted         11.2
# stretch_manh     resnet18  224    stretch    manh  weighted         11.2
# khong_weight     resnet18  224  letterbox     nhe      none         11.2
# anh_128          resnet18  128  letterbox     nhe  weighted         11.2
# densenet121   densenet121  224  letterbox     nhe  weighted          7.0
# cnn_tu_dau      small_cnn  150  letterbox    manh      none          0.4
#
#                                                         câu hỏi
# thí nghiệm
# resnet18                      baseline; giữ tỉ lệ bằng đệm viền
# stretch_nhe   ép vuông đổi cách mã hóa tỉ lệ khung, có đổi l...
# augment_manh      augment mạnh có thu hẹp khoảng cách OOF→test?
# stretch_manh     augment mạnh có bù được biến dạng do ép vuông?
# khong_weight                         trọng số lớp có cần không?
# anh_128                           128px có mất gì so với 224px?
# densenet121                       mô hình lớn hơn có hơn không?
# cnn_tu_dau                      tái hiện CNN 150px train từ đầu

# %% [markdown]
# ## 2.5. Vòng huấn luyện
#
# Adam, learning rate giảm theo validation AUC, dừng sớm sau 5 epoch không cải
# thiện. Mỗi fold chỉ sinh prediction validation và checkpoint. Sau đó notebook
# ghép OOF validation để chọn cấu hình và tune hai threshold riêng.
#
# Known benchmark **không tham gia** chọn checkpoint, cấu hình hay threshold.
# Mục 3.4 chấm cấu hình `BEST` đã khóa; mục 3.5 chấm thêm bốn ô 2×2 đã đăng ký
# trước để chẩn đoán distribution shift. Các kết quả benchmark này mang nhãn
# `exploratory_known_test`, không phải final untouched evaluation.

# %%
@torch.no_grad()
def predict(model, loader, size=IMG_SIZE):
    """(nhãn thật, xác suất PNEUMONIA) trên toàn bộ loader."""
    model.eval()
    labels_all, probs_all = [], []
    for images, labels in loader:
        logits = model(to_model_input(images, size))
        probs_all += torch.softmax(logits.float(), dim=1)[:, 1].cpu().tolist()
        labels_all += labels.tolist()
    return np.array(labels_all), np.array(probs_all)


def run_fold(spec, fold_index, epochs=EPOCHS):
    log(f"\n{'=' * 62}\n{spec['name']}  |  fold {fold_index}\n{'=' * 62}")
    resize = spec.get("resize", RESIZE_MODE)
    log(f"{spec['arch']} | {spec['size']}px | resize {resize} | "
        f"augment {spec['aug']} | balancing {spec['balancing']}")
    set_seed(SEED + fold_index)

    split = FOLDS[fold_index]
    loaders = make_loaders(split, seed=SEED + fold_index, mode=resize)
    try:
        model = build_model(spec["arch"], pretrained=True)
    except Exception as exc:
        raise RuntimeError("Không tải được ImageNet weights. Bật Internet trên Kaggle "
                           "hoặc tải weights vào cache trước khi chạy.") from exc
    size, aug = spec["size"], AUG_PRESETS[spec["aug"]]

    weights = class_weights_from(split) if spec["balancing"] == "weighted" else None
    log("trọng số lớp:", [round(w, 3) for w in weights.tolist()] if weights is not None
        else "không dùng")
    criterion = nn.CrossEntropyLoss(weight=weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", factor=0.3, patience=2)
    scaler = torch.amp.GradScaler("cuda", enabled=AMP_ENABLED)

    best_score, best_epoch, best_state, stale = -np.inf, 0, None, 0
    for epoch in range(1, epochs + 1):
        model.train()
        running_loss = 0.0
        for images, labels in loaders["train"]:
            inputs = to_model_input(images, size, aug)
            labels = labels.to(DEVICE, non_blocking=PIN_MEMORY)
            optimizer.zero_grad(set_to_none=True)
            with torch.amp.autocast(device_type=DEVICE.type, enabled=AMP_ENABLED):
                loss = criterion(model(inputs), labels)
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            running_loss += loss.item() * inputs.size(0)

        train_loss = running_loss / len(loaders["train"].dataset)
        val_labels, val_probs = predict(model, loaders["val"], size)
        val_metrics = metrics_at(val_labels, val_probs, 0.5)
        scheduler.step(val_metrics["auc"])

        marker = ""
        if val_metrics["auc"] > best_score + 1e-8:
            best_score, best_epoch, stale = val_metrics["auc"], epoch, 0
            best_state = {k: v.detach().cpu().clone()
                          for k, v in model.state_dict().items()}
            marker = "  <- best"
        else:
            stale += 1

        log(f"epoch {epoch:>2}/{epochs}  loss {train_loss:.4f}  "
            f"val_f1@0.5 {val_metrics['f1']:.4f}  val_auc {val_metrics['auc']:.4f}{marker}")
        if stale >= PATIENCE:
            log(f"dừng sớm ở epoch {epoch}")
            break

    model.load_state_dict(best_state)
    log(f"khôi phục checkpoint epoch {best_epoch}, val_auc {best_score:.4f}")
    val_labels, val_probs = predict(model, loaders["val"], size)
    val_rows = split[split["split"] == "val"].reset_index(drop=True)
    val_groups = val_rows["group_id"].to_numpy()
    assert np.array_equal(val_labels, val_rows["class_id"].to_numpy())

    tag = f"{spec['name']}_fold{fold_index}"
    checkpoint_path = WORK_DIR / f"{tag}.pth"
    torch.save(best_state, checkpoint_path)
    val_rows.assign(p_pneumonia=val_probs).to_csv(
        WORK_DIR / f"validation_predictions_{tag}.csv", index=False)

    result = {
        "experiment": spec["name"], "resize": resize, "arch": spec["arch"], "size": spec["size"],
        "balancing": spec["balancing"], "fold": fold_index,
        "best_epoch": best_epoch, "checkpoint": str(checkpoint_path),
        "val_labels": val_labels, "val_probs": val_probs, "val_groups": val_groups,
        "val": metrics_at(val_labels, val_probs, 0.5),
    }
    del model, loaders, optimizer, scheduler, scaler, best_state
    gc.collect()
    if DEVICE.type == "cuda":
        torch.cuda.empty_cache()
    elif DEVICE.type == "mps":
        torch.mps.empty_cache()
    return result

# %% [markdown]
# ---
#
# # 3. Kết quả
#
# ## 3.1. Huấn luyện

# %%
log(f"Bắt đầu {RUN_MODE}: {len(EXPERIMENTS)} thí nghiệm × {len(FOLDS)} fold × "
    f"tối đa {EPOCHS} epoch")
_t0 = time.time()
RUNS = [run_fold(spec, fold)
        for spec in EXPERIMENTS
        for fold in range(len(FOLDS))]
log(f"\ntổng thời gian: {(time.time() - _t0) / 60:.1f} phút "
    f"({len(EXPERIMENTS)} thí nghiệm × {len(FOLDS)} fold)")
# Out:
# Bắt đầu full: 8 thí nghiệm × 5 fold × tối đa 15 epoch
#
# ==============================================================
# resnet18  |  fold 0
# ==============================================================
# resnet18 | 224px | resize letterbox | augment nhe | balancing weighted
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 165MB/s]
# trọng số lớp: [1.908, 0.678]
# epoch  1/15  loss 0.1276  val_f1@0.5 0.9786  val_auc 0.9966  <- best
# epoch  2/15  loss 0.0679  val_f1@0.5 0.9889  val_auc 0.9989  <- best
# epoch  3/15  loss 0.0503  val_f1@0.5 0.9926  val_auc 0.9994  <- best
# epoch  4/15  loss 0.0391  val_f1@0.5 0.9841  val_auc 0.9991
# epoch  5/15  loss 0.0428  val_f1@0.5 0.9836  val_auc 0.9989
# epoch  6/15  loss 0.0220  val_f1@0.5 0.9906  val_auc 0.9991
# epoch  7/15  loss 0.0153  val_f1@0.5 0.9938  val_auc 0.9994
# epoch  8/15  loss 0.0106  val_f1@0.5 0.9950  val_auc 0.9994  <- best
# epoch  9/15  loss 0.0091  val_f1@0.5 0.9926  val_auc 0.9994
# epoch 10/15  loss 0.0073  val_f1@0.5 0.9950  val_auc 0.9995  <- best
# epoch 11/15  loss 0.0077  val_f1@0.5 0.9932  val_auc 0.9995
# epoch 12/15  loss 0.0050  val_f1@0.5 0.9938  val_auc 0.9995  <- best
# epoch 13/15  loss 0.0051  val_f1@0.5 0.9938  val_auc 0.9995
# epoch 14/15  loss 0.0058  val_f1@0.5 0.9926  val_auc 0.9995  <- best
# epoch 15/15  loss 0.0068  val_f1@0.5 0.9932  val_auc 0.9995  <- best
# khôi phục checkpoint epoch 15, val_auc 0.9995
#
# ==============================================================
# resnet18  |  fold 1
# ==============================================================
# resnet18 | 224px | resize letterbox | augment nhe | balancing weighted
# trọng số lớp: [1.959, 0.671]
# epoch  1/15  loss 0.1462  val_f1@0.5 0.9878  val_auc 0.9978  <- best
# epoch  2/15  loss 0.0655  val_f1@0.5 0.9918  val_auc 0.9997  <- best
# epoch  3/15  loss 0.0505  val_f1@0.5 0.9848  val_auc 0.9995
# epoch  4/15  loss 0.0324  val_f1@0.5 0.9834  val_auc 0.9996
# epoch  5/15  loss 0.0461  val_f1@0.5 0.9932  val_auc 0.9994
# epoch  6/15  loss 0.0184  val_f1@0.5 0.9932  val_auc 0.9998  <- best
# epoch  7/15  loss 0.0182  val_f1@0.5 0.9932  val_auc 0.9999  <- best
# epoch  8/15  loss 0.0182  val_f1@0.5 0.9939  val_auc 0.9996
# epoch  9/15  loss 0.0106  val_f1@0.5 0.9966  val_auc 0.9997
# epoch 10/15  loss 0.0070  val_f1@0.5 0.9952  val_auc 0.9999  <- best
# epoch 11/15  loss 0.0071  val_f1@0.5 0.9959  val_auc 0.9999  <- best
# epoch 12/15  loss 0.0056  val_f1@0.5 0.9959  val_auc 0.9999  <- best
# epoch 13/15  loss 0.0053  val_f1@0.5 0.9966  val_auc 0.9999
# epoch 14/15  loss 0.0061  val_f1@0.5 0.9959  val_auc 0.9998
# epoch 15/15  loss 0.0101  val_f1@0.5 0.9966  val_auc 0.9999
# khôi phục checkpoint epoch 12, val_auc 0.9999
#
# ==============================================================
# resnet18  |  fold 2
# ==============================================================
# resnet18 | 224px | resize letterbox | augment nhe | balancing weighted
# trọng số lớp: [1.941, 0.674]
# epoch  1/15  loss 0.1442  val_f1@0.5 0.9821  val_auc 0.9987  <- best
# epoch  2/15  loss 0.0774  val_f1@0.5 0.9873  val_auc 0.9988  <- best
# epoch  3/15  loss 0.0495  val_f1@0.5 0.9866  val_auc 0.9991  <- best
# epoch  4/15  loss 0.0461  val_f1@0.5 0.9885  val_auc 0.9991  <- best
# epoch  5/15  loss 0.0405  val_f1@0.5 0.9879  val_auc 0.9993  <- best
# epoch  6/15  loss 0.0270  val_f1@0.5 0.9924  val_auc 0.9994  <- best
# epoch  7/15  loss 0.0307  val_f1@0.5 0.9879  val_auc 0.9992
# epoch  8/15  loss 0.0247  val_f1@0.5 0.9917  val_auc 0.9996  <- best
# epoch  9/15  loss 0.0131  val_f1@0.5 0.9879  val_auc 0.9991
# epoch 10/15  loss 0.0121  val_f1@0.5 0.9833  val_auc 0.9994
# epoch 11/15  loss 0.0259  val_f1@0.5 0.9887  val_auc 0.9987
# epoch 12/15  loss 0.0126  val_f1@0.5 0.9905  val_auc 0.9994
# epoch 13/15  loss 0.0059  val_f1@0.5 0.9917  val_auc 0.9995
# dừng sớm ở epoch 13
# khôi phục checkpoint epoch 8, val_auc 0.9996
#
# ==============================================================
# resnet18  |  fold 3
# ==============================================================
# resnet18 | 224px | resize letterbox | augment nhe | balancing weighted
# trọng số lớp: [1.956, 0.672]
# epoch  1/15  loss 0.1361  val_f1@0.5 0.9788  val_auc 0.9958  <- best
# epoch  2/15  loss 0.0764  val_f1@0.5 0.9869  val_auc 0.9976  <- best
# epoch  3/15  loss 0.0588  val_f1@0.5 0.9815  val_auc 0.9979  <- best
# epoch  4/15  loss 0.0402  val_f1@0.5 0.9889  val_auc 0.9971
# epoch  5/15  loss 0.0243  val_f1@0.5 0.9895  val_auc 0.9981  <- best
# epoch  6/15  loss 0.0265  val_f1@0.5 0.9827  val_auc 0.9986  <- best
# epoch  7/15  loss 0.0241  val_f1@0.5 0.9914  val_auc 0.9983
# epoch  8/15  loss 0.0335  val_f1@0.5 0.9915  val_auc 0.9988  <- best
# epoch  9/15  loss 0.0185  val_f1@0.5 0.9928  val_auc 0.9994  <- best
# epoch 10/15  loss 0.0227  val_f1@0.5 0.9895  val_auc 0.9985
# epoch 11/15  loss 0.0155  val_f1@0.5 0.9851  val_auc 0.9976
# epoch 12/15  loss 0.0210  val_f1@0.5 0.9895  val_auc 0.9986
# epoch 13/15  loss 0.0081  val_f1@0.5 0.9921  val_auc 0.9987
# epoch 14/15  loss 0.0053  val_f1@0.5 0.9921  val_auc 0.9985
# dừng sớm ở epoch 14
# khôi phục checkpoint epoch 9, val_auc 0.9994
#
# ==============================================================
# resnet18  |  fold 4
# ==============================================================
# resnet18 | 224px | resize letterbox | augment nhe | balancing weighted
# trọng số lớp: [1.932, 0.675]
# epoch  1/15  loss 0.1347  val_f1@0.5 0.9904  val_auc 0.9989  <- best
# epoch  2/15  loss 0.0588  val_f1@0.5 0.9892  val_auc 0.9991  <- best
# epoch  3/15  loss 0.0502  val_f1@0.5 0.9904  val_auc 0.9995  <- best
# epoch  4/15  loss 0.0335  val_f1@0.5 0.9911  val_auc 0.9994
# epoch  5/15  loss 0.0283  val_f1@0.5 0.9911  val_auc 0.9995
# epoch  6/15  loss 0.0319  val_f1@0.5 0.9930  val_auc 0.9994
# epoch  7/15  loss 0.0147  val_f1@0.5 0.9923  val_auc 0.9996  <- best
# epoch  8/15  loss 0.0136  val_f1@0.5 0.9923  val_auc 0.9996  <- best
# epoch  9/15  loss 0.0102  val_f1@0.5 0.9930  val_auc 0.9996
# epoch 10/15  loss 0.0088  val_f1@0.5 0.9943  val_auc 0.9996
# epoch 11/15  loss 0.0055  val_f1@0.5 0.9930  val_auc 0.9997  <- best
# epoch 12/15  loss 0.0047  val_f1@0.5 0.9936  val_auc 0.9997  <- best
# epoch 13/15  loss 0.0081  val_f1@0.5 0.9930  val_auc 0.9997
# epoch 14/15  loss 0.0053  val_f1@0.5 0.9936  val_auc 0.9996
# epoch 15/15  loss 0.0083  val_f1@0.5 0.9943  val_auc 0.9997
# khôi phục checkpoint epoch 12, val_auc 0.9997
#
# ==============================================================
# stretch_nhe  |  fold 0
# ==============================================================
# resnet18 | 224px | resize stretch | augment nhe | balancing weighted
# trọng số lớp: [1.908, 0.678]
# epoch  1/15  loss 0.1224  val_f1@0.5 0.9818  val_auc 0.9980  <- best
# epoch  2/15  loss 0.0803  val_f1@0.5 0.9889  val_auc 0.9983  <- best
# epoch  3/15  loss 0.0533  val_f1@0.5 0.9926  val_auc 0.9992  <- best
# epoch  4/15  loss 0.0427  val_f1@0.5 0.9944  val_auc 0.9992  <- best
# epoch  5/15  loss 0.0457  val_f1@0.5 0.9875  val_auc 0.9993  <- best
# epoch  6/15  loss 0.0274  val_f1@0.5 0.9919  val_auc 0.9993
# epoch  7/15  loss 0.0254  val_f1@0.5 0.9919  val_auc 0.9992
# epoch  8/15  loss 0.0262  val_f1@0.5 0.9853  val_auc 0.9993  <- best
# epoch  9/15  loss 0.0151  val_f1@0.5 0.9944  val_auc 0.9996  <- best
# epoch 10/15  loss 0.0102  val_f1@0.5 0.9944  val_auc 0.9996  <- best
# epoch 11/15  loss 0.0158  val_f1@0.5 0.9932  val_auc 0.9997  <- best
# epoch 12/15  loss 0.0067  val_f1@0.5 0.9944  val_auc 0.9996
# epoch 13/15  loss 0.0061  val_f1@0.5 0.9938  val_auc 0.9997
# epoch 14/15  loss 0.0047  val_f1@0.5 0.9926  val_auc 0.9997
# epoch 15/15  loss 0.0061  val_f1@0.5 0.9932  val_auc 0.9997
# khôi phục checkpoint epoch 11, val_auc 0.9997
#
# ==============================================================
# stretch_nhe  |  fold 1
# ==============================================================
# resnet18 | 224px | resize stretch | augment nhe | balancing weighted
# trọng số lớp: [1.959, 0.671]
# epoch  1/15  loss 0.1363  val_f1@0.5 0.9722  val_auc 0.9966  <- best
# epoch  2/15  loss 0.0707  val_f1@0.5 0.9925  val_auc 0.9990  <- best
# epoch  3/15  loss 0.0491  val_f1@0.5 0.9904  val_auc 0.9990  <- best
# epoch  4/15  loss 0.0493  val_f1@0.5 0.9778  val_auc 0.9985
# epoch  5/15  loss 0.0427  val_f1@0.5 0.9700  val_auc 0.9990
# epoch  6/15  loss 0.0239  val_f1@0.5 0.9897  val_auc 0.9991  <- best
# epoch  7/15  loss 0.0183  val_f1@0.5 0.9952  val_auc 0.9992  <- best
# epoch  8/15  loss 0.0231  val_f1@0.5 0.9926  val_auc 0.9993  <- best
# epoch  9/15  loss 0.0126  val_f1@0.5 0.9952  val_auc 0.9992
# epoch 10/15  loss 0.0080  val_f1@0.5 0.9925  val_auc 0.9992
# epoch 11/15  loss 0.0074  val_f1@0.5 0.9939  val_auc 0.9993  <- best
# epoch 12/15  loss 0.0060  val_f1@0.5 0.9945  val_auc 0.9994  <- best
# epoch 13/15  loss 0.0066  val_f1@0.5 0.9959  val_auc 0.9994
# epoch 14/15  loss 0.0066  val_f1@0.5 0.9946  val_auc 0.9993
# epoch 15/15  loss 0.0115  val_f1@0.5 0.9952  val_auc 0.9995  <- best
# khôi phục checkpoint epoch 15, val_auc 0.9995
#
# ==============================================================
# stretch_nhe  |  fold 2
# ==============================================================
# resnet18 | 224px | resize stretch | augment nhe | balancing weighted
# trọng số lớp: [1.941, 0.674]
# epoch  1/15  loss 0.1392  val_f1@0.5 0.9820  val_auc 0.9986  <- best
# epoch  2/15  loss 0.0835  val_f1@0.5 0.9905  val_auc 0.9989  <- best
# epoch  3/15  loss 0.0572  val_f1@0.5 0.9880  val_auc 0.9991  <- best
# epoch  4/15  loss 0.0459  val_f1@0.5 0.9846  val_auc 0.9990
# epoch  5/15  loss 0.0394  val_f1@0.5 0.9879  val_auc 0.9992  <- best
# epoch  6/15  loss 0.0316  val_f1@0.5 0.9911  val_auc 0.9991
# epoch  7/15  loss 0.0317  val_f1@0.5 0.9788  val_auc 0.9985
# epoch  8/15  loss 0.0352  val_f1@0.5 0.9911  val_auc 0.9988
# epoch  9/15  loss 0.0180  val_f1@0.5 0.9911  val_auc 0.9995  <- best
# epoch 10/15  loss 0.0101  val_f1@0.5 0.9885  val_auc 0.9994
# epoch 11/15  loss 0.0090  val_f1@0.5 0.9905  val_auc 0.9993
# epoch 12/15  loss 0.0058  val_f1@0.5 0.9924  val_auc 0.9994
# epoch 13/15  loss 0.0078  val_f1@0.5 0.9918  val_auc 0.9995
# epoch 14/15  loss 0.0067  val_f1@0.5 0.9924  val_auc 0.9995  <- best
# epoch 15/15  loss 0.0059  val_f1@0.5 0.9924  val_auc 0.9996  <- best
# khôi phục checkpoint epoch 15, val_auc 0.9996
#
# ==============================================================
# stretch_nhe  |  fold 3
# ==============================================================
# resnet18 | 224px | resize stretch | augment nhe | balancing weighted
# trọng số lớp: [1.956, 0.672]
# epoch  1/15  loss 0.1342  val_f1@0.5 0.9456  val_auc 0.9957  <- best
# epoch  2/15  loss 0.0781  val_f1@0.5 0.9705  val_auc 0.9960  <- best
# epoch  3/15  loss 0.0544  val_f1@0.5 0.9774  val_auc 0.9967  <- best
# epoch  4/15  loss 0.0411  val_f1@0.5 0.9862  val_auc 0.9974  <- best
# epoch  5/15  loss 0.0269  val_f1@0.5 0.9875  val_auc 0.9981  <- best
# epoch  6/15  loss 0.0354  val_f1@0.5 0.9704  val_auc 0.9980
# epoch  7/15  loss 0.0226  val_f1@0.5 0.9889  val_auc 0.9977
# epoch  8/15  loss 0.0263  val_f1@0.5 0.9875  val_auc 0.9984  <- best
# epoch  9/15  loss 0.0175  val_f1@0.5 0.9861  val_auc 0.9984  <- best
# epoch 10/15  loss 0.0254  val_f1@0.5 0.9921  val_auc 0.9990  <- best
# epoch 11/15  loss 0.0181  val_f1@0.5 0.9845  val_auc 0.9982
# epoch 12/15  loss 0.0160  val_f1@0.5 0.9834  val_auc 0.9974
# epoch 13/15  loss 0.0154  val_f1@0.5 0.9806  val_auc 0.9983
# epoch 14/15  loss 0.0129  val_f1@0.5 0.9896  val_auc 0.9984
# epoch 15/15  loss 0.0071  val_f1@0.5 0.9915  val_auc 0.9986
# dừng sớm ở epoch 15
# khôi phục checkpoint epoch 10, val_auc 0.9990
#
# ==============================================================
# stretch_nhe  |  fold 4
# ==============================================================
# resnet18 | 224px | resize stretch | augment nhe | balancing weighted
# trọng số lớp: [1.932, 0.675]
# epoch  1/15  loss 0.1466  val_f1@0.5 0.9705  val_auc 0.9991  <- best
# epoch  2/15  loss 0.0578  val_f1@0.5 0.9904  val_auc 0.9989
# epoch  3/15  loss 0.0569  val_f1@0.5 0.9936  val_auc 0.9995  <- best
# epoch  4/15  loss 0.0357  val_f1@0.5 0.9917  val_auc 0.9996  <- best
# epoch  5/15  loss 0.0434  val_f1@0.5 0.9904  val_auc 0.9988
# epoch  6/15  loss 0.0351  val_f1@0.5 0.9936  val_auc 0.9993
# epoch  7/15  loss 0.0195  val_f1@0.5 0.9904  val_auc 0.9995
# epoch  8/15  loss 0.0177  val_f1@0.5 0.9936  val_auc 0.9994
# epoch  9/15  loss 0.0129  val_f1@0.5 0.9942  val_auc 0.9994
# dừng sớm ở epoch 9
# khôi phục checkpoint epoch 4, val_auc 0.9996
#
# ==============================================================
# augment_manh  |  fold 0
# ==============================================================
# resnet18 | 224px | resize letterbox | augment manh | balancing weighted
# trọng số lớp: [1.908, 0.678]
# epoch  1/15  loss 0.1572  val_f1@0.5 0.9818  val_auc 0.9977  <- best
# epoch  2/15  loss 0.0993  val_f1@0.5 0.9869  val_auc 0.9980  <- best
# epoch  3/15  loss 0.0778  val_f1@0.5 0.9896  val_auc 0.9985  <- best
# epoch  4/15  loss 0.0614  val_f1@0.5 0.9926  val_auc 0.9989  <- best
# epoch  5/15  loss 0.0630  val_f1@0.5 0.9856  val_auc 0.9987
# epoch  6/15  loss 0.0539  val_f1@0.5 0.9862  val_auc 0.9988
# epoch  7/15  loss 0.0431  val_f1@0.5 0.9919  val_auc 0.9990  <- best
# epoch  8/15  loss 0.0355  val_f1@0.5 0.9919  val_auc 0.9991  <- best
# epoch  9/15  loss 0.0292  val_f1@0.5 0.9926  val_auc 0.9990
# epoch 10/15  loss 0.0236  val_f1@0.5 0.9938  val_auc 0.9993  <- best
# epoch 11/15  loss 0.0307  val_f1@0.5 0.9944  val_auc 0.9992
# epoch 12/15  loss 0.0234  val_f1@0.5 0.9944  val_auc 0.9993  <- best
# epoch 13/15  loss 0.0224  val_f1@0.5 0.9950  val_auc 0.9994  <- best
# epoch 14/15  loss 0.0218  val_f1@0.5 0.9932  val_auc 0.9993
# epoch 15/15  loss 0.0240  val_f1@0.5 0.9931  val_auc 0.9994
# khôi phục checkpoint epoch 13, val_auc 0.9994
#
# ==============================================================
# augment_manh  |  fold 1
# ==============================================================
# resnet18 | 224px | resize letterbox | augment manh | balancing weighted
# trọng số lớp: [1.959, 0.671]
# epoch  1/15  loss 0.1652  val_f1@0.5 0.9757  val_auc 0.9980  <- best
# epoch  2/15  loss 0.1006  val_f1@0.5 0.9828  val_auc 0.9991  <- best
# epoch  3/15  loss 0.0719  val_f1@0.5 0.9799  val_auc 0.9993  <- best
# epoch  4/15  loss 0.0680  val_f1@0.5 0.9932  val_auc 0.9994  <- best
# epoch  5/15  loss 0.0669  val_f1@0.5 0.9852  val_auc 0.9979
# epoch  6/15  loss 0.0593  val_f1@0.5 0.9800  val_auc 0.9987
# epoch  7/15  loss 0.0413  val_f1@0.5 0.9876  val_auc 0.9994
# epoch  8/15  loss 0.0475  val_f1@0.5 0.9939  val_auc 0.9993
# epoch  9/15  loss 0.0321  val_f1@0.5 0.9932  val_auc 0.9993
# dừng sớm ở epoch 9
# khôi phục checkpoint epoch 4, val_auc 0.9994
#
# ==============================================================
# augment_manh  |  fold 2
# ==============================================================
# resnet18 | 224px | resize letterbox | augment manh | balancing weighted
# trọng số lớp: [1.941, 0.674]
# epoch  1/15  loss 0.1781  val_f1@0.5 0.9768  val_auc 0.9982  <- best
# epoch  2/15  loss 0.1079  val_f1@0.5 0.9782  val_auc 0.9987  <- best
# epoch  3/15  loss 0.0816  val_f1@0.5 0.9887  val_auc 0.9986
# epoch  4/15  loss 0.0692  val_f1@0.5 0.9854  val_auc 0.9983
# epoch  5/15  loss 0.0626  val_f1@0.5 0.9860  val_auc 0.9990  <- best
# epoch  6/15  loss 0.0611  val_f1@0.5 0.9887  val_auc 0.9987
# epoch  7/15  loss 0.0472  val_f1@0.5 0.9898  val_auc 0.9991  <- best
# epoch  8/15  loss 0.0513  val_f1@0.5 0.9881  val_auc 0.9989
# epoch  9/15  loss 0.0261  val_f1@0.5 0.9885  val_auc 0.9994  <- best
# epoch 10/15  loss 0.0263  val_f1@0.5 0.9892  val_auc 0.9995  <- best
# epoch 11/15  loss 0.0276  val_f1@0.5 0.9879  val_auc 0.9994
# epoch 12/15  loss 0.0199  val_f1@0.5 0.9892  val_auc 0.9994
# epoch 13/15  loss 0.0185  val_f1@0.5 0.9893  val_auc 0.9993
# epoch 14/15  loss 0.0193  val_f1@0.5 0.9886  val_auc 0.9994
# epoch 15/15  loss 0.0157  val_f1@0.5 0.9886  val_auc 0.9994
# dừng sớm ở epoch 15
# khôi phục checkpoint epoch 10, val_auc 0.9995
#
# ==============================================================
# augment_manh  |  fold 3
# ==============================================================
# resnet18 | 224px | resize letterbox | augment manh | balancing weighted
# trọng số lớp: [1.956, 0.672]
# epoch  1/15  loss 0.1745  val_f1@0.5 0.9753  val_auc 0.9973  <- best
# epoch  2/15  loss 0.0905  val_f1@0.5 0.9817  val_auc 0.9967
# epoch  3/15  loss 0.0913  val_f1@0.5 0.9818  val_auc 0.9974  <- best
# epoch  4/15  loss 0.0721  val_f1@0.5 0.9764  val_auc 0.9982  <- best
# epoch  5/15  loss 0.0465  val_f1@0.5 0.9814  val_auc 0.9985  <- best
# epoch  6/15  loss 0.0576  val_f1@0.5 0.9895  val_auc 0.9993  <- best
# epoch  7/15  loss 0.0449  val_f1@0.5 0.9888  val_auc 0.9989
# epoch  8/15  loss 0.0528  val_f1@0.5 0.9875  val_auc 0.9987
# epoch  9/15  loss 0.0412  val_f1@0.5 0.9876  val_auc 0.9987
# epoch 10/15  loss 0.0339  val_f1@0.5 0.9915  val_auc 0.9993
# epoch 11/15  loss 0.0310  val_f1@0.5 0.9902  val_auc 0.9992
# dừng sớm ở epoch 11
# khôi phục checkpoint epoch 6, val_auc 0.9993
#
# ==============================================================
# augment_manh  |  fold 4
# ==============================================================
# resnet18 | 224px | resize letterbox | augment manh | balancing weighted
# trọng số lớp: [1.932, 0.675]
# epoch  1/15  loss 0.1737  val_f1@0.5 0.9826  val_auc 0.9985  <- best
# epoch  2/15  loss 0.0779  val_f1@0.5 0.9849  val_auc 0.9982
# epoch  3/15  loss 0.0771  val_f1@0.5 0.9871  val_auc 0.9982
# epoch  4/15  loss 0.0688  val_f1@0.5 0.9905  val_auc 0.9993  <- best
# epoch  5/15  loss 0.0676  val_f1@0.5 0.9831  val_auc 0.9977
# epoch  6/15  loss 0.0566  val_f1@0.5 0.9917  val_auc 0.9991
# epoch  7/15  loss 0.0560  val_f1@0.5 0.9904  val_auc 0.9995  <- best
# epoch  8/15  loss 0.0478  val_f1@0.5 0.9917  val_auc 0.9992
# epoch  9/15  loss 0.0441  val_f1@0.5 0.9892  val_auc 0.9985
# epoch 10/15  loss 0.0358  val_f1@0.5 0.9910  val_auc 0.9992
# epoch 11/15  loss 0.0299  val_f1@0.5 0.9923  val_auc 0.9994
# epoch 12/15  loss 0.0226  val_f1@0.5 0.9910  val_auc 0.9995  <- best
# epoch 13/15  loss 0.0282  val_f1@0.5 0.9917  val_auc 0.9995
# epoch 14/15  loss 0.0213  val_f1@0.5 0.9923  val_auc 0.9996  <- best
# epoch 15/15  loss 0.0202  val_f1@0.5 0.9924  val_auc 0.9996
# khôi phục checkpoint epoch 14, val_auc 0.9996
#
# ==============================================================
# stretch_manh  |  fold 0
# ==============================================================
# resnet18 | 224px | resize stretch | augment manh | balancing weighted
# trọng số lớp: [1.908, 0.678]
# epoch  1/15  loss 0.1671  val_f1@0.5 0.9547  val_auc 0.9958  <- best
# epoch  2/15  loss 0.1078  val_f1@0.5 0.9703  val_auc 0.9948
# epoch  3/15  loss 0.0857  val_f1@0.5 0.9832  val_auc 0.9970  <- best
# epoch  4/15  loss 0.0735  val_f1@0.5 0.9881  val_auc 0.9985  <- best
# epoch  5/15  loss 0.0678  val_f1@0.5 0.9594  val_auc 0.9983
# epoch  6/15  loss 0.0535  val_f1@0.5 0.9560  val_auc 0.9972
# epoch  7/15  loss 0.0534  val_f1@0.5 0.9786  val_auc 0.9966
# epoch  8/15  loss 0.0485  val_f1@0.5 0.9837  val_auc 0.9978
# epoch  9/15  loss 0.0368  val_f1@0.5 0.9862  val_auc 0.9982
# dừng sớm ở epoch 9
# khôi phục checkpoint epoch 4, val_auc 0.9985
#
# ==============================================================
# stretch_manh  |  fold 1
# ==============================================================
# resnet18 | 224px | resize stretch | augment manh | balancing weighted
# trọng số lớp: [1.959, 0.671]
# epoch  1/15  loss 0.1762  val_f1@0.5 0.9413  val_auc 0.9947  <- best
# epoch  2/15  loss 0.0984  val_f1@0.5 0.9599  val_auc 0.9973  <- best
# epoch  3/15  loss 0.0811  val_f1@0.5 0.9686  val_auc 0.9981  <- best
# epoch  4/15  loss 0.0677  val_f1@0.5 0.9441  val_auc 0.9980
# epoch  5/15  loss 0.0724  val_f1@0.5 0.9649  val_auc 0.9983  <- best
# epoch  6/15  loss 0.0672  val_f1@0.5 0.9517  val_auc 0.9976
# epoch  7/15  loss 0.0638  val_f1@0.5 0.9517  val_auc 0.9985  <- best
# epoch  8/15  loss 0.0563  val_f1@0.5 0.9750  val_auc 0.9979
# epoch  9/15  loss 0.0586  val_f1@0.5 0.9898  val_auc 0.9989  <- best
# epoch 10/15  loss 0.0427  val_f1@0.5 0.9793  val_auc 0.9983
# epoch 11/15  loss 0.0426  val_f1@0.5 0.9925  val_auc 0.9989
# epoch 12/15  loss 0.0408  val_f1@0.5 0.9757  val_auc 0.9990  <- best
# epoch 13/15  loss 0.0408  val_f1@0.5 0.9786  val_auc 0.9988
# epoch 14/15  loss 0.0394  val_f1@0.5 0.9911  val_auc 0.9990
# epoch 15/15  loss 0.0443  val_f1@0.5 0.9729  val_auc 0.9986
# khôi phục checkpoint epoch 12, val_auc 0.9990
#
# ==============================================================
# stretch_manh  |  fold 2
# ==============================================================
# resnet18 | 224px | resize stretch | augment manh | balancing weighted
# trọng số lớp: [1.941, 0.674]
# epoch  1/15  loss 0.1810  val_f1@0.5 0.9735  val_auc 0.9960  <- best
# epoch  2/15  loss 0.1079  val_f1@0.5 0.9580  val_auc 0.9966  <- best
# epoch  3/15  loss 0.0909  val_f1@0.5 0.9866  val_auc 0.9979  <- best
# epoch  4/15  loss 0.0893  val_f1@0.5 0.9834  val_auc 0.9978
# epoch  5/15  loss 0.0758  val_f1@0.5 0.9755  val_auc 0.9980  <- best
# epoch  6/15  loss 0.0587  val_f1@0.5 0.9801  val_auc 0.9987  <- best
# epoch  7/15  loss 0.0555  val_f1@0.5 0.9866  val_auc 0.9992  <- best
# epoch  8/15  loss 0.0601  val_f1@0.5 0.9898  val_auc 0.9990
# epoch  9/15  loss 0.0545  val_f1@0.5 0.9681  val_auc 0.9986
# epoch 10/15  loss 0.0478  val_f1@0.5 0.9551  val_auc 0.9990
# epoch 11/15  loss 0.0393  val_f1@0.5 0.9859  val_auc 0.9993  <- best
# epoch 12/15  loss 0.0326  val_f1@0.5 0.9885  val_auc 0.9995  <- best
# epoch 13/15  loss 0.0236  val_f1@0.5 0.9853  val_auc 0.9994
# epoch 14/15  loss 0.0240  val_f1@0.5 0.9866  val_auc 0.9992
# epoch 15/15  loss 0.0235  val_f1@0.5 0.9846  val_auc 0.9993
# khôi phục checkpoint epoch 12, val_auc 0.9995
#
# ==============================================================
# stretch_manh  |  fold 3
# ==============================================================
# resnet18 | 224px | resize stretch | augment manh | balancing weighted
# trọng số lớp: [1.956, 0.672]
# epoch  1/15  loss 0.1827  val_f1@0.5 0.9809  val_auc 0.9965  <- best
# epoch  2/15  loss 0.0897  val_f1@0.5 0.9656  val_auc 0.9957
# epoch  3/15  loss 0.0910  val_f1@0.5 0.9741  val_auc 0.9961
# epoch  4/15  loss 0.0737  val_f1@0.5 0.9822  val_auc 0.9979  <- best
# epoch  5/15  loss 0.0557  val_f1@0.5 0.9788  val_auc 0.9976
# epoch  6/15  loss 0.0639  val_f1@0.5 0.9691  val_auc 0.9970
# epoch  7/15  loss 0.0528  val_f1@0.5 0.9740  val_auc 0.9969
# epoch  8/15  loss 0.0403  val_f1@0.5 0.9774  val_auc 0.9975
# epoch  9/15  loss 0.0350  val_f1@0.5 0.9761  val_auc 0.9973
# dừng sớm ở epoch 9
# khôi phục checkpoint epoch 4, val_auc 0.9979
#
# ==============================================================
# stretch_manh  |  fold 4
# ==============================================================
# resnet18 | 224px | resize stretch | augment manh | balancing weighted
# trọng số lớp: [1.932, 0.675]
# epoch  1/15  loss 0.1763  val_f1@0.5 0.9610  val_auc 0.9962  <- best
# epoch  2/15  loss 0.0932  val_f1@0.5 0.9787  val_auc 0.9976  <- best
# epoch  3/15  loss 0.0958  val_f1@0.5 0.9705  val_auc 0.9988  <- best
# epoch  4/15  loss 0.0696  val_f1@0.5 0.9891  val_auc 0.9993  <- best
# epoch  5/15  loss 0.0712  val_f1@0.5 0.9905  val_auc 0.9992
# epoch  6/15  loss 0.0641  val_f1@0.5 0.9890  val_auc 0.9989
# epoch  7/15  loss 0.0548  val_f1@0.5 0.9636  val_auc 0.9985
# epoch  8/15  loss 0.0478  val_f1@0.5 0.9884  val_auc 0.9992
# epoch  9/15  loss 0.0344  val_f1@0.5 0.9818  val_auc 0.9992
# dừng sớm ở epoch 9
# khôi phục checkpoint epoch 4, val_auc 0.9993
#
# ==============================================================
# khong_weight  |  fold 0
# ==============================================================
# resnet18 | 224px | resize letterbox | augment nhe | balancing none
# trọng số lớp: không dùng
# epoch  1/15  loss 0.1087  val_f1@0.5 0.9875  val_auc 0.9977  <- best
# epoch  2/15  loss 0.0537  val_f1@0.5 0.9859  val_auc 0.9983  <- best
# epoch  3/15  loss 0.0459  val_f1@0.5 0.9932  val_auc 0.9988  <- best
# epoch  4/15  loss 0.0379  val_f1@0.5 0.9938  val_auc 0.9990  <- best
# epoch  5/15  loss 0.0294  val_f1@0.5 0.9869  val_auc 0.9989
# epoch  6/15  loss 0.0174  val_f1@0.5 0.9894  val_auc 0.9990  <- best
# epoch  7/15  loss 0.0202  val_f1@0.5 0.9913  val_auc 0.9992  <- best
# epoch  8/15  loss 0.0204  val_f1@0.5 0.9735  val_auc 0.9987
# epoch  9/15  loss 0.0164  val_f1@0.5 0.9932  val_auc 0.9993  <- best
# epoch 10/15  loss 0.0119  val_f1@0.5 0.9906  val_auc 0.9994  <- best
# epoch 11/15  loss 0.0175  val_f1@0.5 0.9932  val_auc 0.9993
# epoch 12/15  loss 0.0153  val_f1@0.5 0.9932  val_auc 0.9993
# epoch 13/15  loss 0.0237  val_f1@0.5 0.9883  val_auc 0.9986
# epoch 14/15  loss 0.0128  val_f1@0.5 0.9914  val_auc 0.9994
# epoch 15/15  loss 0.0102  val_f1@0.5 0.9956  val_auc 0.9994  <- best
# khôi phục checkpoint epoch 15, val_auc 0.9994
#
# ==============================================================
# khong_weight  |  fold 1
# ==============================================================
# resnet18 | 224px | resize letterbox | augment nhe | balancing none
# trọng số lớp: không dùng
# epoch  1/15  loss 0.1133  val_f1@0.5 0.9839  val_auc 0.9984  <- best
# epoch  2/15  loss 0.0595  val_f1@0.5 0.9918  val_auc 0.9993  <- best
# epoch  3/15  loss 0.0431  val_f1@0.5 0.9828  val_auc 0.9991
# epoch  4/15  loss 0.0358  val_f1@0.5 0.9918  val_auc 0.9993
# epoch  5/15  loss 0.0319  val_f1@0.5 0.9918  val_auc 0.9991
# epoch  6/15  loss 0.0136  val_f1@0.5 0.9952  val_auc 0.9996  <- best
# epoch  7/15  loss 0.0110  val_f1@0.5 0.9946  val_auc 0.9995
# epoch  8/15  loss 0.0143  val_f1@0.5 0.9959  val_auc 0.9995
# epoch  9/15  loss 0.0075  val_f1@0.5 0.9973  val_auc 0.9997  <- best
# epoch 10/15  loss 0.0047  val_f1@0.5 0.9959  val_auc 0.9997  <- best
# epoch 11/15  loss 0.0046  val_f1@0.5 0.9966  val_auc 0.9997  <- best
# epoch 12/15  loss 0.0040  val_f1@0.5 0.9952  val_auc 0.9997
# epoch 13/15  loss 0.0044  val_f1@0.5 0.9966  val_auc 0.9996
# epoch 14/15  loss 0.0073  val_f1@0.5 0.9980  val_auc 0.9997
# epoch 15/15  loss 0.0078  val_f1@0.5 0.9966  val_auc 0.9997
# khôi phục checkpoint epoch 11, val_auc 0.9997
#
# ==============================================================
# khong_weight  |  fold 2
# ==============================================================
# resnet18 | 224px | resize letterbox | augment nhe | balancing none
# trọng số lớp: không dùng
# epoch  1/15  loss 0.1453  val_f1@0.5 0.9834  val_auc 0.9974  <- best
# epoch  2/15  loss 0.0741  val_f1@0.5 0.9892  val_auc 0.9984  <- best
# epoch  3/15  loss 0.0457  val_f1@0.5 0.9847  val_auc 0.9986  <- best
# epoch  4/15  loss 0.0403  val_f1@0.5 0.9866  val_auc 0.9988  <- best
# epoch  5/15  loss 0.0374  val_f1@0.5 0.9880  val_auc 0.9986
# epoch  6/15  loss 0.0345  val_f1@0.5 0.9875  val_auc 0.9992  <- best
# epoch  7/15  loss 0.0239  val_f1@0.5 0.9886  val_auc 0.9990
# epoch  8/15  loss 0.0242  val_f1@0.5 0.9840  val_auc 0.9988
# epoch  9/15  loss 0.0174  val_f1@0.5 0.9866  val_auc 0.9989
# epoch 10/15  loss 0.0090  val_f1@0.5 0.9924  val_auc 0.9994  <- best
# epoch 11/15  loss 0.0061  val_f1@0.5 0.9918  val_auc 0.9994  <- best
# epoch 12/15  loss 0.0043  val_f1@0.5 0.9924  val_auc 0.9995  <- best
# epoch 13/15  loss 0.0038  val_f1@0.5 0.9924  val_auc 0.9995  <- best
# epoch 14/15  loss 0.0040  val_f1@0.5 0.9899  val_auc 0.9994
# epoch 15/15  loss 0.0038  val_f1@0.5 0.9931  val_auc 0.9995  <- best
# khôi phục checkpoint epoch 15, val_auc 0.9995
#
# ==============================================================
# khong_weight  |  fold 3
# ==============================================================
# resnet18 | 224px | resize letterbox | augment nhe | balancing none
# trọng số lớp: không dùng
# epoch  1/15  loss 0.1252  val_f1@0.5 0.9835  val_auc 0.9967  <- best
# epoch  2/15  loss 0.0623  val_f1@0.5 0.9806  val_auc 0.9973  <- best
# epoch  3/15  loss 0.0537  val_f1@0.5 0.9768  val_auc 0.9973
# epoch  4/15  loss 0.0375  val_f1@0.5 0.9888  val_auc 0.9983  <- best
# epoch  5/15  loss 0.0222  val_f1@0.5 0.9888  val_auc 0.9985  <- best
# epoch  6/15  loss 0.0209  val_f1@0.5 0.9861  val_auc 0.9990  <- best
# epoch  7/15  loss 0.0216  val_f1@0.5 0.9922  val_auc 0.9985
# epoch  8/15  loss 0.0261  val_f1@0.5 0.9862  val_auc 0.9981
# epoch  9/15  loss 0.0153  val_f1@0.5 0.9895  val_auc 0.9989
# epoch 10/15  loss 0.0078  val_f1@0.5 0.9915  val_auc 0.9992  <- best
# epoch 11/15  loss 0.0073  val_f1@0.5 0.9909  val_auc 0.9991
# epoch 12/15  loss 0.0086  val_f1@0.5 0.9922  val_auc 0.9992  <- best
# epoch 13/15  loss 0.0044  val_f1@0.5 0.9921  val_auc 0.9992
# epoch 14/15  loss 0.0041  val_f1@0.5 0.9928  val_auc 0.9991
# epoch 15/15  loss 0.0027  val_f1@0.5 0.9921  val_auc 0.9991
# khôi phục checkpoint epoch 12, val_auc 0.9992
#
# ==============================================================
# khong_weight  |  fold 4
# ==============================================================
# resnet18 | 224px | resize letterbox | augment nhe | balancing none
# trọng số lớp: không dùng
# epoch  1/15  loss 0.1202  val_f1@0.5 0.9879  val_auc 0.9986  <- best
# epoch  2/15  loss 0.0524  val_f1@0.5 0.9880  val_auc 0.9993  <- best
# epoch  3/15  loss 0.0464  val_f1@0.5 0.9924  val_auc 0.9991
# epoch  4/15  loss 0.0297  val_f1@0.5 0.9905  val_auc 0.9991
# epoch  5/15  loss 0.0284  val_f1@0.5 0.9855  val_auc 0.9985
# epoch  6/15  loss 0.0180  val_f1@0.5 0.9930  val_auc 0.9995  <- best
# epoch  7/15  loss 0.0168  val_f1@0.5 0.9923  val_auc 0.9996  <- best
# epoch  8/15  loss 0.0107  val_f1@0.5 0.9930  val_auc 0.9997  <- best
# epoch  9/15  loss 0.0084  val_f1@0.5 0.9923  val_auc 0.9995
# epoch 10/15  loss 0.0101  val_f1@0.5 0.9949  val_auc 0.9995
# epoch 11/15  loss 0.0053  val_f1@0.5 0.9936  val_auc 0.9997  <- best
# epoch 12/15  loss 0.0041  val_f1@0.5 0.9936  val_auc 0.9997
# epoch 13/15  loss 0.0073  val_f1@0.5 0.9942  val_auc 0.9997
# epoch 14/15  loss 0.0038  val_f1@0.5 0.9936  val_auc 0.9996
# epoch 15/15  loss 0.0043  val_f1@0.5 0.9936  val_auc 0.9996
# khôi phục checkpoint epoch 11, val_auc 0.9997
#
# ==============================================================
# anh_128  |  fold 0
# ==============================================================
# resnet18 | 128px | resize letterbox | augment nhe | balancing weighted
# trọng số lớp: [1.908, 0.678]
# epoch  1/15  loss 0.1506  val_f1@0.5 0.9837  val_auc 0.9975  <- best
# epoch  2/15  loss 0.0772  val_f1@0.5 0.9889  val_auc 0.9987  <- best
# epoch  3/15  loss 0.0611  val_f1@0.5 0.9932  val_auc 0.9991  <- best
# epoch  4/15  loss 0.0483  val_f1@0.5 0.9875  val_auc 0.9983
# epoch  5/15  loss 0.0501  val_f1@0.5 0.9925  val_auc 0.9991
# epoch  6/15  loss 0.0339  val_f1@0.5 0.9919  val_auc 0.9990
# epoch  7/15  loss 0.0249  val_f1@0.5 0.9926  val_auc 0.9992  <- best
# epoch  8/15  loss 0.0159  val_f1@0.5 0.9932  val_auc 0.9991
# epoch  9/15  loss 0.0138  val_f1@0.5 0.9932  val_auc 0.9994  <- best
# epoch 10/15  loss 0.0132  val_f1@0.5 0.9950  val_auc 0.9994  <- best
# epoch 11/15  loss 0.0141  val_f1@0.5 0.9944  val_auc 0.9993
# epoch 12/15  loss 0.0105  val_f1@0.5 0.9932  val_auc 0.9994
# epoch 13/15  loss 0.0077  val_f1@0.5 0.9932  val_auc 0.9995  <- best
# epoch 14/15  loss 0.0092  val_f1@0.5 0.9957  val_auc 0.9995  <- best
# epoch 15/15  loss 0.0054  val_f1@0.5 0.9957  val_auc 0.9994
# khôi phục checkpoint epoch 14, val_auc 0.9995
#
# ==============================================================
# anh_128  |  fold 1
# ==============================================================
# resnet18 | 128px | resize letterbox | augment nhe | balancing weighted
# trọng số lớp: [1.959, 0.671]
# epoch  1/15  loss 0.1661  val_f1@0.5 0.9857  val_auc 0.9980  <- best
# epoch  2/15  loss 0.0759  val_f1@0.5 0.9800  val_auc 0.9981  <- best
# epoch  3/15  loss 0.0614  val_f1@0.5 0.9678  val_auc 0.9988  <- best
# epoch  4/15  loss 0.0517  val_f1@0.5 0.9905  val_auc 0.9989  <- best
# epoch  5/15  loss 0.0434  val_f1@0.5 0.9905  val_auc 0.9991  <- best
# epoch  6/15  loss 0.0386  val_f1@0.5 0.9848  val_auc 0.9993  <- best
# epoch  7/15  loss 0.0391  val_f1@0.5 0.9925  val_auc 0.9994  <- best
# epoch  8/15  loss 0.0308  val_f1@0.5 0.9905  val_auc 0.9991
# epoch  9/15  loss 0.0261  val_f1@0.5 0.9939  val_auc 0.9996  <- best
# epoch 10/15  loss 0.0214  val_f1@0.5 0.9918  val_auc 0.9996
# epoch 11/15  loss 0.0219  val_f1@0.5 0.9932  val_auc 0.9991
# epoch 12/15  loss 0.0173  val_f1@0.5 0.9891  val_auc 0.9993
# epoch 13/15  loss 0.0134  val_f1@0.5 0.9966  val_auc 0.9992
# epoch 14/15  loss 0.0116  val_f1@0.5 0.9966  val_auc 0.9994
# dừng sớm ở epoch 14
# khôi phục checkpoint epoch 9, val_auc 0.9996
#
# ==============================================================
# anh_128  |  fold 2
# ==============================================================
# resnet18 | 128px | resize letterbox | augment nhe | balancing weighted
# trọng số lớp: [1.941, 0.674]
# epoch  1/15  loss 0.1729  val_f1@0.5 0.9848  val_auc 0.9959  <- best
# epoch  2/15  loss 0.0833  val_f1@0.5 0.9874  val_auc 0.9986  <- best
# epoch  3/15  loss 0.0567  val_f1@0.5 0.9775  val_auc 0.9987  <- best
# epoch  4/15  loss 0.0522  val_f1@0.5 0.9898  val_auc 0.9986
# epoch  5/15  loss 0.0473  val_f1@0.5 0.9840  val_auc 0.9991  <- best
# epoch  6/15  loss 0.0405  val_f1@0.5 0.9899  val_auc 0.9991  <- best
# epoch  7/15  loss 0.0402  val_f1@0.5 0.9918  val_auc 0.9988
# epoch  8/15  loss 0.0435  val_f1@0.5 0.9911  val_auc 0.9992  <- best
# epoch  9/15  loss 0.0444  val_f1@0.5 0.9867  val_auc 0.9986
# epoch 10/15  loss 0.0262  val_f1@0.5 0.9872  val_auc 0.9989
# epoch 11/15  loss 0.0216  val_f1@0.5 0.9906  val_auc 0.9980
# epoch 12/15  loss 0.0153  val_f1@0.5 0.9937  val_auc 0.9992
# epoch 13/15  loss 0.0082  val_f1@0.5 0.9911  val_auc 0.9993  <- best
# epoch 14/15  loss 0.0088  val_f1@0.5 0.9911  val_auc 0.9993
# epoch 15/15  loss 0.0053  val_f1@0.5 0.9924  val_auc 0.9993
# khôi phục checkpoint epoch 13, val_auc 0.9993
#
# ==============================================================
# anh_128  |  fold 3
# ==============================================================
# resnet18 | 128px | resize letterbox | augment nhe | balancing weighted
# trọng số lớp: [1.956, 0.672]
# epoch  1/15  loss 0.1580  val_f1@0.5 0.9680  val_auc 0.9930  <- best
# epoch  2/15  loss 0.0772  val_f1@0.5 0.9812  val_auc 0.9964  <- best
# epoch  3/15  loss 0.0655  val_f1@0.5 0.9849  val_auc 0.9965  <- best
# epoch  4/15  loss 0.0484  val_f1@0.5 0.9882  val_auc 0.9977  <- best
# epoch  5/15  loss 0.0346  val_f1@0.5 0.9848  val_auc 0.9977  <- best
# epoch  6/15  loss 0.0313  val_f1@0.5 0.9780  val_auc 0.9983  <- best
# epoch  7/15  loss 0.0356  val_f1@0.5 0.9855  val_auc 0.9979
# epoch  8/15  loss 0.0281  val_f1@0.5 0.9851  val_auc 0.9986  <- best
# epoch  9/15  loss 0.0210  val_f1@0.5 0.9862  val_auc 0.9979
# epoch 10/15  loss 0.0249  val_f1@0.5 0.9908  val_auc 0.9981
# epoch 11/15  loss 0.0183  val_f1@0.5 0.9844  val_auc 0.9978
# epoch 12/15  loss 0.0131  val_f1@0.5 0.9856  val_auc 0.9982
# epoch 13/15  loss 0.0081  val_f1@0.5 0.9861  val_auc 0.9980
# dừng sớm ở epoch 13
# khôi phục checkpoint epoch 8, val_auc 0.9986
#
# ==============================================================
# anh_128  |  fold 4
# ==============================================================
# resnet18 | 128px | resize letterbox | augment nhe | balancing weighted
# trọng số lớp: [1.932, 0.675]
# epoch  1/15  loss 0.1613  val_f1@0.5 0.9865  val_auc 0.9974  <- best
# epoch  2/15  loss 0.0676  val_f1@0.5 0.9799  val_auc 0.9981  <- best
# epoch  3/15  loss 0.0646  val_f1@0.5 0.9851  val_auc 0.9991  <- best
# epoch  4/15  loss 0.0407  val_f1@0.5 0.9880  val_auc 0.9987
# epoch  5/15  loss 0.0477  val_f1@0.5 0.9874  val_auc 0.9978
# epoch  6/15  loss 0.0399  val_f1@0.5 0.9911  val_auc 0.9983
# epoch  7/15  loss 0.0225  val_f1@0.5 0.9930  val_auc 0.9985
# epoch  8/15  loss 0.0146  val_f1@0.5 0.9936  val_auc 0.9986
# dừng sớm ở epoch 8
# khôi phục checkpoint epoch 3, val_auc 0.9991
#
# ==============================================================
# densenet121  |  fold 0
# ==============================================================
# densenet121 | 224px | resize letterbox | augment nhe | balancing weighted
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 142MB/s]
# trọng số lớp: [1.908, 0.678]
# epoch  1/15  loss 0.1384  val_f1@0.5 0.9851  val_auc 0.9968  <- best
# epoch  2/15  loss 0.0661  val_f1@0.5 0.9888  val_auc 0.9984  <- best
# epoch  3/15  loss 0.0452  val_f1@0.5 0.9914  val_auc 0.9987  <- best
# epoch  4/15  loss 0.0447  val_f1@0.5 0.9913  val_auc 0.9982
# epoch  5/15  loss 0.0274  val_f1@0.5 0.9881  val_auc 0.9984
# epoch  6/15  loss 0.0186  val_f1@0.5 0.9925  val_auc 0.9992  <- best
# epoch  7/15  loss 0.0253  val_f1@0.5 0.9889  val_auc 0.9985
# epoch  8/15  loss 0.0163  val_f1@0.5 0.9877  val_auc 0.9991
# epoch  9/15  loss 0.0115  val_f1@0.5 0.9931  val_auc 0.9995  <- best
# epoch 10/15  loss 0.0171  val_f1@0.5 0.9870  val_auc 0.9982
# epoch 11/15  loss 0.0216  val_f1@0.5 0.9931  val_auc 0.9995
# epoch 12/15  loss 0.0162  val_f1@0.5 0.9767  val_auc 0.9971
# epoch 13/15  loss 0.0092  val_f1@0.5 0.9925  val_auc 0.9995
# epoch 14/15  loss 0.0065  val_f1@0.5 0.9938  val_auc 0.9995  <- best
# epoch 15/15  loss 0.0047  val_f1@0.5 0.9938  val_auc 0.9995  <- best
# khôi phục checkpoint epoch 15, val_auc 0.9995
#
# ==============================================================
# densenet121  |  fold 1
# ==============================================================
# densenet121 | 224px | resize letterbox | augment nhe | balancing weighted
# trọng số lớp: [1.959, 0.671]
# epoch  1/15  loss 0.1404  val_f1@0.5 0.9898  val_auc 0.9985  <- best
# epoch  2/15  loss 0.0579  val_f1@0.5 0.9876  val_auc 0.9994  <- best
# epoch  3/15  loss 0.0469  val_f1@0.5 0.9835  val_auc 0.9994  <- best
# epoch  4/15  loss 0.0349  val_f1@0.5 0.9764  val_auc 0.9990
# epoch  5/15  loss 0.0327  val_f1@0.5 0.9946  val_auc 0.9988
# epoch  6/15  loss 0.0175  val_f1@0.5 0.9911  val_auc 0.9996  <- best
# epoch  7/15  loss 0.0087  val_f1@0.5 0.9904  val_auc 0.9996  <- best
# epoch  8/15  loss 0.0123  val_f1@0.5 0.9925  val_auc 0.9997  <- best
# epoch  9/15  loss 0.0069  val_f1@0.5 0.9939  val_auc 0.9998  <- best
# epoch 10/15  loss 0.0044  val_f1@0.5 0.9959  val_auc 0.9998
# epoch 11/15  loss 0.0044  val_f1@0.5 0.9932  val_auc 0.9998  <- best
# epoch 12/15  loss 0.0031  val_f1@0.5 0.9904  val_auc 0.9998
# epoch 13/15  loss 0.0031  val_f1@0.5 0.9939  val_auc 0.9998
# epoch 14/15  loss 0.0040  val_f1@0.5 0.9945  val_auc 0.9999  <- best
# epoch 15/15  loss 0.0111  val_f1@0.5 0.9925  val_auc 0.9998
# khôi phục checkpoint epoch 14, val_auc 0.9999
#
# ==============================================================
# densenet121  |  fold 2
# ==============================================================
# densenet121 | 224px | resize letterbox | augment nhe | balancing weighted
# trọng số lớp: [1.941, 0.674]
# epoch  1/15  loss 0.1345  val_f1@0.5 0.9840  val_auc 0.9989  <- best
# epoch  2/15  loss 0.0720  val_f1@0.5 0.9866  val_auc 0.9992  <- best
# epoch  3/15  loss 0.0397  val_f1@0.5 0.9892  val_auc 0.9993  <- best
# epoch  4/15  loss 0.0473  val_f1@0.5 0.9911  val_auc 0.9994  <- best
# epoch  5/15  loss 0.0356  val_f1@0.5 0.9930  val_auc 0.9994
# epoch  6/15  loss 0.0191  val_f1@0.5 0.9898  val_auc 0.9995  <- best
# epoch  7/15  loss 0.0253  val_f1@0.5 0.9854  val_auc 0.9990
# epoch  8/15  loss 0.0285  val_f1@0.5 0.9866  val_auc 0.9995  <- best
# epoch  9/15  loss 0.0326  val_f1@0.5 0.9930  val_auc 0.9996  <- best
# epoch 10/15  loss 0.0104  val_f1@0.5 0.9924  val_auc 0.9998  <- best
# epoch 11/15  loss 0.0141  val_f1@0.5 0.9885  val_auc 0.9995
# epoch 12/15  loss 0.0153  val_f1@0.5 0.9853  val_auc 0.9993
# epoch 13/15  loss 0.0149  val_f1@0.5 0.9865  val_auc 0.9995
# epoch 14/15  loss 0.0079  val_f1@0.5 0.9911  val_auc 0.9997
# epoch 15/15  loss 0.0037  val_f1@0.5 0.9917  val_auc 0.9996
# dừng sớm ở epoch 15
# khôi phục checkpoint epoch 10, val_auc 0.9998
#
# ==============================================================
# densenet121  |  fold 3
# ==============================================================
# densenet121 | 224px | resize letterbox | augment nhe | balancing weighted
# trọng số lớp: [1.956, 0.672]
# epoch  1/15  loss 0.1363  val_f1@0.5 0.9869  val_auc 0.9958  <- best
# epoch  2/15  loss 0.0630  val_f1@0.5 0.9830  val_auc 0.9965  <- best
# epoch  3/15  loss 0.0522  val_f1@0.5 0.9849  val_auc 0.9971  <- best
# epoch  4/15  loss 0.0320  val_f1@0.5 0.9870  val_auc 0.9958
# epoch  5/15  loss 0.0209  val_f1@0.5 0.9895  val_auc 0.9974  <- best
# epoch  6/15  loss 0.0224  val_f1@0.5 0.9881  val_auc 0.9966
# epoch  7/15  loss 0.0246  val_f1@0.5 0.9841  val_auc 0.9984  <- best
# epoch  8/15  loss 0.0200  val_f1@0.5 0.9902  val_auc 0.9957
# epoch  9/15  loss 0.0150  val_f1@0.5 0.9901  val_auc 0.9973
# epoch 10/15  loss 0.0123  val_f1@0.5 0.9902  val_auc 0.9979
# epoch 11/15  loss 0.0081  val_f1@0.5 0.9915  val_auc 0.9976
# epoch 12/15  loss 0.0042  val_f1@0.5 0.9902  val_auc 0.9968
# dừng sớm ở epoch 12
# khôi phục checkpoint epoch 7, val_auc 0.9984
#
# ==============================================================
# densenet121  |  fold 4
# ==============================================================
# densenet121 | 224px | resize letterbox | augment nhe | balancing weighted
# trọng số lớp: [1.932, 0.675]
# epoch  1/15  loss 0.1487  val_f1@0.5 0.9833  val_auc 0.9980  <- best
# epoch  2/15  loss 0.0541  val_f1@0.5 0.9840  val_auc 0.9979
# epoch  3/15  loss 0.0470  val_f1@0.5 0.9864  val_auc 0.9990  <- best
# epoch  4/15  loss 0.0366  val_f1@0.5 0.9936  val_auc 0.9996  <- best
# epoch  5/15  loss 0.0310  val_f1@0.5 0.9917  val_auc 0.9993
# epoch  6/15  loss 0.0227  val_f1@0.5 0.9890  val_auc 0.9996
# epoch  7/15  loss 0.0221  val_f1@0.5 0.9878  val_auc 0.9992
# epoch  8/15  loss 0.0116  val_f1@0.5 0.9923  val_auc 0.9997  <- best
# epoch  9/15  loss 0.0080  val_f1@0.5 0.9923  val_auc 0.9996
# epoch 10/15  loss 0.0062  val_f1@0.5 0.9930  val_auc 0.9996
# epoch 11/15  loss 0.0039  val_f1@0.5 0.9917  val_auc 0.9997  <- best
# epoch 12/15  loss 0.0031  val_f1@0.5 0.9923  val_auc 0.9997  <- best
# epoch 13/15  loss 0.0062  val_f1@0.5 0.9923  val_auc 0.9997
# epoch 14/15  loss 0.0029  val_f1@0.5 0.9923  val_auc 0.9997
# epoch 15/15  loss 0.0079  val_f1@0.5 0.9936  val_auc 0.9997
# khôi phục checkpoint epoch 12, val_auc 0.9997
#
# ==============================================================
# cnn_tu_dau  |  fold 0
# ==============================================================
# small_cnn | 150px | resize letterbox | augment manh | balancing none
# trọng số lớp: không dùng
# epoch  1/15  loss 0.3653  val_f1@0.5 0.9338  val_auc 0.9614  <- best
# epoch  2/15  loss 0.2709  val_f1@0.5 0.9381  val_auc 0.9669  <- best
# epoch  3/15  loss 0.2543  val_f1@0.5 0.9333  val_auc 0.9652
# epoch  4/15  loss 0.2427  val_f1@0.5 0.9434  val_auc 0.9690  <- best
# epoch  5/15  loss 0.2429  val_f1@0.5 0.9480  val_auc 0.9713  <- best
# epoch  6/15  loss 0.2240  val_f1@0.5 0.9489  val_auc 0.9725  <- best
# epoch  7/15  loss 0.2276  val_f1@0.5 0.9511  val_auc 0.9744  <- best
# epoch  8/15  loss 0.2191  val_f1@0.5 0.9409  val_auc 0.9754  <- best
# epoch  9/15  loss 0.1998  val_f1@0.5 0.9541  val_auc 0.9774  <- best
# epoch 10/15  loss 0.2055  val_f1@0.5 0.9312  val_auc 0.9789  <- best
# epoch 11/15  loss 0.2052  val_f1@0.5 0.9548  val_auc 0.9798  <- best
# epoch 12/15  loss 0.2033  val_f1@0.5 0.9486  val_auc 0.9796
# epoch 13/15  loss 0.1942  val_f1@0.5 0.9478  val_auc 0.9805  <- best
# epoch 14/15  loss 0.1833  val_f1@0.5 0.9630  val_auc 0.9846  <- best
# epoch 15/15  loss 0.1918  val_f1@0.5 0.9645  val_auc 0.9848  <- best
# khôi phục checkpoint epoch 15, val_auc 0.9848
#
# ==============================================================
# cnn_tu_dau  |  fold 1
# ==============================================================
# small_cnn | 150px | resize letterbox | augment manh | balancing none
# trọng số lớp: không dùng
# epoch  1/15  loss 0.3706  val_f1@0.5 0.9434  val_auc 0.9694  <- best
# epoch  2/15  loss 0.2659  val_f1@0.5 0.9231  val_auc 0.9713  <- best
# epoch  3/15  loss 0.2561  val_f1@0.5 0.9398  val_auc 0.9732  <- best
# epoch  4/15  loss 0.2255  val_f1@0.5 0.9471  val_auc 0.9743  <- best
# epoch  5/15  loss 0.2396  val_f1@0.5 0.9166  val_auc 0.9731
# epoch  6/15  loss 0.2174  val_f1@0.5 0.9287  val_auc 0.9767  <- best
# epoch  7/15  loss 0.2084  val_f1@0.5 0.9419  val_auc 0.9716
# epoch  8/15  loss 0.2133  val_f1@0.5 0.9530  val_auc 0.9801  <- best
# epoch  9/15  loss 0.2022  val_f1@0.5 0.9550  val_auc 0.9794
# epoch 10/15  loss 0.1955  val_f1@0.5 0.9501  val_auc 0.9779
# epoch 11/15  loss 0.1992  val_f1@0.5 0.9306  val_auc 0.9817  <- best
# epoch 12/15  loss 0.1932  val_f1@0.5 0.9527  val_auc 0.9790
# epoch 13/15  loss 0.1827  val_f1@0.5 0.9436  val_auc 0.9821  <- best
# epoch 14/15  loss 0.1818  val_f1@0.5 0.9347  val_auc 0.9815
# epoch 15/15  loss 0.1823  val_f1@0.5 0.9534  val_auc 0.9866  <- best
# khôi phục checkpoint epoch 15, val_auc 0.9866
#
# ==============================================================
# cnn_tu_dau  |  fold 2
# ==============================================================
# small_cnn | 150px | resize letterbox | augment manh | balancing none
# trọng số lớp: không dùng
# epoch  1/15  loss 0.3810  val_f1@0.5 0.9024  val_auc 0.9636  <- best
# epoch  2/15  loss 0.2807  val_f1@0.5 0.9461  val_auc 0.9649  <- best
# epoch  3/15  loss 0.2641  val_f1@0.5 0.9452  val_auc 0.9679  <- best
# epoch  4/15  loss 0.2434  val_f1@0.5 0.9522  val_auc 0.9724  <- best
# epoch  5/15  loss 0.2289  val_f1@0.5 0.9512  val_auc 0.9733  <- best
# epoch  6/15  loss 0.2190  val_f1@0.5 0.9466  val_auc 0.9722
# epoch  7/15  loss 0.2267  val_f1@0.5 0.9602  val_auc 0.9790  <- best
# epoch  8/15  loss 0.2255  val_f1@0.5 0.9620  val_auc 0.9820  <- best
# epoch  9/15  loss 0.2080  val_f1@0.5 0.9519  val_auc 0.9768
# epoch 10/15  loss 0.2046  val_f1@0.5 0.9587  val_auc 0.9833  <- best
# epoch 11/15  loss 0.2066  val_f1@0.5 0.9394  val_auc 0.9838  <- best
# epoch 12/15  loss 0.2050  val_f1@0.5 0.9550  val_auc 0.9844  <- best
# epoch 13/15  loss 0.1894  val_f1@0.5 0.9572  val_auc 0.9837
# epoch 14/15  loss 0.1956  val_f1@0.5 0.9652  val_auc 0.9850  <- best
# epoch 15/15  loss 0.1870  val_f1@0.5 0.9663  val_auc 0.9849
# khôi phục checkpoint epoch 14, val_auc 0.9850
#
# ==============================================================
# cnn_tu_dau  |  fold 3
# ==============================================================
# small_cnn | 150px | resize letterbox | augment manh | balancing none
# trọng số lớp: không dùng
# epoch  1/15  loss 0.3687  val_f1@0.5 0.9285  val_auc 0.9619  <- best
# epoch  2/15  loss 0.2669  val_f1@0.5 0.9312  val_auc 0.9665  <- best
# epoch  3/15  loss 0.2467  val_f1@0.5 0.9375  val_auc 0.9642
# epoch  4/15  loss 0.2383  val_f1@0.5 0.9410  val_auc 0.9660
# epoch  5/15  loss 0.2239  val_f1@0.5 0.9445  val_auc 0.9700  <- best
# epoch  6/15  loss 0.2220  val_f1@0.5 0.9379  val_auc 0.9676
# epoch  7/15  loss 0.2145  val_f1@0.5 0.9292  val_auc 0.9685
# epoch  8/15  loss 0.2159  val_f1@0.5 0.9447  val_auc 0.9732  <- best
# epoch  9/15  loss 0.1994  val_f1@0.5 0.9493  val_auc 0.9739  <- best
# epoch 10/15  loss 0.1944  val_f1@0.5 0.9495  val_auc 0.9776  <- best
# epoch 11/15  loss 0.1994  val_f1@0.5 0.9507  val_auc 0.9790  <- best
# epoch 12/15  loss 0.1933  val_f1@0.5 0.9520  val_auc 0.9781
# epoch 13/15  loss 0.1829  val_f1@0.5 0.9478  val_auc 0.9767
# epoch 14/15  loss 0.1720  val_f1@0.5 0.9265  val_auc 0.9750
# epoch 15/15  loss 0.1651  val_f1@0.5 0.9598  val_auc 0.9850  <- best
# khôi phục checkpoint epoch 15, val_auc 0.9850
#
# ==============================================================
# cnn_tu_dau  |  fold 4
# ==============================================================
# small_cnn | 150px | resize letterbox | augment manh | balancing none
# trọng số lớp: không dùng
# epoch  1/15  loss 0.3653  val_f1@0.5 0.8918  val_auc 0.9537  <- best
# epoch  2/15  loss 0.2823  val_f1@0.5 0.9383  val_auc 0.9709  <- best
# epoch  3/15  loss 0.2647  val_f1@0.5 0.9454  val_auc 0.9735  <- best
# epoch  4/15  loss 0.2415  val_f1@0.5 0.9451  val_auc 0.9719
# epoch  5/15  loss 0.2392  val_f1@0.5 0.9445  val_auc 0.9742  <- best
# epoch  6/15  loss 0.2151  val_f1@0.5 0.9518  val_auc 0.9744  <- best
# epoch  7/15  loss 0.2194  val_f1@0.5 0.9423  val_auc 0.9787  <- best
# epoch  8/15  loss 0.2196  val_f1@0.5 0.9504  val_auc 0.9754
# epoch  9/15  loss 0.2204  val_f1@0.5 0.9516  val_auc 0.9794  <- best
# epoch 10/15  loss 0.2067  val_f1@0.5 0.9585  val_auc 0.9792
# epoch 11/15  loss 0.2025  val_f1@0.5 0.9324  val_auc 0.9789
# epoch 12/15  loss 0.2043  val_f1@0.5 0.9513  val_auc 0.9811  <- best
# epoch 13/15  loss 0.2016  val_f1@0.5 0.9579  val_auc 0.9785
# epoch 14/15  loss 0.1817  val_f1@0.5 0.9612  val_auc 0.9850  <- best
# epoch 15/15  loss 0.1756  val_f1@0.5 0.9381  val_auc 0.9838
# khôi phục checkpoint epoch 14, val_auc 0.9850
#
# tổng thời gian: 79.1 phút (8 thí nghiệm × 5 fold)

# %%
display(pd.DataFrame([
    {"thí nghiệm": r["experiment"], "fold": r["fold"], "resize": r["resize"],
     "epoch tốt nhất": r["best_epoch"], "val F1": round(r["val"]["f1"], 4),
     "val AUC": round(r["val"]["auc"], 4),
     "checkpoint": Path(r["checkpoint"]).name}
    for r in RUNS]).set_index(["thí nghiệm", "fold"]))
# Out:
#                       resize  epoch tốt nhất  val F1  val AUC  \
# thí nghiệm   fold
# resnet18     0     letterbox              15  0.9932   0.9995
#              1     letterbox              12  0.9959   0.9999
#              2     letterbox               8  0.9917   0.9996
#              3     letterbox               9  0.9928   0.9994
#              4     letterbox              12  0.9936   0.9997
# stretch_nhe  0       stretch              11  0.9932   0.9997
#              1       stretch              15  0.9952   0.9995
#              2       stretch              15  0.9924   0.9996
#              3       stretch              10  0.9921   0.9990
#              4       stretch               4  0.9917   0.9996
# augment_manh 0     letterbox              13  0.9950   0.9994
#              1     letterbox               4  0.9932   0.9994
#              2     letterbox              10  0.9892   0.9995
#              3     letterbox               6  0.9895   0.9993
#              4     letterbox              14  0.9923   0.9996
# stretch_manh 0       stretch               4  0.9881   0.9985
#              1       stretch              12  0.9757   0.9990
#              2       stretch              12  0.9885   0.9995
#              3       stretch               4  0.9822   0.9979
#              4       stretch               4  0.9891   0.9993
# khong_weight 0     letterbox              15  0.9956   0.9994
#              1     letterbox              11  0.9966   0.9997
#              2     letterbox              15  0.9931   0.9995
#              3     letterbox              12  0.9922   0.9992
#              4     letterbox              11  0.9936   0.9997
# anh_128      0     letterbox              14  0.9957   0.9995
#              1     letterbox               9  0.9939   0.9996
#              2     letterbox              13  0.9911   0.9993
#              3     letterbox               8  0.9851   0.9986
#              4     letterbox               3  0.9851   0.9991
# densenet121  0     letterbox              15  0.9938   0.9995
#              1     letterbox              14  0.9945   0.9999
#              2     letterbox              10  0.9924   0.9998
#              3     letterbox               7  0.9841   0.9984
#              4     letterbox              12  0.9923   0.9997
# cnn_tu_dau   0     letterbox              15  0.9645   0.9848
#              1     letterbox              15  0.9534   0.9866
#              2     letterbox              14  0.9652   0.9850
#              3     letterbox              15  0.9598   0.9850
#              4     letterbox              14  0.9612   0.9850
#
#                                checkpoint
# thí nghiệm   fold
# resnet18     0         resnet18_fold0.pth
#              1         resnet18_fold1.pth
#              2         resnet18_fold2.pth
#              3         resnet18_fold3.pth
#              4         resnet18_fold4.pth
# stretch_nhe  0      stretch_nhe_fold0.pth
#              1      stretch_nhe_fold1.pth
#              2      stretch_nhe_fold2.pth
#              3      stretch_nhe_fold3.pth
#              4      stretch_nhe_fold4.pth
# augment_manh 0     augment_manh_fold0.pth
#              1     augment_manh_fold1.pth
#              2     augment_manh_fold2.pth
#              3     augment_manh_fold3.pth
#              4     augment_manh_fold4.pth
# stretch_manh 0     stretch_manh_fold0.pth
#              1     stretch_manh_fold1.pth
#              2     stretch_manh_fold2.pth
#              3     stretch_manh_fold3.pth
#              4     stretch_manh_fold4.pth
# khong_weight 0     khong_weight_fold0.pth
#              1     khong_weight_fold1.pth
#              2     khong_weight_fold2.pth
#              3     khong_weight_fold3.pth
#              4     khong_weight_fold4.pth
# anh_128      0          anh_128_fold0.pth
#              1          anh_128_fold1.pth
#              2          anh_128_fold2.pth
#              3          anh_128_fold3.pth
#              4          anh_128_fold4.pth
# densenet121  0      densenet121_fold0.pth
#              1      densenet121_fold1.pth
#              2      densenet121_fold2.pth
#              3      densenet121_fold3.pth
#              4      densenet121_fold4.pth
# cnn_tu_dau   0       cnn_tu_dau_fold0.pth
#              1       cnn_tu_dau_fold1.pth
#              2       cnn_tu_dau_fold2.pth
#              3       cnn_tu_dau_fold3.pth
#              4       cnn_tu_dau_fold4.pth

# %% [markdown]
# ## 3.2. So sánh các thí nghiệm
#
# Mọi so sánh cấu hình dưới đây chỉ dùng **out-of-fold validation**. Known benchmark test
# chưa được dự đoán tại thời điểm chọn cấu hình. Khi chỉ chạy một fold, đây là một
# validation holdout và notebook sẽ ghi rõ, không gọi là OOF.

# %%
DEV_LABEL = "OOF validation" if len(FOLDS) > 1 else "validation holdout"
OOF, rows = {}, []
for spec in EXPERIMENTS:
    runs = sorted((r for r in RUNS if r["experiment"] == spec["name"]),
                  key=lambda r: r["fold"])
    labels = np.concatenate([r["val_labels"] for r in runs])
    probs = np.concatenate([r["val_probs"] for r in runs])
    groups = np.concatenate([r["val_groups"] for r in runs])
    group_labels, group_probs = to_group_level(groups, labels, probs)

    image_threshold, image_tuned = tune_threshold(labels, probs)
    group_threshold, group_tuned = tune_threshold(group_labels, group_probs)
    entry = {
        "labels": labels, "probs": probs, "groups": groups,
        "group_labels": group_labels, "group_probs": group_probs,
        "image_threshold": image_threshold, "group_threshold": group_threshold,
        "image_default": metrics_at(labels, probs, 0.5),
        "image_tuned": image_tuned,
        "group_default": metrics_at(group_labels, group_probs, 0.5),
        "group_tuned": group_tuned,
    }
    OOF[spec["name"]] = entry
    for unit, default_key, tuned_key in (
            ("image", "image_default", "image_tuned"),
            ("filename_group", "group_default", "group_tuned")):
        for mode, key in (("default_0.5", default_key), ("validation_tuned", tuned_key)):
            block = entry[key]
            rows.append({"experiment": spec["name"],
                         "resize": spec.get("resize", RESIZE_MODE),
                         "aug": spec["aug"], "balancing": spec["balancing"],
                         "arch": spec["arch"], "size": spec["size"],
                         "unit": unit, "mode": mode,
                         "threshold": block["threshold"],
                         **{k: block[k] for k in METRIC_COLS}})

oof_results = pd.DataFrame(rows)
oof_results.to_csv(WORK_DIR / "results_oof_validation.csv", index=False)
print(f"{DEV_LABEL.upper()} — không dùng test để chọn cấu hình\n")
display(oof_results.set_index(["experiment", "unit", "mode"]).round(4))
# Out:
# OOF VALIDATION — không dùng test để chọn cấu hình
#                                                  resize   aug balancing  \
# experiment   unit           mode
# resnet18     image          default_0.5       letterbox   nhe  weighted
#                             validation_tuned  letterbox   nhe  weighted
#              filename_group default_0.5       letterbox   nhe  weighted
#                             validation_tuned  letterbox   nhe  weighted
# stretch_nhe  image          default_0.5         stretch   nhe  weighted
#                             validation_tuned    stretch   nhe  weighted
#              filename_group default_0.5         stretch   nhe  weighted
#                             validation_tuned    stretch   nhe  weighted
# augment_manh image          default_0.5       letterbox  manh  weighted
#                             validation_tuned  letterbox  manh  weighted
#              filename_group default_0.5       letterbox  manh  weighted
#                             validation_tuned  letterbox  manh  weighted
# stretch_manh image          default_0.5         stretch  manh  weighted
#                             validation_tuned    stretch  manh  weighted
#              filename_group default_0.5         stretch  manh  weighted
#                             validation_tuned    stretch  manh  weighted
# khong_weight image          default_0.5       letterbox   nhe      none
#                             validation_tuned  letterbox   nhe      none
#              filename_group default_0.5       letterbox   nhe      none
#                             validation_tuned  letterbox   nhe      none
# anh_128      image          default_0.5       letterbox   nhe  weighted
#                             validation_tuned  letterbox   nhe  weighted
#              filename_group default_0.5       letterbox   nhe  weighted
#                             validation_tuned  letterbox   nhe  weighted
# densenet121  image          default_0.5       letterbox   nhe  weighted
#                             validation_tuned  letterbox   nhe  weighted
#              filename_group default_0.5       letterbox   nhe  weighted
#                             validation_tuned  letterbox   nhe  weighted
# cnn_tu_dau   image          default_0.5       letterbox  manh      none
#                             validation_tuned  letterbox  manh      none
#              filename_group default_0.5       letterbox  manh      none
#                             validation_tuned  letterbox  manh      none
#
#                                                      arch  size  threshold  \
# experiment   unit           mode
# resnet18     image          default_0.5          resnet18   224     0.5000
#                             validation_tuned     resnet18   224     0.9500
#              filename_group default_0.5          resnet18   224     0.5000
#                             validation_tuned     resnet18   224     0.8280
# stretch_nhe  image          default_0.5          resnet18   224     0.5000
#                             validation_tuned     resnet18   224     0.8983
#              filename_group default_0.5          resnet18   224     0.5000
#                             validation_tuned     resnet18   224     0.7670
# augment_manh image          default_0.5          resnet18   224     0.5000
#                             validation_tuned     resnet18   224     0.8246
#              filename_group default_0.5          resnet18   224     0.5000
#                             validation_tuned     resnet18   224     0.7963
# stretch_manh image          default_0.5          resnet18   224     0.5000
#                             validation_tuned     resnet18   224     0.5719
#              filename_group default_0.5          resnet18   224     0.5000
#                             validation_tuned     resnet18   224     0.4089
# khong_weight image          default_0.5          resnet18   224     0.5000
#                             validation_tuned     resnet18   224     0.9291
#              filename_group default_0.5          resnet18   224     0.5000
#                             validation_tuned     resnet18   224     0.9066
# anh_128      image          default_0.5          resnet18   128     0.5000
#                             validation_tuned     resnet18   128     0.9275
#              filename_group default_0.5          resnet18   128     0.5000
#                             validation_tuned     resnet18   128     0.8356
# densenet121  image          default_0.5       densenet121   224     0.5000
#                             validation_tuned  densenet121   224     0.9028
#              filename_group default_0.5       densenet121   224     0.5000
#                             validation_tuned  densenet121   224     0.7019
# cnn_tu_dau   image          default_0.5         small_cnn   150     0.5000
#                             validation_tuned    small_cnn   150     0.4454
#              filename_group default_0.5         small_cnn   150     0.5000
#                             validation_tuned    small_cnn   150     0.4920
#
#                                               accuracy  precision  recall  \
# experiment   unit           mode
# resnet18     image          default_0.5         0.9903     0.9964  0.9905
#                             validation_tuned    0.9786     0.9995  0.9717
#              filename_group default_0.5         0.9869     0.9946  0.9857
#                             validation_tuned    0.9828     0.9983  0.9759
# stretch_nhe  image          default_0.5         0.9895     0.9971  0.9887
#                             validation_tuned    0.9813     1.0000  0.9748
#              filename_group default_0.5         0.9875     0.9959  0.9853
#                             validation_tuned    0.9823     0.9983  0.9751
# augment_manh image          default_0.5         0.9880     0.9956  0.9882
#                             validation_tuned    0.9822     0.9992  0.9768
#              filename_group default_0.5         0.9853     0.9930  0.9849
#                             validation_tuned    0.9790     0.9979  0.9706
# stretch_manh image          default_0.5         0.9778     0.9960  0.9740
#                             validation_tuned    0.9765     0.9968  0.9714
#              filename_group default_0.5         0.9744     0.9937  0.9678
#                             validation_tuned    0.9752     0.9921  0.9706
# khong_weight image          default_0.5         0.9914     0.9956  0.9928
#                             validation_tuned    0.9834     0.9995  0.9781
#              filename_group default_0.5         0.9883     0.9934  0.9890
#                             validation_tuned    0.9815     0.9987  0.9735
# anh_128      image          default_0.5         0.9855     0.9902  0.9902
#                             validation_tuned    0.9773     0.9971  0.9722
#              filename_group default_0.5         0.9820     0.9857  0.9873
#                             validation_tuned    0.9766     0.9921  0.9727
# densenet121  image          default_0.5         0.9874     0.9984  0.9845
#                             validation_tuned    0.9797     0.9997  0.9730
#              filename_group default_0.5         0.9836     0.9975  0.9780
#                             validation_tuned    0.9817     0.9983  0.9743
# cnn_tu_dau   image          default_0.5         0.9417     0.9545  0.9676
#                             validation_tuned    0.9392     0.9491  0.9701
#              filename_group default_0.5         0.9354     0.9365  0.9690
#                             validation_tuned    0.9349     0.9344  0.9706
#
#                                               specificity      f1  bal_acc  \
# experiment   unit           mode
# resnet18     image          default_0.5            0.9896  0.9934   0.9900
#                             validation_tuned       0.9985  0.9854   0.9851
#              filename_group default_0.5            0.9893  0.9902   0.9875
#                             validation_tuned       0.9967  0.9870   0.9863
# stretch_nhe  image          default_0.5            0.9918  0.9929   0.9903
#                             validation_tuned       1.0000  0.9872   0.9874
#              filename_group default_0.5            0.9918  0.9906   0.9886
#                             validation_tuned       0.9967  0.9866   0.9859
# augment_manh image          default_0.5            0.9874  0.9919   0.9878
#                             validation_tuned       0.9978  0.9879   0.9873
#              filename_group default_0.5            0.9861  0.9889   0.9855
#                             validation_tuned       0.9959  0.9841   0.9833
# stretch_manh image          default_0.5            0.9889  0.9849   0.9814
#                             validation_tuned       0.9911  0.9840   0.9813
#              filename_group default_0.5            0.9877  0.9806   0.9777
#                             validation_tuned       0.9844  0.9812   0.9775
# khong_weight image          default_0.5            0.9874  0.9942   0.9901
#                             validation_tuned       0.9985  0.9887   0.9883
#              filename_group default_0.5            0.9869  0.9912   0.9879
#                             validation_tuned       0.9975  0.9859   0.9855
# anh_128      image          default_0.5            0.9718  0.9902   0.9810
#                             validation_tuned       0.9918  0.9845   0.9820
#              filename_group default_0.5            0.9713  0.9865   0.9793
#                             validation_tuned       0.9844  0.9823   0.9785
# densenet121  image          default_0.5            0.9956  0.9914   0.9901
#                             validation_tuned       0.9993  0.9862   0.9861
#              filename_group default_0.5            0.9951  0.9876   0.9865
#                             validation_tuned       0.9967  0.9862   0.9855
# cnn_tu_dau   image          default_0.5            0.8673  0.9610   0.9174
#                             validation_tuned       0.8503  0.9595   0.9102
#              filename_group default_0.5            0.8679  0.9525   0.9185
#                             validation_tuned       0.8630  0.9522   0.9168
#
#                                                  auc  pr_auc
# experiment   unit           mode
# resnet18     image          default_0.5       0.9996  0.9999
#                             validation_tuned  0.9996  0.9999
#              filename_group default_0.5       0.9994  0.9997
#                             validation_tuned  0.9994  0.9997
# stretch_nhe  image          default_0.5       0.9994  0.9998
#                             validation_tuned  0.9994  0.9998
#              filename_group default_0.5       0.9991  0.9996
#                             validation_tuned  0.9991  0.9996
# augment_manh image          default_0.5       0.9994  0.9998
#                             validation_tuned  0.9994  0.9998
#              filename_group default_0.5       0.9990  0.9995
#                             validation_tuned  0.9990  0.9995
# stretch_manh image          default_0.5       0.9987  0.9995
#                             validation_tuned  0.9987  0.9995
#              filename_group default_0.5       0.9980  0.9990
#                             validation_tuned  0.9980  0.9990
# khong_weight image          default_0.5       0.9995  0.9998
#                             validation_tuned  0.9995  0.9998
#              filename_group default_0.5       0.9992  0.9996
#                             validation_tuned  0.9992  0.9996
# anh_128      image          default_0.5       0.9987  0.9995
#                             validation_tuned  0.9987  0.9995
#              filename_group default_0.5       0.9981  0.9991
#                             validation_tuned  0.9981  0.9991
# densenet121  image          default_0.5       0.9995  0.9998
#                             validation_tuned  0.9995  0.9998
#              filename_group default_0.5       0.9992  0.9996
#                             validation_tuned  0.9992  0.9996
# cnn_tu_dau   image          default_0.5       0.9828  0.9939
#                             validation_tuned  0.9828  0.9939
#              filename_group default_0.5       0.9803  0.9900
#                             validation_tuned  0.9803  0.9900

# %% [markdown]
# ## 3.3. Khóa cấu hình và hai điểm làm việc
#
# Cấu hình được chọn bằng group AUC trên OOF validation — chỉ số không phụ thuộc
# threshold. Sau khi khóa cấu hình, notebook tune riêng threshold mức ảnh và mức
# group. Mục tiêu mặc định: specificity cao nhất trong các điểm có sensitivity
# ít nhất 97%; có thể đổi sang balanced accuracy ở cell cấu hình.

# %%
BEST = max(OOF, key=lambda name: OOF[name]["group_default"]["auc"])
BEST_SPEC = next(spec for spec in EXPERIMENTS if spec["name"] == BEST)
IMAGE_THRESHOLD = OOF[BEST]["image_threshold"]
GROUP_THRESHOLD = OOF[BEST]["group_threshold"]

print(f"Cấu hình đã khóa bằng {DEV_LABEL} group AUC: {BEST}")
print(f"  group AUC          : {OOF[BEST]['group_default']['auc']:.4f}")
print(f"  threshold mức ảnh  : {IMAGE_THRESHOLD:.4f}")
print(f"  threshold mức group: {GROUP_THRESHOLD:.4f}")
print(f"  objective          : {THRESHOLD_OBJECTIVE}",
      f"(sensitivity >= {TARGET_SENSITIVITY:.0%})"
      if THRESHOLD_OBJECTIVE == "sensitivity" else "")
assert "test_probs" not in RUNS[0], "Test đã bị đọc trước khi khóa cấu hình"
# Một nguồn sự thật cho khâu tiền xử lý của cấu hình đã khóa. Mọi thứ phía sau
# (test, Grad-CAM, che vùng, mục 4.5) phải dùng đúng biến này.
BEST_RESIZE = BEST_SPEC.get("resize", RESIZE_MODE)
XAI_RESIZE = BEST_RESIZE
XAI_CACHE = IMAGE_CACHES[BEST_RESIZE]
print(f"  tiền xử lý         : {BEST_RESIZE}")
# Out:
# Cấu hình đã khóa bằng OOF validation group AUC: resnet18
#   group AUC          : 0.9994
#   threshold mức ảnh  : 0.9500
#   threshold mức group: 0.8280
#   objective          : sensitivity (sensitivity >= 97%)
#   tiền xử lý         : letterbox

# %% [markdown]
# ## 3.4. Known benchmark test — chỉ sau khi đã khóa cấu hình
#
# Chỉ cấu hình `BEST` vừa khóa được ensemble qua các fold và chạy trên test.
# Không có vòng lặp chọn lại kiến trúc, augmentation hay threshold sau khi xem bảng
# này. Vì test cũ đã từng được project xem ở notebook v2, kết quả mới vẫn cần một
# external/fresh holdout trước khi gọi là ước lượng cuối không thiên lệch.
#
# > **Về tên gọi.** Tập test này **không còn là holdout nguyên vẹn**. Nó đã được
# > xem ở lần chạy v2, và chính độ đặc hiệu thấp trên nó đã sinh ra giả thuyết về
# > tỉ lệ khung ở mục 1.4. Vì vậy notebook gọi nó là *known benchmark test* chứ
# > không phải *official holdout*, và con số dưới đây là ước lượng **lạc quan**
# > của khả năng khái quát hóa. Một ước lượng không thiên lệch cần tập bệnh nhân
# > mới, từ nguồn khác.

# %%
def show_confusion(title, matrix):
    (tn, fp), (fn, tp) = matrix
    sensitivity, specificity = tp / max(tp + fn, 1), tn / max(tn + fp, 1)
    precision = tp / max(tp + fp, 1)
    print(f"\n{title}  (n={tn + fp + fn + tp})")
    print(f"  TN {tn:>4}   FP {fp:>4}")
    print(f"  FN {fn:>4}   TP {tp:>4}")
    print(f"  bỏ sót {fn}/{fn + tp} ca viêm phổi  → độ nhạy {sensitivity:.1%}")
    print(f"  báo nhầm {fp}/{tn + fp} ca bình thường → độ đặc hiệu {specificity:.1%}")
    print(f"  precision {precision:.1%}  |  balanced accuracy "
          f"{(sensitivity + specificity) / 2:.1%}")


def load_model_from_run(run):
    model = build_model(run["arch"], pretrained=False)
    try:
        state = torch.load(run["checkpoint"], map_location="cpu", weights_only=True)
    except TypeError:  # PyTorch cũ
        state = torch.load(run["checkpoint"], map_location="cpu")
    model.load_state_dict(state)
    return model.eval()


best_runs = sorted((r for r in RUNS if r["experiment"] == BEST),
                   key=lambda r: r["fold"])
test_rows = FOLDS[0][FOLDS[0]["split"] == "test"].reset_index(drop=True)

# Ảnh test phải qua đúng khâu tiền xử lý mà mô hình đã được train. Dùng mặc
# định letterbox ở đây sẽ chấm một mô hình stretch trên phân phối đầu vào khác
# hẳn lúc train, và mọi chỉ số phía dưới đều sai mà không có dấu hiệu gì.
assert {run["resize"] for run in best_runs} == {BEST_RESIZE}, \
    "Các fold của BEST không cùng một chế độ resize."
test_loader = make_loader(FOLDS[0], "test", seed=SEED, mode=BEST_RESIZE)
print(f"Tiền xử lý dùng cho known benchmark test: {BEST_RESIZE}\n")

test_probabilities, test_labels = [], None
for run in best_runs:
    model = load_model_from_run(run)
    labels, probs = predict(model, test_loader, run["size"])
    if test_labels is None:
        test_labels = labels
    else:
        assert np.array_equal(test_labels, labels)
    test_probabilities.append(probs)
    del model
    gc.collect()
    if DEVICE.type == "cuda":
        torch.cuda.empty_cache()
    elif DEVICE.type == "mps":
        torch.mps.empty_cache()

test_probs = np.mean(test_probabilities, axis=0)
assert np.array_equal(test_labels, test_rows["class_id"].to_numpy())
test_groups = test_rows["group_id"].to_numpy()
group_labels, group_probs = to_group_level(test_groups, test_labels, test_probs)

FINAL = {
    "image_default": metrics_at(test_labels, test_probs, 0.5),
    "image_tuned": metrics_at(test_labels, test_probs, IMAGE_THRESHOLD),
    "group_default": metrics_at(group_labels, group_probs, 0.5),
    "group_tuned": metrics_at(group_labels, group_probs, GROUP_THRESHOLD),
    "test_labels": test_labels, "test_probs": test_probs,
    "group_labels": group_labels, "group_probs": group_probs,
}

final_rows = []
for unit, default_key, tuned_key in (
        ("image", "image_default", "image_tuned"),
        ("filename_group", "group_default", "group_tuned")):
    for mode, key in (("default_0.5", default_key), ("validation_tuned", tuned_key)):
        block = FINAL[key]
        final_rows.append({"experiment": BEST,
                           "arch": BEST_SPEC["arch"],
                           "resize": BEST_RESIZE,
                           "aug": BEST_SPEC["aug"],
                           "balancing": BEST_SPEC["balancing"],
                           "evaluation": "known_benchmark_not_final",
                           "unit": unit, "mode": mode,
                           "threshold": block["threshold"],
                           **{k: block[k] for k in METRIC_COLS},
                           "confusion_matrix": json.dumps(block["confusion_matrix"])})
final_results = pd.DataFrame(final_rows)
final_results.to_csv(WORK_DIR / "results_known_benchmark_test.csv", index=False)
test_rows.assign(p_pneumonia=test_probs,
                 pred=(test_probs >= IMAGE_THRESHOLD).astype(int),
                 experiment=BEST, resize=BEST_RESIZE).to_csv(
                     WORK_DIR / "predictions_known_benchmark_test_images.csv", index=False)

best_group_predictions = (pd.DataFrame({
    "group_id": test_groups, "label": test_labels, "p_pneumonia": test_probs,
}).groupby("group_id", as_index=False)
  .agg(label=("label", "first"), p_pneumonia=("p_pneumonia", "mean")))
best_group_predictions["pred"] = (
    best_group_predictions["p_pneumonia"] >= GROUP_THRESHOLD).astype(int)
best_group_predictions["experiment"] = BEST
best_group_predictions["resize"] = BEST_RESIZE
best_group_predictions.to_csv(
    WORK_DIR / "predictions_known_benchmark_test_groups.csv", index=False)

print(f"KNOWN BENCHMARK TEST — cấu hình đã khóa: {BEST}\n")
display(final_results.set_index(["unit", "mode"]).round(4))
show_confusion(f"{BEST} — TEST image @ {IMAGE_THRESHOLD:.3f}",
               FINAL["image_tuned"]["confusion_matrix"])
show_confusion(f"{BEST} — TEST filename-group @ {GROUP_THRESHOLD:.3f}",
               FINAL["group_tuned"]["confusion_matrix"])

# Loader BEST không còn dùng; giải phóng persistent workers trước mục 3.5.
del test_loader
gc.collect()

# XAI được thực hiện trên MỘT model thành viên đại diện, không phải ensemble.
# Việc load model được hoãn tới phần 4 để không giữ thêm model trên GPU trong
# lúc mục 3.5 chấm bốn ô 2×2.
XAI_RUN = best_runs[0]
XAI_SIZE = XAI_RUN["size"]
# Out:
# Tiền xử lý dùng cho known benchmark test: letterbox
#
# KNOWN BENCHMARK TEST — cấu hình đã khóa: resnet18
#                                 experiment      arch     resize  aug  \
# unit           mode
# image          default_0.5        resnet18  resnet18  letterbox  nhe
#                validation_tuned   resnet18  resnet18  letterbox  nhe
# filename_group default_0.5        resnet18  resnet18  letterbox  nhe
#                validation_tuned   resnet18  resnet18  letterbox  nhe
#
#                                 balancing                 evaluation  \
# unit           mode
# image          default_0.5       weighted  known_benchmark_not_final
#                validation_tuned  weighted  known_benchmark_not_final
# filename_group default_0.5       weighted  known_benchmark_not_final
#                validation_tuned  weighted  known_benchmark_not_final
#
#                                  threshold  accuracy  precision  recall  \
# unit           mode
# image          default_0.5           0.500    0.8269     0.7843  0.9974
#                validation_tuned      0.950    0.8862     0.8552  0.9846
# filename_group default_0.5           0.500    0.7570     0.6623  0.9951
#                validation_tuned      0.828    0.8248     0.7319  0.9951
#
#                                  specificity      f1  bal_acc     auc  pr_auc  \
# unit           mode
# image          default_0.5            0.5427  0.8781   0.7701  0.9537  0.9600
#                validation_tuned       0.7222  0.9154   0.8534  0.9537  0.9600
# filename_group default_0.5            0.5422  0.7953   0.7686  0.9489  0.9277
#                validation_tuned       0.6711  0.8434   0.8331  0.9489  0.9277
#
#                                        confusion_matrix
# unit           mode
# image          default_0.5       [[127, 107], [1, 389]]
#                validation_tuned   [[169, 65], [6, 384]]
# filename_group default_0.5       [[122, 103], [1, 202]]
#                validation_tuned   [[151, 74], [1, 202]]
# resnet18 — TEST image @ 0.950  (n=624)
#   TN  169   FP   65
#   FN    6   TP  384
#   bỏ sót 6/390 ca viêm phổi  → độ nhạy 98.5%
#   báo nhầm 65/234 ca bình thường → độ đặc hiệu 72.2%
#   precision 85.5%  |  balanced accuracy 85.3%
#
# resnet18 — TEST filename-group @ 0.828  (n=428)
#   TN  151   FP   74
#   FN    1   TP  202
#   bỏ sót 1/203 ca viêm phổi  → độ nhạy 99.5%
#   báo nhầm 74/225 ca bình thường → độ đặc hiệu 67.1%
#   precision 73.2%  |  balanced accuracy 83.3%

# %% [markdown]
# ## 3.5. Đối chứng 2×2: cách resize có đổi lỗi báo nhầm không?
#
# Mục 3.4 chỉ chấm cấu hình đã khóa. Nhưng câu hỏi của phần này — *ép ảnh về
# vuông có làm mô hình bám vào tỉ lệ khung không* — cần chỉ số test của **cả bốn**
# ô, vì so sánh chỉ có nghĩa khi đặt cạnh nhau.
#
# Đây **không phải** chọn mô hình. Bốn tên đã đăng ký trong `FACTORIAL_NAMES`
# trước khi chạy, ngưỡng lấy nguyên từ OOF của từng ô, không tinh chỉnh lại trên
# test, và `BEST` ở mục 3.3 vẫn được chọn hoàn toàn bằng OOF.
#
# Cột đáng đọc nhất không phải test AUC mà là **khoảng cách OOF→test**. Một đặc
# trưng tắt chạy tốt trong cross-validation rồi hụt khi đổi phân phối sẽ lộ ra ở
# đó chứ không lộ ở AUC tuyệt đối.
#
# Cần nói rõ: **cả hai cách resize đều mã hóa tỉ lệ khung**, chỉ là mã hóa khác
# nhau. Letterbox để lại độ dày viền đệm; stretch để lại mức kéo giãn trong chính
# giải phẫu. Nên đây là so sánh *hai cách biểu diễn*, không phải *có confound* so
# với *không confound*.

# %%
# Loader tái dùng theo từng chế độ resize; dựng lại mỗi ô sẽ tốn vô ích.
TEST_LOADERS = {}


def test_loader_for(mode):
    if mode not in TEST_LOADERS:
        TEST_LOADERS[mode] = make_loader(FOLDS[0], "test", seed=SEED, mode=mode)
    return TEST_LOADERS[mode]


def ensemble_test_probs(name):
    """Xác suất trung bình các fold của một thí nghiệm, trên known benchmark."""
    # Cấu hình BEST đã được chấm ở 3.4; tái dùng prediction để tránh inference lặp.
    if name == BEST:
        return FINAL["test_labels"].copy(), FINAL["test_probs"].copy()

    runs = sorted((r for r in RUNS if r["experiment"] == name),
                  key=lambda r: r["fold"])
    if not runs:
        raise KeyError(f"Không có checkpoint cho thí nghiệm {name!r}")
    modes = {r["resize"] for r in runs}
    assert len(modes) == 1, f"{name}: các fold không cùng chế độ resize"
    loader = test_loader_for(modes.pop())

    stack, seen_labels = [], None
    for run in runs:
        model = load_model_from_run(run)
        labels, probs = predict(model, loader, run["size"])
        if seen_labels is None:
            seen_labels = labels
        else:
            assert np.array_equal(seen_labels, labels)
        stack.append(probs)
        del model
        gc.collect()
        if DEVICE.type == "cuda":
            torch.cuda.empty_cache()
        elif DEVICE.type == "mps":
            torch.mps.empty_cache()
    assert np.array_equal(seen_labels, test_rows["class_id"].to_numpy())
    return seen_labels, np.mean(stack, axis=0)


def unpack_cm(matrix):
    (tn, fp), (fn, tp) = matrix
    return int(tn), int(fp), int(fn), int(tp)


factorial_rows, FACTORIAL_TEST = [], {}
available = [n for n in FACTORIAL_NAMES if n in OOF]
for name in available:
    spec = next(s for s in EXPERIMENTS if s["name"] == name)
    labels, probs = ensemble_test_probs(name)
    groups = test_rows["group_id"].to_numpy()
    g_labels, g_probs = to_group_level(groups, labels, probs)
    FACTORIAL_TEST[name] = {"labels": labels, "probs": probs,
                            "group_labels": g_labels, "group_probs": g_probs}

    # Lưu prediction để audit lại mà không phải reload 20 checkpoint.
    image_pred = test_rows.assign(
        p_pneumonia=probs,
        pred=(probs >= OOF[name]["image_threshold"]).astype(int),
        experiment=name,
        resize=spec.get("resize", RESIZE_MODE),
    )
    image_pred.to_csv(
        WORK_DIR / f"predictions_known_benchmark_{name}_images.csv", index=False)

    group_pred = (pd.DataFrame({
        "group_id": groups, "label": labels, "p_pneumonia": probs,
    }).groupby("group_id", as_index=False)
      .agg(label=("label", "first"), p_pneumonia=("p_pneumonia", "mean")))
    group_pred["pred"] = (
        group_pred["p_pneumonia"] >= OOF[name]["group_threshold"]).astype(int)
    group_pred["experiment"] = name
    group_pred["resize"] = spec.get("resize", RESIZE_MODE)
    group_pred.to_csv(
        WORK_DIR / f"predictions_known_benchmark_{name}_groups.csv", index=False)

    # Ngưỡng KHÓA từ OOF của chính ô đó. Không tinh chỉnh lại trên benchmark.
    for unit, oof_key, thr, te_lab, te_prob in (
            ("image", "image_tuned", OOF[name]["image_threshold"], labels, probs),
            ("filename_group", "group_tuned", OOF[name]["group_threshold"],
             g_labels, g_probs)):
        oof_m = OOF[name][oof_key]
        test_m = metrics_at(te_lab, te_prob, thr)
        tn, fp, fn, tp = unpack_cm(test_m["confusion_matrix"])
        factorial_rows.append({
            "experiment": name,
            "resize": spec.get("resize", RESIZE_MODE),
            "aug": spec["aug"],
            "unit": unit,
            "threshold": thr,
            "oof_auc": oof_m["auc"],
            "test_auc": test_m["auc"],
            # Giữ cột gap để tương thích, đồng thời thêm tên có chiều rõ ràng.
            "auc_gap": test_m["auc"] - oof_m["auc"],
            "auc_test_minus_oof": test_m["auc"] - oof_m["auc"],
            "auc_drop_oof_minus_test": oof_m["auc"] - test_m["auc"],
            "oof_specificity": oof_m["specificity"],
            "test_specificity": test_m["specificity"],
            "specificity_gap": test_m["specificity"] - oof_m["specificity"],
            "specificity_test_minus_oof": test_m["specificity"] - oof_m["specificity"],
            "specificity_drop_oof_minus_test": oof_m["specificity"] - test_m["specificity"],
            "oof_recall": oof_m["recall"],
            "test_recall": test_m["recall"],
            "test_tn": tn, "test_fp": fp, "test_fn": fn, "test_tp": tp,
            "test_confusion_matrix": json.dumps(test_m["confusion_matrix"]),
        })

if not factorial_rows:
    raise RuntimeError(
        f"Không ô nào của FACTORIAL_NAMES={FACTORIAL_NAMES} có trong OOF "
        f"({sorted(OOF)}). Kiểm tra lại tên thí nghiệm.")

factorial = pd.DataFrame(factorial_rows)
factorial["evaluation"] = "exploratory_known_test"
factorial.to_csv(WORK_DIR / "results_factorial_resize.csv", index=False)

print("ĐỐI CHỨNG 2×2 trên known benchmark — thăm dò, KHÔNG dùng để chọn "
      "mô hình\nNgưỡng lấy từ OOF của từng ô, không tinh chỉnh lại trên benchmark.\n")
display(factorial.set_index(["experiment", "unit"]).drop(columns="evaluation")
        .round(4))

resize_modes = set(factorial["resize"])
if len(available) == 4 and len(resize_modes) == 2:
    group_factorial = factorial[factorial["unit"] == "filename_group"]
    grid = group_factorial.pivot(
        index="resize", columns="aug", values="test_specificity")
    print("\nĐộ đặc hiệu mức group trên benchmark, tại ngưỡng OOF:\n")
    display(grid.round(4))

    lb = group_factorial[group_factorial["resize"] == "letterbox"]
    st = group_factorial[group_factorial["resize"] == "stretch"]
    print("Mức giảm OOF→benchmark của độ đặc hiệu, trung bình theo augmentation:")
    print(f"  letterbox {lb['specificity_drop_oof_minus_test'].mean():+.4f}")
    print(f"  stretch   {st['specificity_drop_oof_minus_test'].mean():+.4f}")
    print("  Số dương lớn hơn = tụt nhiều hơn khi đổi phân phối.")

    # Hiệu ứng 2×2 mô tả; chưa phải kiểm định vì chỉ có một benchmark.
    if {"nhe", "manh"}.issubset(grid.columns):
        resize_effect_light = grid.loc["stretch", "nhe"] - grid.loc["letterbox", "nhe"]
        resize_effect_strong = grid.loc["stretch", "manh"] - grid.loc["letterbox", "manh"]
        aug_effect_letterbox = grid.loc["letterbox", "manh"] - grid.loc["letterbox", "nhe"]
        aug_effect_stretch = grid.loc["stretch", "manh"] - grid.loc["stretch", "nhe"]
        interaction = resize_effect_strong - resize_effect_light
        print("\nHiệu ứng mô tả trên test specificity mức group:")
        print(f"  stretch − letterbox | augment nhẹ : {resize_effect_light:+.4f}")
        print(f"  stretch − letterbox | augment mạnh: {resize_effect_strong:+.4f}")
        print(f"  augment mạnh − nhẹ  | letterbox    : {aug_effect_letterbox:+.4f}")
        print(f"  augment mạnh − nhẹ  | stretch      : {aug_effect_stretch:+.4f}")
        print(f"  interaction (difference-in-differences): {interaction:+.4f}")
else:
    print(f"\nCó {len(available)} ô, {len(resize_modes)} chế độ resize — "
          f"bảng đầy đủ cần bốn ô và cả hai chế độ. "
          f"{'Đây là smoke run.' if RUN_MODE == 'smoke' else ''}")


# Prediction đã được đưa vào FACTORIAL_TEST/CSV; giải phóng persistent workers.
TEST_LOADERS.clear()
gc.collect()
# Out:
# ĐỐI CHỨNG 2×2 trên known benchmark — thăm dò, KHÔNG dùng để chọn mô hình
# Ngưỡng lấy từ OOF của từng ô, không tinh chỉnh lại trên benchmark.
#                                 resize   aug  threshold  oof_auc  test_auc  \
# experiment   unit
# resnet18     image           letterbox   nhe     0.9500   0.9996    0.9537
#              filename_group  letterbox   nhe     0.8280   0.9994    0.9489
# stretch_nhe  image             stretch   nhe     0.8983   0.9994    0.9720
#              filename_group    stretch   nhe     0.7670   0.9991    0.9669
# augment_manh image           letterbox  manh     0.8246   0.9994    0.9642
#              filename_group  letterbox  manh     0.7963   0.9990    0.9561
# stretch_manh image             stretch  manh     0.5719   0.9987    0.9828
#              filename_group    stretch  manh     0.4089   0.9980    0.9779
#
#                              auc_gap  auc_test_minus_oof  \
# experiment   unit
# resnet18     image           -0.0459             -0.0459
#              filename_group  -0.0505             -0.0505
# stretch_nhe  image           -0.0274             -0.0274
#              filename_group  -0.0322             -0.0322
# augment_manh image           -0.0351             -0.0351
#              filename_group  -0.0430             -0.0430
# stretch_manh image           -0.0158             -0.0158
#              filename_group  -0.0201             -0.0201
#
#                              auc_drop_oof_minus_test  oof_specificity  \
# experiment   unit
# resnet18     image                            0.0459           0.9985
#              filename_group                   0.0505           0.9967
# stretch_nhe  image                            0.0274           1.0000
#              filename_group                   0.0322           0.9967
# augment_manh image                            0.0351           0.9978
#              filename_group                   0.0430           0.9959
# stretch_manh image                            0.0158           0.9911
#              filename_group                   0.0201           0.9844
#
#                              test_specificity  specificity_gap  \
# experiment   unit
# resnet18     image                     0.7222          -0.2763
#              filename_group            0.6711          -0.3256
# stretch_nhe  image                     0.8120          -0.1880
#              filename_group            0.7378          -0.2589
# augment_manh image                     0.6838          -0.3140
#              filename_group            0.6756          -0.3203
# stretch_manh image                     0.8248          -0.1663
#              filename_group            0.7689          -0.2155
#
#                              specificity_test_minus_oof  \
# experiment   unit
# resnet18     image                              -0.2763
#              filename_group                     -0.3256
# stretch_nhe  image                              -0.1880
#              filename_group                     -0.2589
# augment_manh image                              -0.3140
#              filename_group                     -0.3203
# stretch_manh image                              -0.1663
#              filename_group                     -0.2155
#
#                              specificity_drop_oof_minus_test  oof_recall  \
# experiment   unit
# resnet18     image                                    0.2763      0.9717
#              filename_group                           0.3256      0.9759
# stretch_nhe  image                                    0.1880      0.9748
#              filename_group                           0.2589      0.9751
# augment_manh image                                    0.3140      0.9768
#              filename_group                           0.3203      0.9706
# stretch_manh image                                    0.1663      0.9714
#              filename_group                           0.2155      0.9706
#
#                              test_recall  test_tn  test_fp  test_fn  test_tp  \
# experiment   unit
# resnet18     image                0.9846      169       65        6      384
#              filename_group       0.9951      151       74        1      202
# stretch_nhe  image                0.9846      190       44        6      384
#              filename_group       0.9951      166       59        1      202
# augment_manh image                0.9949      160       74        2      388
#              filename_group       0.9951      152       73        1      202
# stretch_manh image                0.9949      193       41        2      388
#              filename_group       0.9951      173       52        1      202
#
#                              test_confusion_matrix
# experiment   unit
# resnet18     image           [[169, 65], [6, 384]]
#              filename_group  [[151, 74], [1, 202]]
# stretch_nhe  image           [[190, 44], [6, 384]]
#              filename_group  [[166, 59], [1, 202]]
# augment_manh image           [[160, 74], [2, 388]]
#              filename_group  [[152, 73], [1, 202]]
# stretch_manh image           [[193, 41], [2, 388]]
#              filename_group  [[173, 52], [1, 202]]
# Độ đặc hiệu mức group trên benchmark, tại ngưỡng OOF:
# aug          manh     nhe
# resize
# letterbox  0.6756  0.6711
# stretch    0.7689  0.7378
# Mức giảm OOF→benchmark của độ đặc hiệu, trung bình theo augmentation:
#   letterbox +0.3230
#   stretch   +0.2372
#   Số dương lớn hơn = tụt nhiều hơn khi đổi phân phối.
#
# Hiệu ứng mô tả trên test specificity mức group:
#   stretch − letterbox | augment nhẹ : +0.0667
#   stretch − letterbox | augment mạnh: +0.0933
#   augment mạnh − nhẹ  | letterbox    : +0.0044
#   augment mạnh − nhẹ  | stretch      : +0.0311
#   interaction (difference-in-differences): +0.0267
# 0

# %% [markdown]
# ---
#
# # 4. Diễn giải mô hình
#
# Grad-CAM là công cụ tạo giả thuyết, không chứng minh mô hình dùng đúng nhu mô
# phổi nếu chưa có lung mask. Phần này giải thích logit PNEUMONIA của một checkpoint
# thuộc cấu hình đã khóa và tách kết quả theo bốn ô confusion matrix.
#
# Ca đại diện được chọn từ prediction ensemble; heatmap sinh bởi checkpoint fold 0.

# %%
class GradCAM:
    """Grad-CAM bằng hook trên một lớp tích chập.

    Mỗi kênh đặc trưng được đánh trọng số bằng gradient trung bình của nó với
    logit mục tiêu, cộng lại rồi lấy phần dương.
    """

    def __init__(self, model, target_layer):
        self.model, self.activations, self.gradients = model, None, None
        self._handles = [
            target_layer.register_forward_hook(self._save_activations),
            target_layer.register_full_backward_hook(self._save_gradients)]

    def _save_activations(self, module, inputs, output):
        self.activations = output.detach()

    def _save_gradients(self, module, grad_input, grad_output):
        self.gradients = grad_output[0].detach()

    def __call__(self, images, class_indices=None):
        self.model.zero_grad(set_to_none=True)
        logits = self.model(images)          # cần gradient nên không dùng no_grad
        if class_indices is None:
            class_indices = logits.argmax(dim=1)
        indices = torch.arange(len(images), device=logits.device)
        logits[indices, class_indices].sum().backward()

        weights = self.gradients.mean(dim=(2, 3), keepdim=True)
        cams = F.relu((weights * self.activations).sum(dim=1, keepdim=True))
        cams = F.interpolate(cams, size=images.shape[-2:],
                             mode="bilinear", align_corners=False)[:, 0]
        cams = cams - cams.amin(dim=(1, 2), keepdim=True)
        cams = cams / (cams.amax(dim=(1, 2), keepdim=True) + 1e-8)
        return cams.cpu().numpy(), logits.detach()

    def close(self):
        for handle in self._handles:
            handle.remove()


def denormalize(tensor):
    mean = torch.tensor(IMAGENET_MEAN).view(3, 1, 1)
    std  = torch.tensor(IMAGENET_STD).view(3, 1, 1)
    return (tensor.cpu() * std + mean).clamp(0, 1).mean(0).numpy()


def model_input(row):
    """Đi qua đúng đường chuẩn hoá của model thành viên dùng cho XAI."""
    raw = torch.from_numpy(XAI_CACHE[int(row["cache_index"])]).unsqueeze(0)
    return to_model_input(raw, XAI_SIZE)


# Không trộn prediction của ensemble với explanation của một checkpoint.
# XAI ở đây là audit của model thành viên đại diện XAI_RUN.
xai_model = load_model_from_run(XAI_RUN)
XAI_THRESHOLD, _ = tune_threshold(
    XAI_RUN["val_labels"], XAI_RUN["val_probs"],
    objective=THRESHOLD_OBJECTIVE, target_sensitivity=TARGET_SENSITIVITY)
xai_loader = make_loader(
    FOLDS[0], "test", seed=SEED, mode=XAI_RUN["resize"])
XAI_LABELS, XAI_PROBS = predict(xai_model, xai_loader, XAI_SIZE)
assert np.array_equal(XAI_LABELS, test_rows["class_id"].to_numpy())
XAI_PREDS = (XAI_PROBS >= XAI_THRESHOLD).astype(int)
ensemble_preds = (FINAL["test_probs"] >= IMAGE_THRESHOLD).astype(int)
xai_agreement = float((XAI_PREDS == ensemble_preds).mean())

cam_engine = GradCAM(
    xai_model, target_layer_for(xai_model, XAI_RUN["arch"]))
print(f"XAI audit: {BEST} | fold {XAI_RUN['fold']} | resize {XAI_RUN['resize']}")
print(f"  threshold chọn trên validation fold: {XAI_THRESHOLD:.3f}")
print(f"  đồng thuận nhãn với ensemble BEST : {xai_agreement:.1%}")
print("  Heatmap phía dưới giải thích logit PNEUMONIA của model thành viên này,")
print("  không được diễn giải như explanation chính xác của ensemble.")
# Out:
# XAI audit: resnet18 | fold 0 | resize letterbox
#   threshold chọn trên validation fold: 0.992
#   đồng thuận nhãn với ensemble BEST : 96.8%
#   Heatmap phía dưới giải thích logit PNEUMONIA của model thành viên này,
#   không được diễn giải như explanation chính xác của ensemble.

# %% [markdown]
# ## 4.1. Chọn ca đại diện
#
# Lấy một ca cho mỗi ô confusion matrix của **model thành viên dùng cho XAI**, chọn ca tự tin nhất — ca tự tin mà
# vẫn sai là ca đáng mổ xẻ nhất. Lấy mẫu theo từng ô thay vì lấy đều theo chỉ số, vì
# danh sách ảnh sắp theo lớp nên lấy đều sẽ lệch hẳn về PNEUMONIA.

# %%
xai_rows = test_rows.assign(
    true=XAI_LABELS, p_pneumonia=XAI_PROBS, pred=XAI_PREDS)

CM_CELLS = {"TN — NORMAL đúng": (0, 0), "FP — báo động giả": (0, 1),
            "FN — BỎ SÓT viêm phổi": (1, 0), "TP — PNEUMONIA đúng": (1, 1)}

picks = {}
for name, (true_label, pred_label) in CM_CELLS.items():
    subset = xai_rows[(xai_rows["true"] == true_label)
                      & (xai_rows["pred"] == pred_label)]
    if subset.empty:
        print(f"{name:<24}: không có ca nào")
        continue
    confidence = subset["p_pneumonia"] if pred_label == 1 else 1 - subset["p_pneumonia"]
    picks[name] = subset.loc[confidence.idxmax()]
    print(f"{name:<24}: {len(subset):>3} ca  |  chọn {picks[name]['filename']}")
# Out:
# TN — NORMAL đúng        : 170 ca  |  chọn IM-0070-0001.jpeg
# FP — báo động giả       :  64 ca  |  chọn NORMAL2-IM-0246-0001.jpeg
# FN — BỎ SÓT viêm phổi   :   3 ca  |  chọn person154_bacteria_728.jpeg
# TP — PNEUMONIA đúng     : 387 ca  |  chọn person100_bacteria_478.jpeg

# %% [markdown]
# ## 4.2. Bản đồ nhiệt

# %%
figure, axes = plt.subplots(2, len(picks), figsize=(4.0 * len(picks), 8.6),
                            constrained_layout=True)
axes = np.atleast_2d(axes)

for column, (name, row) in enumerate(picks.items()):
    tensor = model_input(row)
    target = torch.ones(len(tensor), dtype=torch.long, device=DEVICE)
    cams, logits = cam_engine(tensor, target)
    probability = float(row["p_pneumonia"])
    grayscale = denormalize(tensor[0])

    axes[0, column].imshow(grayscale, cmap="gray")
    axes[0, column].set_title(f"{name}\nthật: {CLASSES[row['true']]}",
                              fontsize=11, pad=10)
    axes[1, column].imshow(grayscale, cmap="gray")
    axes[1, column].imshow(cams[0], cmap="jet", alpha=0.45)
    axes[1, column].text(
        0.03, 0.97, f"đoán: {CLASSES[row['pred']]} ({probability:.1%})",
        transform=axes[1, column].transAxes, va="top", ha="left",
        fontsize=10, fontweight="600", color="white",
        bbox=dict(boxstyle="round,pad=0.35", facecolor="#0b0b0b",
                  alpha=0.72, edgecolor="none"))
    for axis in axes[:, column]:
        axis.axis("off")

figure.suptitle(f"Grad-CAM cho logit PNEUMONIA — {BEST}, fold {XAI_RUN['fold']}", fontsize=13)
plt.show()

# %% [markdown]
# ## 4.3. Khối lượng nhiệt ở viền ảnh
#
# Quan sát vài tấm bằng mắt dễ dẫn tới kết luận cảm tính. Phép đo dưới đây tính tỉ
# lệ khối lượng nhiệt rơi vào **viền hình học 15%** trên mẫu stratify theo TN/FP/FN/TP.
# Viền hình học vẫn có thể chứa phổi ngoại vi; đây không phải phép đo lung-vs-artifact.
#
# Mốc diện tích chỉ giúp phát hiện heatmap tập trung bất thường ở biên. Muốn kết
# luận ngoài phổi cần segmentation mask thật.

# %%
def border_mass_fraction(cam, border=BORDER_FRAC):
    height, width = cam.shape
    margin_y, margin_x = int(height * border), int(width * border)
    interior = cam[margin_y:height - margin_y, margin_x:width - margin_x].sum()
    return float(1.0 - interior / (cam.sum() + 1e-8))


per_cell = 3 if RUN_MODE == "smoke" else 30
sample_parts = []
for (true_label, pred_label), subset in xai_rows.groupby(["true", "pred"]):
    sample_parts.append(subset.sample(n=min(per_cell, len(subset)),
                                      random_state=SEED + 10 * true_label + pred_label))
sample = pd.concat(sample_parts, ignore_index=True)
fractions = np.array([border_mass_fraction(cam_engine(model_input(row))[0][0])
                      for _, row in sample.iterrows()])
baseline = 1 - (1 - 2 * BORDER_FRAC) ** 2

print(f"n = {len(fractions)} ảnh benchmark từ XAI fold {XAI_RUN['fold']}  |  viền ngoài {BORDER_FRAC:.0%}")
print(f"  trung vị       : {np.median(fractions):.1%}")
print(f"  trung bình     : {fractions.mean():.1%}")
print(f"  cao nhất       : {fractions.max():.1%}")
print(f"  mốc ngẫu nhiên : {baseline:.1%}")
print(f"  số ca vượt mốc : {(fractions > baseline).sum()}/{len(fractions)}")
# Out:
# n = 93 ảnh benchmark từ XAI fold 0  |  viền ngoài 15%
#   trung vị       : 49.2%
#   trung bình     : 46.0%
#   cao nhất       : 71.8%
#   mốc ngẫu nhiên : 51.0%
#   số ca vượt mốc : 35/93

# %% [markdown]
# ## 4.4. Kiểm tra bằng cách che vùng
#
# Phép thử này che vùng trên ảnh `uint8` **trước normalization**, rồi đo thay đổi có
# dấu của logit PNEUMONIA. Nó tránh tạo màu ngoài phân phối như cách chèn một scalar
# sau ImageNet normalization.
#
# - Che **viền hình học 15%**
# - Che **hình chữ nhật trung tâm**
#
# Hai vùng không tương đương mask phổi/ngoài phổi. Kết quả chỉ dùng để tạo giả
# thuyết cho thí nghiệm có lung segmentation sau này.

# %%
@torch.no_grad()
def pneumonia_logit(tensor):
    return xai_model(tensor).float()[0, 1].item()


def occluded_input(row, region, border=BORDER_FRAC):
    """Che trên uint8 trước normalization; trả tensor model input."""
    out = torch.from_numpy(XAI_CACHE[int(row["cache_index"])]).clone()
    height, width = out.shape
    my, mx = int(height * border), int(width * border)
    fill = torch.median(out.float()).to(out.dtype)
    if region == "border":
        out[:my, :] = fill; out[height - my:, :] = fill
        out[:, :mx] = fill; out[:, width - mx:] = fill
    else:
        out[my:height - my, mx:width - mx] = fill
    return to_model_input(out.unsqueeze(0), XAI_SIZE)


rows = []
for _, row in sample.iterrows():
    tensor = model_input(row)
    base = pneumonia_logit(tensor)
    delta_border = pneumonia_logit(occluded_input(row, "border")) - base
    delta_center = pneumonia_logit(occluded_input(row, "center")) - base
    rows.append({"cell": f"{int(row['true'])}->{int(row['pred'])}",
                 "logit gốc": base,
                 "Δlogit che viền": delta_border,
                 "Δlogit che giữa": delta_center,
                 "|Δ| che viền": abs(delta_border),
                 "|Δ| che giữa": abs(delta_center)})
occlusion = pd.DataFrame(rows)

print(f"n = {len(occlusion)} ảnh benchmark của XAI fold {XAI_RUN['fold']}, stratify theo confusion cell\n")
display(occlusion.groupby("cell")[["Δlogit che viền", "Δlogit che giữa",
                                    "|Δ| che viền", "|Δ| che giữa"]].median().round(4))
print("\nDấu âm: che vùng làm giảm logit PNEUMONIA; dấu dương: làm tăng logit.")
print("Không diễn giải viền/giữa thành ngoài-phổi/trong-phổi khi chưa có lung mask.")

cam_engine.close()
del xai_model, xai_loader
gc.collect()
if DEVICE.type == "cuda":
    torch.cuda.empty_cache()
elif DEVICE.type == "mps":
    torch.mps.empty_cache()
# Out:
# n = 93 ảnh benchmark của XAI fold 0, stratify theo confusion cell
#       Δlogit che viền  Δlogit che giữa  |Δ| che viền  |Δ| che giữa
# cell
# 0->0           5.0595           5.6842        5.0595        5.6842
# 0->1           0.3387           2.2401        0.8900        2.2401
# 1->0           2.8285           3.4463        2.8285        3.4463
# 1->1          -0.1819           0.2289        0.9013        1.0917
# Dấu âm: che vùng làm giảm logit PNEUMONIA; dấu dương: làm tăng logit.
# Không diễn giải viền/giữa thành ngoài-phổi/trong-phổi khi chưa có lung mask.

# %% [markdown]
# ## 4.5. Ảnh bị báo nhầm có tỉ lệ khung nghiêng về đâu?
#
# Mục 1.4 cho thấy tỉ lệ khung *một mình* đã tách được hai lớp. Câu hỏi ở đây
# khác: trong số ảnh NORMAL mà mô hình gọi là PNEUMONIA, tỉ lệ khung của chúng
# nằm gần phân phối nào?
#
# Ba lưu ý về cách đọc kết quả:
#
# **Đơn vị suy luận là filename-derived group, không phải ảnh.** Một group có
# nhiều ảnh, nên kiểm định trên từng ảnh vi phạm giả định độc lập và cho `p` nhỏ
# hơn thực tế. Bảng mức ảnh của `BEST` vẫn in ra để mô tả, nhưng kiểm định chạy ở
# mức group.
#
# **Đây là quan hệ, không phải nhân quả.** FP và TN do chính mô hình và ngưỡng
# tạo ra. Tỉ lệ khung khác nhau giữa hai nhóm cho thấy *liên hệ*, chưa chứng minh
# mô hình dùng tỉ lệ khung để quyết định. Tỉ lệ khung còn có thể chỉ là proxy cho
# máy chụp, tư thế, quy trình crop hay độ phân giải nguồn.
#
# **Phần tương quan liên tục không phụ thuộc ngưỡng.** Kiểm định FP/TN đổi theo
# ngưỡng; Spearman giữa tỉ lệ khung và xác suất dự đoán, chạy trên *toàn bộ*
# NORMAL, thì không.
#
# Notebook báo chi tiết cho ensemble `BEST` và đồng thời lập bảng cho mọi ô
# factorial đã có prediction. Nhờ vậy có thể kiểm tra liệu thay resize/augmentation
# có làm giảm mối liên hệ geometry→score hay chỉ đổi confusion matrix.

# %%
from scipy.stats import mannwhitneyu, spearmanr


def cliffs_delta(a, b):
    """P(a>b) - P(a<b); tie đóng góp 0."""
    a = np.asarray(a, dtype=float)
    b = np.asarray(b, dtype=float)
    if len(a) == 0 or len(b) == 0:
        return np.nan
    pairwise = a[:, None] - b[None, :]
    return float((pairwise > 0).mean() - (pairwise < 0).mean())


def percentile_ci(values, alpha=0.05):
    values = np.asarray(values, dtype=float)
    values = values[np.isfinite(values)]
    if len(values) == 0:
        return np.nan, np.nan
    return tuple(np.percentile(values, [100 * alpha / 2, 100 * (1 - alpha / 2)]))


def bootstrap_geometry_effects(fp, tn, reps=BOOTSTRAP_REPS, seed=SEED):
    """KTC bootstrap ở đúng đơn vị group và đúng statistic được báo."""
    fp = np.asarray(fp, dtype=float)
    tn = np.asarray(tn, dtype=float)
    rng = np.random.default_rng(seed)
    median_shifts, deltas = [], []
    for _ in range(reps):
        fp_b = rng.choice(fp, len(fp), replace=True)
        tn_b = rng.choice(tn, len(tn), replace=True)
        median_shifts.append(float(np.median(fp_b) - np.median(tn_b)))
        deltas.append(cliffs_delta(fp_b, tn_b))
    return percentile_ci(median_shifts), percentile_ci(deltas)


def build_group_audit(labels, probs):
    image_audit = test_rows.assign(
        true=np.asarray(labels),
        p_pneumonia=np.asarray(probs),
        aspect=test_rows["path"].map(ASPECT),
    ).dropna(subset=["aspect"])

    group_label_counts = image_audit.groupby("group_id")["true"].nunique()
    if int(group_label_counts.max()) != 1:
        bad = group_label_counts[group_label_counts > 1].index.tolist()[:5]
        raise ValueError(f"Group benchmark chứa nhiều nhãn, ví dụ: {bad}")

    grouped = (image_audit.groupby("group_id", as_index=False)
               .agg(true=("true", "first"),
                    probability=("p_pneumonia", "mean"),
                    aspect=("aspect", "median")))
    return image_audit, grouped


def audit_aspect_association(name, resize, labels, probs, group_threshold,
                             image_threshold=None, detailed=False, seed=SEED):
    image_audit, grouped = build_group_audit(labels, probs)
    grouped["pred"] = (grouped["probability"] >= group_threshold).astype(int)

    normals = grouped[grouped["true"] == 0]
    fp = normals.loc[normals["pred"] == 1, "aspect"].to_numpy()
    tn = normals.loc[normals["pred"] == 0, "aspect"].to_numpy()
    pneu = grouped.loc[grouped["true"] == 1, "aspect"].to_numpy()

    row = {
        "experiment": name,
        "resize": resize,
        "unit": "filename_group",
        "group_threshold": float(group_threshold),
        "n_normal_groups": int(len(normals)),
        "n_fp": int(len(fp)),
        "n_tn": int(len(tn)),
        "n_pneumonia_groups": int(len(pneu)),
    }

    if detailed:
        threshold_for_images = IMAGE_THRESHOLD if image_threshold is None else image_threshold
        print(f"Cấu hình {name} (resize {resize})")
        print("MÔ TẢ, mức ảnh")
        image_pred = (image_audit["p_pneumonia"] >= threshold_for_images).astype(int)
        for label, mask in (
                ("NORMAL nhận đúng (TN)",
                 (image_audit["true"] == 0) & (image_pred == 0)),
                ("NORMAL báo nhầm (FP)",
                 (image_audit["true"] == 0) & (image_pred == 1)),
                ("PNEUMONIA thật", image_audit["true"] == 1)):
            values = image_audit.loc[mask, "aspect"]
            if len(values):
                print(f"  {label:<24} n={len(values):>3}  "
                      f"trung vị {values.median():.3f}  TB {values.mean():.3f}")
        print(f"\nKIỂM ĐỊNH, mức group (ngưỡng {group_threshold:.3f})")
        print(f"  TN n={len(tn)}  FP n={len(fp)}  PNEUMONIA n={len(pneu)}")

    if len(fp) >= 5 and len(tn) >= 5:
        u_stat, pvalue = mannwhitneyu(fp, tn, alternative="greater")
        delta = 2 * u_stat / (len(fp) * len(tn)) - 1
        # Kiểm tra công thức U và định nghĩa trực tiếp không lệch nhau.
        assert np.isclose(delta, cliffs_delta(fp, tn), atol=1e-12)

        median_shift = float(np.median(fp) - np.median(tn))
        mean_shift = float(np.mean(fp) - np.mean(tn))
        span = float(np.median(pneu) - np.median(tn)) if len(pneu) else np.nan
        median_ci, delta_ci = bootstrap_geometry_effects(
            fp, tn, reps=BOOTSTRAP_REPS, seed=seed)

        row.update({
            "median_shift": median_shift,
            "median_shift_ci_low": float(median_ci[0]),
            "median_shift_ci_high": float(median_ci[1]),
            "mean_shift": mean_shift,
            "cliffs_delta": float(delta),
            "cliffs_delta_ci_low": float(delta_ci[0]),
            "cliffs_delta_ci_high": float(delta_ci[1]),
            "mann_whitney_u": float(u_stat),
            "mann_whitney_p_one_sided": float(pvalue),
            "normalized_median_shift": (
                float(median_shift / span)
                if np.isfinite(span) and abs(span) > 1e-9 else np.nan),
        })

        if detailed:
            print(f"  lệch trung vị FP − TN     {median_shift:+.3f}  "
                  f"KTC95% [{median_ci[0]:+.3f}, {median_ci[1]:+.3f}]")
            print(f"  Cliff's delta             {delta:+.3f}  "
                  f"KTC95% [{delta_ci[0]:+.3f}, {delta_ci[1]:+.3f}]")
            if np.isfinite(row["normalized_median_shift"]):
                print(f"  dịch chuyển chuẩn hóa     "
                      f"{row['normalized_median_shift']:+.0%}  "
                      f"= (median FP−TN)/(median PNEUMONIA−TN)")
            print(f"  Mann–Whitney một phía     p = {pvalue:.4f}")
    elif detailed:
        print("  Quá ít group FP/TN để kiểm định.")

    if len(normals) >= 10 and normals["aspect"].nunique() > 1 \
            and normals["probability"].nunique() > 1:
        rho, p_rho = spearmanr(normals["aspect"], normals["probability"])
        if np.isfinite(rho):
            row.update({
                "spearman_rho_normal": float(rho),
                "spearman_p_two_sided": float(p_rho),
            })
            if detailed:
                print("\nTRÊN RIÊNG NORMAL, không dùng ngưỡng")
                print(f"  Spearman(tỉ lệ khung, xác suất PNEUMONIA) "
                      f"= {rho:+.3f}  p = {p_rho:.4f}")
    return row


def holm_adjust(frame, p_col, out_col):
    """Holm–Bonferroni trong một family kiểm định; giữ NaN khi không có p."""
    adjusted = pd.Series(np.nan, index=frame.index, dtype=float)
    valid = frame[p_col].dropna().sort_values()
    m = len(valid)
    if m:
        running = 0.0
        for rank, (idx, pvalue) in enumerate(valid.items()):
            candidate = (m - rank) * float(pvalue)
            running = max(running, candidate)
            adjusted.loc[idx] = min(1.0, running)
    frame[out_col] = adjusted
    return frame


# Chi tiết cho ensemble BEST.
best_audit_row = audit_aspect_association(
    BEST, BEST_RESIZE,
    FINAL["test_labels"], FINAL["test_probs"],
    GROUP_THRESHOLD, image_threshold=IMAGE_THRESHOLD,
    detailed=True, seed=SEED)

# Bảng so sánh mọi ô 2×2 đã được chấm. Không chạy lại inference.
audit_rows = []
for offset, name in enumerate(available):
    if name == BEST:
        # Tái dùng cùng bootstrap draw với phần in chi tiết để KTC không lệch nhau.
        audit_rows.append(best_audit_row)
        continue
    spec = next(s for s in EXPERIMENTS if s["name"] == name)
    pred = FACTORIAL_TEST[name]
    audit_rows.append(audit_aspect_association(
        name,
        spec.get("resize", RESIZE_MODE),
        pred["labels"], pred["probs"],
        OOF[name]["group_threshold"],
        image_threshold=OOF[name]["image_threshold"],
        detailed=False,
        seed=SEED + 1000 + offset,
    ))

# BEST có thể không thuộc 2×2; thêm vào bảng mà không nhân đôi.
if BEST not in {row["experiment"] for row in audit_rows}:
    audit_rows.append(best_audit_row)

aspect_audit_results = pd.DataFrame(audit_rows)
for p_col, out_col in (
        ("mann_whitney_p_one_sided", "mann_whitney_p_holm"),
        ("spearman_p_two_sided", "spearman_p_holm")):
    if p_col in aspect_audit_results:
        aspect_audit_results = holm_adjust(aspect_audit_results, p_col, out_col)

aspect_audit_results.to_csv(
    WORK_DIR / "results_aspect_error_audit.csv", index=False)

print("\nTỔNG HỢP LIÊN HỆ TỈ LỆ KHUNG → LỖI/SCORE, mức group")
columns = [c for c in [
    "experiment", "resize", "n_fp", "n_tn",
    "median_shift", "median_shift_ci_low", "median_shift_ci_high",
    "cliffs_delta", "cliffs_delta_ci_low", "cliffs_delta_ci_high",
    "mann_whitney_p_holm", "spearman_rho_normal", "spearman_p_holm",
] if c in aspect_audit_results]
display(aspect_audit_results[columns].set_index("experiment").round(4))

p_best = best_audit_row.get("mann_whitney_p_one_sided", np.nan)
print()
if np.isfinite(p_best) and p_best < 0.05:
    print("  => Ở BEST, group NORMAL bị báo nhầm có tỉ lệ khung dịch về phía")
    print("     PNEUMONIA. Kết quả PHÙ HỢP với giả thuyết model khai thác")
    print("     acquisition-geometry signal, nhưng chưa chứng minh nhân quả.")
    print("     Bằng chứng nhân quả cần can thiệp trực tiếp như lung crop,")
    print("     aspect-matched evaluation hoặc geometry-invariant training.")
else:
    print("  => Ở BEST, chưa thấy khác biệt FP/TN có ý nghĩa ở mức group.")
    print("     Không nên ép câu chuyện aspect ratio; cần xem thêm Spearman,")
    print("     bảng 2×2 và các nuisance feature khác.")
# Out:
# Cấu hình resnet18 (resize letterbox)
# MÔ TẢ, mức ảnh
#   NORMAL nhận đúng (TN)    n=169  trung vị 1.283  TB 1.305
#   NORMAL báo nhầm (FP)     n= 65  trung vị 1.530  TB 1.531
#   PNEUMONIA thật           n=390  trung vị 1.506  TB 1.527
#
# KIỂM ĐỊNH, mức group (ngưỡng 0.828)
#   TN n=151  FP n=74  PNEUMONIA n=203
#   lệch trung vị FP − TN     +0.257  KTC95% [+0.190, +0.301]
#   Cliff's delta             +0.610  KTC95% [+0.493, +0.725]
#   dịch chuyển chuẩn hóa     +108%  = (median FP−TN)/(median PNEUMONIA−TN)
#   Mann–Whitney một phía     p = 0.0000
#
# TRÊN RIÊNG NORMAL, không dùng ngưỡng
#   Spearman(tỉ lệ khung, xác suất PNEUMONIA) = +0.561  p = 0.0000
#
# TỔNG HỢP LIÊN HỆ TỈ LỆ KHUNG → LỖI/SCORE, mức group
#                  resize  n_fp  n_tn  median_shift  median_shift_ci_low  \
# experiment
# resnet18      letterbox    74   151        0.2568               0.1897
# stretch_nhe     stretch    59   166        0.2614               0.1841
# augment_manh  letterbox    73   152        0.2377               0.1535
# stretch_manh    stretch    52   173        0.2235               0.1139
#
#               median_shift_ci_high  cliffs_delta  cliffs_delta_ci_low  \
# experiment
# resnet18                    0.3007        0.6102               0.4933
# stretch_nhe                 0.3157        0.5971               0.4595
# augment_manh                0.2844        0.5494               0.4126
# stretch_manh                0.2934        0.4735               0.3044
#
#               cliffs_delta_ci_high  mann_whitney_p_holm  spearman_rho_normal  \
# experiment
# resnet18                    0.7253                  0.0               0.5611
# stretch_nhe                 0.7262                  0.0               0.4539
# augment_manh                0.6732                  0.0               0.5116
# stretch_manh                0.6259                  0.0               0.4120
#
#               spearman_p_holm
# experiment
# resnet18                  0.0
# stretch_nhe               0.0
# augment_manh              0.0
# stretch_manh              0.0
#   => Ở BEST, group NORMAL bị báo nhầm có tỉ lệ khung dịch về phía
#      PNEUMONIA. Kết quả PHÙ HỢP với giả thuyết model khai thác
#      acquisition-geometry signal, nhưng chưa chứng minh nhân quả.
#      Bằng chứng nhân quả cần can thiệp trực tiếp như lung crop,
#      aspect-matched evaluation hoặc geometry-invariant training.

# %% [markdown]
# ---
#
# # 5. Kết luận và hạn chế
#
# ## Cách gọi tên kết quả
#
# Khi trích dẫn số từ báo cáo này, ghi kèm nhãn để người đọc biết nó thuộc loại nào:
#
# | Nhãn | Ý nghĩa | Có trong báo cáo này |
# |---|---|---|
# | `smoke` | Kiểm tra kỹ thuật, không dùng để báo cáo | khi `RUN_MODE=smoke` |
# | `reproduced` | Full run theo cấu hình đã ghi | chỉ khi `RUN_MODE=full` |
# | `filename_grouped` | Chia chống rò rỉ theo group suy từ filename | ✅ mọi fold |
# | `external` | Chạy trên nguồn dữ liệu khác | ❌ chưa có |
# | `paper_reported` | Số do tài liệu gốc công bố | không áp dụng |
#
# Không dùng các từ "trustworthy", "clinical-ready", "radiologist-level" khi chưa
# có kiểm chứng lâm sàng bên ngoài.
#
# ## Đã làm được
#
# - Pipeline chạy đầu-cuối, xử lý được các bất thường của bộ dữ liệu: hai kiểu
#   đường dẫn mount, cây thư mục lồng trùng, file sidecar `._*`.
# - Kiểm tra chất lượng dữ liệu có số liệu và tái chạy được.
# - Chia theo filename-derived group và hash, xác nhận không overlap giữa split.
# - Cross-validation nhiều fold, báo khoảng dao động thay vì một con số đơn lẻ.
# - **So sánh ba kiến trúc và hai cách xử lý mất cân bằng** dưới cùng giao thức.
# - Chọn checkpoint bằng validation AUC, chọn cấu hình bằng OOF group AUC.
# - Không dùng known benchmark để chọn checkpoint, cấu hình hoặc threshold; mọi điểm làm việc được khóa từ OOF.
# - Tune riêng threshold mức ảnh và mức filename-derived group.
# - Đối chứng 2×2 tách riêng ảnh hưởng của resize và augmentation dưới cùng fold/seed.
# - XAI dùng mẫu stratify và occlusion trước normalization; không gọi viền/giữa là
#   ngoài-phổi/trong-phổi khi chưa có lung mask. XAI chỉ giải thích một model thành
#   viên đại diện và được tách khỏi prediction ensemble.
# - Seed đầy đủ gồm cả DataLoader; ghi lại phiên bản thư viện vào `environment.json`.
#
# ## Hạn chế
#
# - **Test đã từng được xem trong notebook v2.** Kết quả rerun vẫn cần
#   external/fresh holdout để có ước lượng cuối không thiên lệch.
# - Group chỉ suy từ filename, không phải patient metadata chính thức.
# - Cùng OOF được dùng cho chọn cấu hình và tune threshold; triển khai thật cần
#   calibration set độc lập hoặc nested/cross-fitted calibration.
# - **Các fold đổi đồng thời cả cách chia lẫn seed**, nên `± std` là tổng của hai
#   nguồn dao động, chưa tách riêng được. Muốn tách thì giữ nguyên một fold và đổi
#   seed.
# - Raw softmax từ weighted loss chưa phải xác suất lâm sàng đã calibration.
# - Seed không đảm bảo bitwise-identical giữa CUDA, MPS và CPU.
# - **Precision đo trên tập test có 62,5% ca bệnh**, cao hơn thực tế phòng khám, nên
#   con số này không chuyển sang môi trường triển khai được.
# - **Dữ liệu từ một trung tâm, chỉ gồm bệnh nhi 1–5 tuổi.** Không có cơ sở suy rộng
#   sang người lớn hay cơ sở y tế khác nếu chưa kiểm chứng trên dữ liệu ngoài.
# - **Nhãn nhị phân** không mô tả các bất thường khác có thể có trong nhóm bình thường.
#
# ## Hướng tiếp theo
#
# 1. Kiểm chứng trên một bộ dữ liệu ngoài trước khi nói tới khả năng khái quát hoá.
# 2. Bổ sung lung segmentation mask rồi chạy lại XAI/occlusion đúng vùng giải phẫu.
# 3. Calibration độc lập và báo Brier score, ECE, calibration curve.
# 4. Hard-negative mining chỉ từ train/OOF, tuyệt đối không lấy từ known benchmark.
# 5. Chạy nhiều seed và patient/group bootstrap confidence interval.
#
# ## Tệp xuất ra
#
# | Tệp | Nội dung |
# |---|---|
# | `train_log.txt` | Nhật ký huấn luyện đầy đủ |
# | `resolved_config.json` | Cấu hình thực tế sau khi resolve auto/smoke/full |
# | `results_oof_validation.csv` | So sánh cấu hình chỉ từ validation |
# | `results_known_benchmark_test.csv` | Kết quả benchmark của cấu hình `BEST` |
# | `results_factorial_resize.csv` | Đối chứng 2×2 với gap/drop OOF→benchmark |
# | `results_aspect_error_audit.csv` | Effect size, KTC bootstrap và Spearman theo model |
# | `predictions_known_benchmark_test_images.csv` | Xác suất benchmark mức ảnh của `BEST` |
# | `predictions_known_benchmark_test_groups.csv` | Xác suất benchmark mức group của `BEST` |
# | `predictions_known_benchmark_*_images.csv` | Prediction mức ảnh cho các ô factorial |
# | `predictions_known_benchmark_*_groups.csv` | Prediction mức group cho các ô factorial |
# | `validation_predictions_*` | OOF/holdout prediction từng fold |
# | `manifest_fold*.csv` | Danh sách ảnh chính xác của từng fold |
# | `environment.json` | Phiên bản thư viện, device, mode, seed |
# | `*_fold*.pth` | Trọng số tốt nhất của từng thí nghiệm × fold |
#
# Đính kèm `manifest_fold*.csv`, `resolved_config.json` và `environment.json` khi
# nộp để người đọc truy ngược được đúng danh sách ảnh, cấu hình và môi trường đứng
# sau mỗi con số.
